# %% [markdown]
# # 네이버 뉴스 본문 수집 (BS4 Colab용)
#
# 기사 주소 수집 노트북에서 만든 `링크_{press}_*.json`을 읽고, 각 기사 페이지에서 제목·본문·날짜·카테고리를 가져오는 노트북임.
# 언론사별 기간 파일 하나를 읽어 본문 CSV 하나로 저장함. 중간에 끊겨도 저장된 지점부터 이어서 가능.
#
# - 입력: `링크_{press}_{YYMMDD}_{YYMMDD}.json`
# - 출력: `본문_bs4_{press}_{YYMMDD}_{YYMMDD}.csv`
# - 보조 파일: 중간 저장 JSON, 다시 시도해도 실패한 기사 주소 JSON
# - 처리 내용: 기사 본문 수집, 오류 기사 1회 재시도, 스포츠/연예 기사 따로 처리, 이미 끝난 파일 건너뛰기

# %%
# Colab 환경 세팅 — requests, BeautifulSoup 설치
# !pip install -q requests beautifulsoup4 pandas

# %%
# 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Drive 안의 프로젝트 폴더로 이동
import os
PROJECT_DIR = '/content/drive/MyDrive/Text-data-Analysis_26-Spring'
os.chdir(PROJECT_DIR)
print(f'현재 작업 폴더: {os.getcwd()}')
# Out:
# 현재 작업 폴더: /content/drive/MyDrive/Text-data-Analysis_26-Spring

# %%
import json
import os
import random
import re
import time
import unicodedata
from datetime import datetime, timedelta
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup

# 기사 페이지를 읽을 때 쓰는 기본 정보 설정
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36'

# 수집할 언론사와 기간 지정
# 기사 주소 수집 노트북과 동일한 press_ranges 그대로 사용. oid는 본문 수집에선 안 씀
# press 하나당 start_date ~ end_date 통합 1개 CSV로 저장
# 날짜 형식: 'YYYY.MM.DD'
press_ranges = [
    # 지상파 (이미 수집됨 — 본문_bs4_*.csv가 있으면 SKIP_COMPLETED로 건너뜀)
    {'press': 'SBS', 'oid': '055', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    {'press': 'KBS', 'oid': '056', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    {'press': 'MBC', 'oid': '214', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    # 경제
    {'press': '한국경제', 'oid': '015', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    {'press': '매일경제', 'oid': '009', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    # 정치색
    {'press': '한겨레', 'oid': '028', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    {'press': '조선일보', 'oid': '023', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    # 통신·보도
    {'press': '연합뉴스', 'oid': '001', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
    {'press': 'YTN',     'oid': '052', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
]


# press_ranges의 항목을 실행할 작업 목록으로 바꿈
# 기사 주소 수집 때와 같은 언론사명, 시작일, 종료일을 본문 수집에도 사용
def build_period_jobs(press_ranges):
    jobs = []
    for item in press_ranges:
        # 'YYYY.MM.DD' 형식의 날짜를 실제 날짜로 바꿔 기간이 맞는지 확인
        start = datetime.strptime(item['start_date'], '%Y.%m.%d')
        end = datetime.strptime(item['end_date'], '%Y.%m.%d')
        # 시작 일자가 끝 일자보다 늦으면 작업 범위가 잘못된 것이므로 즉시 중단
        if start > end:
            raise ValueError(f"시작 일자가 끝 일자보다 늦습니다: {item}")
        # oid는 본문 수집에선 안 쓰니까 제외 (링크 파일명은 press로만 매칭)
        jobs.append({
            'press': item['press'],
            'start_date': item['start_date'],
            'end_date': item['end_date'],
        })
    return jobs


# 변수 정의 (날짜 형식: 'YYYY.MM.DD')
# 만든 작업 목록은 다음 셀에서 순서대로 실행
jobs = build_period_jobs(press_ranges)

print(f'총 작업 수: {len(jobs)}')
for job in jobs:
    print(job)

# 셀 3을 건너뛰고 실행해도 기본 프로젝트 경로를 사용할 수 있게 보완
try:
    PROJECT_DIR
except NameError:
    PROJECT_DIR = '/content/drive/MyDrive/Text-data-Analysis_26-Spring'

# 저장할 폴더 지정 — 링크 파일, 중간 저장 파일, 본문 CSV, 실패 목록이 모두 이 폴더에 저장
SAVE_DIR = Path(PROJECT_DIR) / 'news' / 'notebook' / 'crawling' / 'data'
SAVE_DIR.mkdir(parents=True, exist_ok=True)
print(f'저장 폴더: {SAVE_DIR}')

# 요청할 때마다 같은 기본 정보와 한국어 우선 설정 사용
# 네이버 뉴스 본문은 페이지 주소를 열어 받은 내용 안에서 바로 찾을 수 있음
session = requests.Session()
session.headers.update({
    'User-Agent': USER_AGENT,
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
})
print(f'User-Agent: {USER_AGENT}')
# Out:
# 총 작업 수: 9
# {'press': 'SBS', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': 'KBS', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': 'MBC', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': '한국경제', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': '매일경제', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': '한겨레', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': '조선일보', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': '연합뉴스', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# {'press': 'YTN', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# 저장 위치: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36

# %%
# 네이버에 너무 자주 접속하지 않도록 기사/언론사 사이에 짧게 랜덤 대기
# 기사 간 대기 — 빠른 요청 속도에 맞게 짧게 설정
ARTICLE_PAUSE_RANGE_SEC = (0.4, 1.2)
JOB_PAUSE_RANGE_SEC = (8, 20)

# 중간에 끊겨도 이어서 수집할 수 있도록 일정 건수마다 중간 저장
# 너무 자주 저장하지 않도록 저장 간격을 넓게 설정
CHECKPOINT_INTERVAL = 200
REQUEST_TIMEOUT_SEC = 10
SKIP_COMPLETED = True

# 일반 뉴스 주소가 스포츠/연예 페이지로 자동 이동하는 경우를 따로 처리하기 위한 설정
# 주소에 아래 글자가 들어 있으면 스포츠/연예 기사로 보고 카테고리를 따로 가져옴
# 다른 주소 유형이 생기면 이 표에만 추가하면 됨
REDIRECT_DOMAINS = {
    'sports.naver.com': ('스포츠', r'https://m\.sports\.naver\.com/([^/]+)/article/'),
    'entertain.naver.com': ('연예', r'https://m\.entertain\.naver\.com/([^/]+)/article/'),
}

# 랜덤 대기 후 로그 출력
def polite_sleep(label, pause_range):
    pause_sec = random.uniform(*pause_range)
    print(f"{label} {pause_sec:.1f}초 대기")
    time.sleep(pause_sec)

# 파일명에 사용할 YYMMDD_YYMMDD 형식 기간 문자열 생성
# 예: 2026.05.01 ~ 2026.05.07 -> '260501_260507'
def make_period_suffix(start_date, end_date):
    return f"{start_date.replace('.', '')[2:]}_{end_date.replace('.', '')[2:]}"

# 페이지 내용에서 원하는 항목을 찾지 못하면 빈 문자열로 반환
def get_text_or_empty(soup, css_rule):
    element = soup.select_one(css_rule)
    return element.get_text(strip=True) if element else ''

# 본문 안의 줄바꿈/연속 공백을 하나의 공백으로 정리 (CSV/분석 단계 일관성 위해)
def normalize_body_text(text):
    return re.sub(r'\s+', ' ', text).strip()

# 화면에 보이는 한글 날짜를 일반 뉴스 날짜값과 같은 형태로 바꿈
# 예: '2026.05.05. 오전 7:10' -> '2026-05-05 07:10:00'
def parse_korean_datetime(text):
    m = re.match(r'(\d{4})\.(\d{2})\.(\d{2})\.\s*(오전|오후)\s*(\d{1,2}):(\d{2})', text)
    if not m:
        return ''
    y, mo, d, ampm, h, mi = m.groups()
    h = int(h)
    # 12시간제 → 24시간제 변환 (오전 12시 = 00시, 오후 12시 = 12시 그대로)
    if ampm == '오후' and h != 12:
        h += 12
    elif ampm == '오전' and h == 12:
        h = 0
    return f'{y}-{mo}-{d} {h:02d}:{mi}:00'

# 스포츠/연예 기사는 일반 뉴스와 페이지 구조가 달라 따로 추출
# 스포츠/연예 쪽은 제목, 본문, 날짜가 들어 있는 위치가 서로 비슷함
def extract_redirected_article_bs4(response, original_link):
    soup = BeautifulSoup(response.text, 'html.parser')

    # 제목 추출하기 — 페이지 정보에 들어 있는 제목 사용
    title_meta = soup.find('meta', property='og:title')
    title = title_meta.get('content', '').strip() if title_meta else ''

    # 본문 추출하기 — 스포츠/연예 기사 본문 영역 사용
    body_el = soup.select_one('div._article_content')
    body = normalize_body_text(body_el.get_text(strip=True)) if body_el else ''

    # 날짜 추출하기 — em.date 첫 번째(입력일). 두 번째는 수정일이라 무시
    em = soup.select_one('em.date')
    pubdate = parse_korean_datetime(em.get_text(strip=True)) if em else ''

    # 주소에 sports나 entertain이 들어 있는지 보고 카테고리 정리
    # 예: m.sports.naver.com/golf/article/... -> '스포츠/golf'
    category = '기타'
    for domain, (prefix, pattern) in REDIRECT_DOMAINS.items():
        if domain in response.url:
            cat_match = re.match(pattern, response.url)
            category = f'{prefix}/{cat_match.group(1)}' if cat_match else prefix
            break

    # 제목/본문/날짜 중 하나라도 없으면 실패로 기록하고 재시도 대상에 포함
    if not title or not body or not pubdate:
        raise ValueError(f'스포츠/연예 기사: title={bool(title)}, body={bool(body)}, pubdate={bool(pubdate)}')

    # 저장할 때는 처음에 모아 둔 기사 주소 그대로 남김
    return {
        'link': original_link,
        'pubdate': pubdate,
        'category': category,
        'title': title,
        'body': body,
    }

# 기사 한 건에서 title/body/pubdate/category 추출 (BS4 버전)

def extract_article_bs4(link, session=session):
    # 실제 네이버 뉴스 페이지 요청 — 스포츠/연예로 자동 이동되는 경우도 있음
    response = session.get(link, timeout=REQUEST_TIMEOUT_SEC)
    response.raise_for_status()

    # 스포츠/연예 페이지로 이동된 기사면 위에서 만든 별도 추출 함수 사용
    if any(domain in response.url for domain in REDIRECT_DOMAINS):
        return extract_redirected_article_bs4(response, link)

    soup = BeautifulSoup(response.text, 'html.parser')

    # 제목 추출하기
    title = get_text_or_empty(soup, '.media_end_head_headline')

    # 본문 추출하기 — 공백 정리해 단일 문자열로
    body = get_text_or_empty(soup, '#newsct_article')
    body = normalize_body_text(body)

    # 날짜 추출하기 — 화면 글자 대신 페이지 안의 data-date-time 날짜값 사용
    pubdate_element = soup.select_one('span.media_end_head_info_datestamp_time._ARTICLE_DATE_TIME')
    pubdate = pubdate_element.get('data-date-time', '') if pubdate_element else ''

    # 카테고리 추출하기 — 상단 탭 중 현재 활성화된(aria-selected="true") 항목
    category = get_text_or_empty(soup, 'a.Nitem_link[aria-selected="true"] span.Nitem_link_menu')

    # 제목/본문/날짜 중 하나라도 없으면 실패로 기록하고 재시도 대상에 포함
    if not title or not body or not pubdate:
        raise ValueError('title/body/pubdate 중 일부를 추출하지 못함')

    return {
        'link': link,
        'pubdate': pubdate,
        'category': category,
        'title': title,
        'body': body,
    }

# 한 언론사의 기간 통합 링크 JSON을 읽어 본문을 수집하고 통합 CSV로 저장
# 중간 저장 파일로 이어서 수집하고, 오류가 난 기사는 한 번 더 시도한 뒤 실패 목록 저장
# 한글 파일명이 환경에 따라 다르게 저장될 수 있어 이름을 한 번 정리해서 비교
# 같은 이름의 기존 파일이 없으면 새로 저장할 경로를 반환
def resolve_nfc_path(save_dir, filename):
    target = unicodedata.normalize('NFC', filename)
    direct = save_dir / filename
    if direct.exists():
        return direct
    for cand in save_dir.iterdir():
        if unicodedata.normalize('NFC', cand.name) == target:
            return cand
    return save_dir / target

def collect_bodies_bs4(press, start_date, end_date, save_dir=SAVE_DIR):
    # 파일명 키로 쓸 기간 접미사 (예: 260501_260507)
    period = make_period_suffix(start_date, end_date)
    # 입력/출력 경로 — 한글 파일명 차이 때문에 못 찾는 일을 줄이기 위해 이름을 정리해서 비교
    links_path = resolve_nfc_path(save_dir, f"링크_{press}_{period}.json")
    checkpoint_path = resolve_nfc_path(save_dir, f"체크포인트_본문_bs4_{press}_{period}.json")
    csv_save_path = resolve_nfc_path(save_dir, f"본문_bs4_{press}_{period}.csv")

    # 최종 파일이 이미 있으면 같은 기간은 다시 수집하지 않음
    if SKIP_COMPLETED and csv_save_path.exists():
        print()
        print(f"=== {press} / {start_date} ~ {end_date} 이미 완료됨, 건너뜀 ===")
        print(f"기존 파일: {csv_save_path}")
        return csv_save_path

    # 링크 파일 불러오기
    if links_path.exists():
        with links_path.open('r', encoding='utf-8') as f:
            naver_news_links = json.load(f)
        # 대략적인 예상 시간 출력 — 실제 시간은 인터넷 상태와 재시도 여부에 따라 달라질 수 있음
        avg_pause_sec = sum(ARTICLE_PAUSE_RANGE_SEC) / 2
        est_sec_per_article = avg_pause_sec + 0.7
        est_min = len(naver_news_links) * est_sec_per_article / 60
        print()
        print(f"=== {press} / {start_date} ~ {end_date} BS4 본문 수집 시작 ===")
        print(f'링크 {len(naver_news_links)}개 불러옴: {links_path}')
        print(f'예상 소요 시간: 약 {est_min:.0f}분')
    else:
        raise FileNotFoundError(f'링크 파일 없음 — 언론사_네이버뉴스_url_수집_colab.ipynb를 먼저 실행하세요\n경로: {links_path}')

    # 이전에 중단된 작업이 있으면 이어받기 — next_i 인덱스 다음부터 시작
    if checkpoint_path.exists():
        with checkpoint_path.open('r', encoding='utf-8') as f:
            checkpoint = json.load(f)
        # JSON은 dict 키를 문자열로 저장하므로 int로 다시 변환
        all_results = {int(k): v for k, v in checkpoint.get('all_results', {}).items()}
        err_idx = checkpoint.get('err_idx', [])
        i = checkpoint.get('next_i', 0)
        print(f'체크포인트 발견 — {i}번째부터 이어서 시작 (이미 수집: {len(all_results)}건)')
    else:
        all_results = dict()
        i = 0
        err_idx = []
        print('새로 시작')

    # 추출한 링크에 직접 방문하여 크롤링 진행
    for link in naver_news_links[i:]:
        try:
            all_results[i] = extract_article_bs4(link)

            # 진행 중인 건수 표시 코드
            print(f'[{i+1} / {len(naver_news_links)}] \t {(i+1)/len(naver_news_links)*100:.2f}% \t error: {len(err_idx)}')

            i += 1

            # 중간저장 — N건마다 저장해서 중간에 끊겨도 이어서 할 수 있게 함
            if i % CHECKPOINT_INTERVAL == 0:
                with checkpoint_path.open('w', encoding='utf-8') as f:
                    json.dump({'all_results': all_results, 'err_idx': err_idx, 'next_i': i}, f, ensure_ascii=False, indent=2)
                print(f'체크포인트 저장 — {i}건 완료')

            # 봇 탐지 방지를 위해 다음 기사 요청 전 랜덤한 시간을 기다림
            polite_sleep('다음 기사 전', ARTICLE_PAUSE_RANGE_SEC)

        except Exception as exc:
            print(f'오류 발생 — index {i}: {exc!r}')
            # 실패한 index는 err_idx에 저장한 뒤 마지막에 한 번 더 재시도
            err_idx.append(i)
            i += 1
            # 오류가 난 번호도 빠지지 않게 바로 중간 저장
            with checkpoint_path.open('w', encoding='utf-8') as f:
                json.dump({'all_results': all_results, 'err_idx': err_idx, 'next_i': i}, f, ensure_ascii=False, indent=2)

    # 1차 오류 자동 재시도 — 일시적 네트워크 문제나 응답 지연이었던 경우를 한 번 더 시도
    if err_idx:
        print()
        print(f'오류 {len(err_idx)}건 재시도 시작...')
        re_err_idx = []

        for retry_i in err_idx:
            try:
                link = naver_news_links[retry_i]
                all_results[retry_i] = extract_article_bs4(link)
                print(f'재시도 성공 — index {retry_i}')
                polite_sleep('다음 재시도 전', ARTICLE_PAUSE_RANGE_SEC)
            except Exception as exc:
                print(f'재시도 실패 — index {retry_i}: {exc!r}')
                re_err_idx.append(retry_i)

        # 재시도 후에도 실패한 인덱스만 남김 — 본문_bs4_재실패_*.json으로 저장 대상
        err_idx = re_err_idx
        print(f'재시도 완료 — 재실패: {len(err_idx)}건')

    # 수집한 정보들을 표 형태로 변환
    df = pd.DataFrame(all_results).T

    if df.empty:
        raise ValueError('수집된 본문 데이터가 없습니다.')

    # 수집한 기사들 중 중복인 경우 이를 제거
    df_no_duplicates = df.drop_duplicates().reset_index(drop=True)

    # 오래된 순부터 수집했으나 혹시 모를 상황을 방지하기 위해 pubdate를 datetime으로 변환 후 정렬
    df_no_duplicates['pubdate'] = pd.to_datetime(df_no_duplicates['pubdate'], errors='coerce')
    df_sorted = df_no_duplicates.sort_values(by='pubdate')

    # 수집한 정보들을 csv로 저장 (Google Drive에 저장)
    df_sorted.to_csv(csv_save_path, index=False, encoding='utf-8-sig')
    print(f'저장 완료: {csv_save_path}')

    if err_idx:
        # 다시 시도해도 실패한 기사 주소는 별도 JSON으로 저장해 크롬 재확인 노트북에서 볼 수 있게 함
        failed_path = save_dir / f"본문_bs4_재실패_{press}_{period}.json"
        with failed_path.open('w', encoding='utf-8') as f:
            json.dump({'err_idx': err_idx, 'links': [naver_news_links[x] for x in err_idx]}, f, ensure_ascii=False, indent=2)
        print(f'재실패 목록 저장: {failed_path}')
    elif checkpoint_path.exists():
        # 재실패가 없을 때만 중간 파일 삭제 — 실패가 있으면 참고용으로 남김
        checkpoint_path.unlink()

    print(f'본문 수집 완료 — 총 {len(df_sorted)}건 / 오류 {len(err_idx)}건')
    return csv_save_path

# 생성된 jobs를 순서대로 실행
# 한 작업이 실패해도 실패 목록에 기록하고 다음 작업으로 넘어감
results = []
failures = []
for index, job in enumerate(jobs, start=1):
    print()
    print(f"[{index}/{len(jobs)}] 작업 실행: {job}")
    try:
        # 작업 정보의 언론사, 시작일, 종료일을 본문 수집 함수에 전달
        results.append(collect_bodies_bs4(**job))
    except Exception as exc:
        # 한 언론사에서 오류가 나도 전체 작업이 멈추지 않도록 실패 정보만 저장
        failures.append({'job': job, 'error': repr(exc)})
        print(f"작업 실패, 다음 작업으로 넘어감: {exc!r}")
    finally:
        if index < len(jobs):
            # 다음 언론사로 넘어가기 전 대기
            polite_sleep('다음 작업 전', JOB_PAUSE_RANGE_SEC)

# 실패한 작업이 있으면 다시 돌릴 수 있게 파일로 저장
if failures:
    failures_path = SAVE_DIR / '본문_bs4_수집실패목록_naver.json'
    with failures_path.open('w', encoding='utf-8') as f:
        json.dump(failures, f, ensure_ascii=False, indent=2)
    print()
    print(f"실패 작업 {len(failures)}개 저장: {failures_path}")

print()
print('전체 작업 완료')
print(f'성공/건너뜀: {len(results)}개, 실패: {len(failures)}개')
for result_path in results:
    print(result_path)
# Out:
# [1/9] 작업 실행: {'press': 'SBS', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === SBS / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_SBS_260505_260511.csv
# 다음 작업 전 15.8초 대기
#
# [2/9] 작업 실행: {'press': 'KBS', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === KBS / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_KBS_260505_260511.csv
# 다음 작업 전 9.4초 대기
#
# [3/9] 작업 실행: {'press': 'MBC', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === MBC / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_MBC_260505_260511.csv
# 다음 작업 전 18.7초 대기
#
# [4/9] 작업 실행: {'press': '한국경제', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === 한국경제 / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_한국경제_260505_260511.csv
# 다음 작업 전 10.9초 대기
#
# [5/9] 작업 실행: {'press': '매일경제', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === 매일경제 / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_매일경제_260505_260511.csv
# 다음 작업 전 19.8초 대기
#
# [6/9] 작업 실행: {'press': '한겨레', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === 한겨레 / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_한겨레_260505_260511.csv
# 다음 작업 전 18.1초 대기
#
# [7/9] 작업 실행: {'press': '조선일보', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === 조선일보 / 2026.05.05 ~ 2026.05.11 이미 완료됨, 건너뜀 ===
# 기존 파일: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_조선일보_260505_260511.csv
# 다음 작업 전 15.0초 대기
#
# [8/9] 작업 실행: {'press': '연합뉴스', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === 연합뉴스 / 2026.05.05 ~ 2026.05.11 BS4 본문 수집 시작 ===
# 링크 1540개 불러옴: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/링크_연합뉴스_260505_260511.json
# 예상 소요 시간: 약 38분
# 새로 시작
# [1 / 1540] 	 0.06% 	 error: 0
# 다음 기사 전 0.5초 대기
# [2 / 1540] 	 0.13% 	 error: 0
# 다음 기사 전 0.7초 대기
# [3 / 1540] 	 0.19% 	 error: 0
# 다음 기사 전 1.0초 대기
# [4 / 1540] 	 0.26% 	 error: 0
# 다음 기사 전 1.0초 대기
# [5 / 1540] 	 0.32% 	 error: 0
# 다음 기사 전 0.6초 대기
# [6 / 1540] 	 0.39% 	 error: 0
# 다음 기사 전 0.8초 대기
# [7 / 1540] 	 0.45% 	 error: 0
# 다음 기사 전 1.0초 대기
# [8 / 1540] 	 0.52% 	 error: 0
# 다음 기사 전 1.1초 대기
# [9 / 1540] 	 0.58% 	 error: 0
# 다음 기사 전 0.8초 대기
# [10 / 1540] 	 0.65% 	 error: 0
# 다음 기사 전 0.8초 대기
# [11 / 1540] 	 0.71% 	 error: 0
# 다음 기사 전 0.9초 대기
# [12 / 1540] 	 0.78% 	 error: 0
# 다음 기사 전 0.8초 대기
# [13 / 1540] 	 0.84% 	 error: 0
# 다음 기사 전 1.1초 대기
# [14 / 1540] 	 0.91% 	 error: 0
# 다음 기사 전 1.1초 대기
# [15 / 1540] 	 0.97% 	 error: 0
# 다음 기사 전 0.8초 대기
# [16 / 1540] 	 1.04% 	 error: 0
# 다음 기사 전 0.7초 대기
# [17 / 1540] 	 1.10% 	 error: 0
# 다음 기사 전 1.1초 대기
# [18 / 1540] 	 1.17% 	 error: 0
# 다음 기사 전 0.7초 대기
# [19 / 1540] 	 1.23% 	 error: 0
# 다음 기사 전 1.0초 대기
# [20 / 1540] 	 1.30% 	 error: 0
# 다음 기사 전 1.0초 대기
# [21 / 1540] 	 1.36% 	 error: 0
# 다음 기사 전 0.9초 대기
# [22 / 1540] 	 1.43% 	 error: 0
# 다음 기사 전 1.1초 대기
# [23 / 1540] 	 1.49% 	 error: 0
# 다음 기사 전 1.1초 대기
# [24 / 1540] 	 1.56% 	 error: 0
# 다음 기사 전 1.1초 대기
# [25 / 1540] 	 1.62% 	 error: 0
# 다음 기사 전 1.0초 대기
# [26 / 1540] 	 1.69% 	 error: 0
# 다음 기사 전 0.4초 대기
# [27 / 1540] 	 1.75% 	 error: 0
# 다음 기사 전 0.8초 대기
# [28 / 1540] 	 1.82% 	 error: 0
# 다음 기사 전 0.7초 대기
# [29 / 1540] 	 1.88% 	 error: 0
# 다음 기사 전 0.7초 대기
# [30 / 1540] 	 1.95% 	 error: 0
# 다음 기사 전 1.0초 대기
# [31 / 1540] 	 2.01% 	 error: 0
# 다음 기사 전 0.4초 대기
# [32 / 1540] 	 2.08% 	 error: 0
# 다음 기사 전 0.9초 대기
# [33 / 1540] 	 2.14% 	 error: 0
# 다음 기사 전 0.7초 대기
# [34 / 1540] 	 2.21% 	 error: 0
# 다음 기사 전 1.2초 대기
# [35 / 1540] 	 2.27% 	 error: 0
# 다음 기사 전 1.0초 대기
# [36 / 1540] 	 2.34% 	 error: 0
# 다음 기사 전 1.1초 대기
# [37 / 1540] 	 2.40% 	 error: 0
# 다음 기사 전 0.5초 대기
# [38 / 1540] 	 2.47% 	 error: 0
# 다음 기사 전 0.5초 대기
# [39 / 1540] 	 2.53% 	 error: 0
# 다음 기사 전 0.9초 대기
# [40 / 1540] 	 2.60% 	 error: 0
# 다음 기사 전 0.9초 대기
# [41 / 1540] 	 2.66% 	 error: 0
# 다음 기사 전 0.6초 대기
# [42 / 1540] 	 2.73% 	 error: 0
# 다음 기사 전 1.1초 대기
# [43 / 1540] 	 2.79% 	 error: 0
# 다음 기사 전 1.1초 대기
# [44 / 1540] 	 2.86% 	 error: 0
# 다음 기사 전 0.9초 대기
# [45 / 1540] 	 2.92% 	 error: 0
# 다음 기사 전 1.0초 대기
# [46 / 1540] 	 2.99% 	 error: 0
# 다음 기사 전 0.5초 대기
# [47 / 1540] 	 3.05% 	 error: 0
# 다음 기사 전 1.1초 대기
# [48 / 1540] 	 3.12% 	 error: 0
# 다음 기사 전 0.5초 대기
# [49 / 1540] 	 3.18% 	 error: 0
# 다음 기사 전 0.5초 대기
# [50 / 1540] 	 3.25% 	 error: 0
# 다음 기사 전 1.1초 대기
# [51 / 1540] 	 3.31% 	 error: 0
# 다음 기사 전 1.0초 대기
# [52 / 1540] 	 3.38% 	 error: 0
# 다음 기사 전 1.0초 대기
# [53 / 1540] 	 3.44% 	 error: 0
# 다음 기사 전 1.1초 대기
# [54 / 1540] 	 3.51% 	 error: 0
# 다음 기사 전 0.6초 대기
# [55 / 1540] 	 3.57% 	 error: 0
# 다음 기사 전 0.9초 대기
# [56 / 1540] 	 3.64% 	 error: 0
# 다음 기사 전 0.6초 대기
# [57 / 1540] 	 3.70% 	 error: 0
# 다음 기사 전 0.6초 대기
# [58 / 1540] 	 3.77% 	 error: 0
# 다음 기사 전 0.9초 대기
# [59 / 1540] 	 3.83% 	 error: 0
# 다음 기사 전 0.7초 대기
# [60 / 1540] 	 3.90% 	 error: 0
# 다음 기사 전 1.1초 대기
# [61 / 1540] 	 3.96% 	 error: 0
# 다음 기사 전 0.7초 대기
# [62 / 1540] 	 4.03% 	 error: 0
# 다음 기사 전 1.0초 대기
# [63 / 1540] 	 4.09% 	 error: 0
# 다음 기사 전 0.5초 대기
# [64 / 1540] 	 4.16% 	 error: 0
# 다음 기사 전 1.0초 대기
# [65 / 1540] 	 4.22% 	 error: 0
# 다음 기사 전 0.6초 대기
# [66 / 1540] 	 4.29% 	 error: 0
# 다음 기사 전 0.7초 대기
# [67 / 1540] 	 4.35% 	 error: 0
# 다음 기사 전 0.4초 대기
# [68 / 1540] 	 4.42% 	 error: 0
# 다음 기사 전 0.6초 대기
# [69 / 1540] 	 4.48% 	 error: 0
# 다음 기사 전 0.9초 대기
# [70 / 1540] 	 4.55% 	 error: 0
# 다음 기사 전 0.5초 대기
# [71 / 1540] 	 4.61% 	 error: 0
# 다음 기사 전 1.2초 대기
# [72 / 1540] 	 4.68% 	 error: 0
# 다음 기사 전 0.7초 대기
# [73 / 1540] 	 4.74% 	 error: 0
# 다음 기사 전 0.8초 대기
# [74 / 1540] 	 4.81% 	 error: 0
# 다음 기사 전 0.9초 대기
# [75 / 1540] 	 4.87% 	 error: 0
# 다음 기사 전 1.2초 대기
# [76 / 1540] 	 4.94% 	 error: 0
# 다음 기사 전 0.7초 대기
# [77 / 1540] 	 5.00% 	 error: 0
# 다음 기사 전 1.1초 대기
# [78 / 1540] 	 5.06% 	 error: 0
# 다음 기사 전 0.7초 대기
# [79 / 1540] 	 5.13% 	 error: 0
# 다음 기사 전 0.6초 대기
# [80 / 1540] 	 5.19% 	 error: 0
# 다음 기사 전 0.6초 대기
# [81 / 1540] 	 5.26% 	 error: 0
# 다음 기사 전 1.1초 대기
# [82 / 1540] 	 5.32% 	 error: 0
# 다음 기사 전 0.7초 대기
# [83 / 1540] 	 5.39% 	 error: 0
# 다음 기사 전 0.7초 대기
# [84 / 1540] 	 5.45% 	 error: 0
# 다음 기사 전 0.8초 대기
# [85 / 1540] 	 5.52% 	 error: 0
# 다음 기사 전 0.9초 대기
# [86 / 1540] 	 5.58% 	 error: 0
# 다음 기사 전 1.2초 대기
# [87 / 1540] 	 5.65% 	 error: 0
# 다음 기사 전 0.7초 대기
# [88 / 1540] 	 5.71% 	 error: 0
# 다음 기사 전 0.6초 대기
# [89 / 1540] 	 5.78% 	 error: 0
# 다음 기사 전 0.4초 대기
# [90 / 1540] 	 5.84% 	 error: 0
# 다음 기사 전 0.5초 대기
# [91 / 1540] 	 5.91% 	 error: 0
# 다음 기사 전 0.5초 대기
# [92 / 1540] 	 5.97% 	 error: 0
# 다음 기사 전 0.6초 대기
# [93 / 1540] 	 6.04% 	 error: 0
# 다음 기사 전 0.9초 대기
# [94 / 1540] 	 6.10% 	 error: 0
# 다음 기사 전 1.1초 대기
# [95 / 1540] 	 6.17% 	 error: 0
# 다음 기사 전 0.8초 대기
# [96 / 1540] 	 6.23% 	 error: 0
# 다음 기사 전 0.7초 대기
# [97 / 1540] 	 6.30% 	 error: 0
# 다음 기사 전 0.5초 대기
# [98 / 1540] 	 6.36% 	 error: 0
# 다음 기사 전 1.0초 대기
# [99 / 1540] 	 6.43% 	 error: 0
# 다음 기사 전 0.7초 대기
# [100 / 1540] 	 6.49% 	 error: 0
# 다음 기사 전 0.6초 대기
# [101 / 1540] 	 6.56% 	 error: 0
# 다음 기사 전 0.6초 대기
# [102 / 1540] 	 6.62% 	 error: 0
# 다음 기사 전 0.7초 대기
# [103 / 1540] 	 6.69% 	 error: 0
# 다음 기사 전 0.8초 대기
# [104 / 1540] 	 6.75% 	 error: 0
# 다음 기사 전 1.2초 대기
# [105 / 1540] 	 6.82% 	 error: 0
# 다음 기사 전 0.6초 대기
# [106 / 1540] 	 6.88% 	 error: 0
# 다음 기사 전 0.7초 대기
# [107 / 1540] 	 6.95% 	 error: 0
# 다음 기사 전 0.9초 대기
# [108 / 1540] 	 7.01% 	 error: 0
# 다음 기사 전 0.8초 대기
# [109 / 1540] 	 7.08% 	 error: 0
# 다음 기사 전 0.8초 대기
# [110 / 1540] 	 7.14% 	 error: 0
# 다음 기사 전 0.7초 대기
# [111 / 1540] 	 7.21% 	 error: 0
# 다음 기사 전 0.6초 대기
# [112 / 1540] 	 7.27% 	 error: 0
# 다음 기사 전 0.5초 대기
# [113 / 1540] 	 7.34% 	 error: 0
# 다음 기사 전 1.0초 대기
# [114 / 1540] 	 7.40% 	 error: 0
# 다음 기사 전 0.6초 대기
# [115 / 1540] 	 7.47% 	 error: 0
# 다음 기사 전 0.4초 대기
# [116 / 1540] 	 7.53% 	 error: 0
# 다음 기사 전 1.1초 대기
# [117 / 1540] 	 7.60% 	 error: 0
# 다음 기사 전 0.6초 대기
# [118 / 1540] 	 7.66% 	 error: 0
# 다음 기사 전 0.5초 대기
# [119 / 1540] 	 7.73% 	 error: 0
# 다음 기사 전 0.8초 대기
# [120 / 1540] 	 7.79% 	 error: 0
# 다음 기사 전 0.6초 대기
# [121 / 1540] 	 7.86% 	 error: 0
# 다음 기사 전 0.8초 대기
# [122 / 1540] 	 7.92% 	 error: 0
# 다음 기사 전 0.5초 대기
# [123 / 1540] 	 7.99% 	 error: 0
# 다음 기사 전 0.8초 대기
# [124 / 1540] 	 8.05% 	 error: 0
# 다음 기사 전 1.0초 대기
# [125 / 1540] 	 8.12% 	 error: 0
# 다음 기사 전 0.4초 대기
# [126 / 1540] 	 8.18% 	 error: 0
# 다음 기사 전 0.9초 대기
# [127 / 1540] 	 8.25% 	 error: 0
# 다음 기사 전 1.1초 대기
# [128 / 1540] 	 8.31% 	 error: 0
# 다음 기사 전 0.4초 대기
# [129 / 1540] 	 8.38% 	 error: 0
# 다음 기사 전 0.4초 대기
# [130 / 1540] 	 8.44% 	 error: 0
# 다음 기사 전 0.9초 대기
# [131 / 1540] 	 8.51% 	 error: 0
# 다음 기사 전 1.0초 대기
# [132 / 1540] 	 8.57% 	 error: 0
# 다음 기사 전 1.1초 대기
# [133 / 1540] 	 8.64% 	 error: 0
# 다음 기사 전 0.7초 대기
# [134 / 1540] 	 8.70% 	 error: 0
# 다음 기사 전 1.0초 대기
# [135 / 1540] 	 8.77% 	 error: 0
# 다음 기사 전 0.9초 대기
# [136 / 1540] 	 8.83% 	 error: 0
# 다음 기사 전 0.6초 대기
# [137 / 1540] 	 8.90% 	 error: 0
# 다음 기사 전 0.8초 대기
# [138 / 1540] 	 8.96% 	 error: 0
# 다음 기사 전 0.6초 대기
# [139 / 1540] 	 9.03% 	 error: 0
# 다음 기사 전 0.6초 대기
# [140 / 1540] 	 9.09% 	 error: 0
# 다음 기사 전 0.8초 대기
# [141 / 1540] 	 9.16% 	 error: 0
# 다음 기사 전 0.4초 대기
# [142 / 1540] 	 9.22% 	 error: 0
# 다음 기사 전 1.1초 대기
# [143 / 1540] 	 9.29% 	 error: 0
# 다음 기사 전 0.6초 대기
# [144 / 1540] 	 9.35% 	 error: 0
# 다음 기사 전 0.8초 대기
# [145 / 1540] 	 9.42% 	 error: 0
# 다음 기사 전 0.7초 대기
# [146 / 1540] 	 9.48% 	 error: 0
# 다음 기사 전 1.1초 대기
# [147 / 1540] 	 9.55% 	 error: 0
# 다음 기사 전 0.8초 대기
# [148 / 1540] 	 9.61% 	 error: 0
# 다음 기사 전 0.4초 대기
# [149 / 1540] 	 9.68% 	 error: 0
# 다음 기사 전 0.6초 대기
# [150 / 1540] 	 9.74% 	 error: 0
# 다음 기사 전 0.8초 대기
# [151 / 1540] 	 9.81% 	 error: 0
# 다음 기사 전 0.8초 대기
# [152 / 1540] 	 9.87% 	 error: 0
# 다음 기사 전 1.2초 대기
# [153 / 1540] 	 9.94% 	 error: 0
# 다음 기사 전 1.1초 대기
# [154 / 1540] 	 10.00% 	 error: 0
# 다음 기사 전 1.0초 대기
# [155 / 1540] 	 10.06% 	 error: 0
# 다음 기사 전 1.1초 대기
# [156 / 1540] 	 10.13% 	 error: 0
# 다음 기사 전 0.4초 대기
# [157 / 1540] 	 10.19% 	 error: 0
# 다음 기사 전 0.7초 대기
# [158 / 1540] 	 10.26% 	 error: 0
# 다음 기사 전 1.1초 대기
# [159 / 1540] 	 10.32% 	 error: 0
# 다음 기사 전 0.5초 대기
# [160 / 1540] 	 10.39% 	 error: 0
# 다음 기사 전 0.6초 대기
# [161 / 1540] 	 10.45% 	 error: 0
# 다음 기사 전 0.6초 대기
# [162 / 1540] 	 10.52% 	 error: 0
# 다음 기사 전 1.2초 대기
# [163 / 1540] 	 10.58% 	 error: 0
# 다음 기사 전 0.7초 대기
# [164 / 1540] 	 10.65% 	 error: 0
# 다음 기사 전 0.7초 대기
# [165 / 1540] 	 10.71% 	 error: 0
# 다음 기사 전 0.9초 대기
# [166 / 1540] 	 10.78% 	 error: 0
# 다음 기사 전 0.8초 대기
# [167 / 1540] 	 10.84% 	 error: 0
# 다음 기사 전 0.7초 대기
# [168 / 1540] 	 10.91% 	 error: 0
# 다음 기사 전 1.0초 대기
# [169 / 1540] 	 10.97% 	 error: 0
# 다음 기사 전 1.2초 대기
# [170 / 1540] 	 11.04% 	 error: 0
# 다음 기사 전 0.5초 대기
# [171 / 1540] 	 11.10% 	 error: 0
# 다음 기사 전 0.5초 대기
# [172 / 1540] 	 11.17% 	 error: 0
# 다음 기사 전 0.4초 대기
# [173 / 1540] 	 11.23% 	 error: 0
# 다음 기사 전 0.9초 대기
# [174 / 1540] 	 11.30% 	 error: 0
# 다음 기사 전 1.0초 대기
# [175 / 1540] 	 11.36% 	 error: 0
# 다음 기사 전 0.6초 대기
# [176 / 1540] 	 11.43% 	 error: 0
# 다음 기사 전 0.8초 대기
# [177 / 1540] 	 11.49% 	 error: 0
# 다음 기사 전 1.0초 대기
# [178 / 1540] 	 11.56% 	 error: 0
# 다음 기사 전 1.1초 대기
# [179 / 1540] 	 11.62% 	 error: 0
# 다음 기사 전 0.4초 대기
# [180 / 1540] 	 11.69% 	 error: 0
# 다음 기사 전 0.6초 대기
# [181 / 1540] 	 11.75% 	 error: 0
# 다음 기사 전 0.7초 대기
# [182 / 1540] 	 11.82% 	 error: 0
# 다음 기사 전 0.9초 대기
# [183 / 1540] 	 11.88% 	 error: 0
# 다음 기사 전 0.4초 대기
# [184 / 1540] 	 11.95% 	 error: 0
# 다음 기사 전 0.6초 대기
# [185 / 1540] 	 12.01% 	 error: 0
# 다음 기사 전 1.0초 대기
# [186 / 1540] 	 12.08% 	 error: 0
# 다음 기사 전 0.9초 대기
# [187 / 1540] 	 12.14% 	 error: 0
# 다음 기사 전 0.6초 대기
# [188 / 1540] 	 12.21% 	 error: 0
# 다음 기사 전 1.0초 대기
# [189 / 1540] 	 12.27% 	 error: 0
# 다음 기사 전 0.5초 대기
# [190 / 1540] 	 12.34% 	 error: 0
# 다음 기사 전 0.4초 대기
# [191 / 1540] 	 12.40% 	 error: 0
# 다음 기사 전 0.9초 대기
# [192 / 1540] 	 12.47% 	 error: 0
# 다음 기사 전 0.9초 대기
# [193 / 1540] 	 12.53% 	 error: 0
# 다음 기사 전 1.1초 대기
# [194 / 1540] 	 12.60% 	 error: 0
# 다음 기사 전 0.6초 대기
# [195 / 1540] 	 12.66% 	 error: 0
# 다음 기사 전 0.5초 대기
# [196 / 1540] 	 12.73% 	 error: 0
# 다음 기사 전 0.4초 대기
# [197 / 1540] 	 12.79% 	 error: 0
# 다음 기사 전 0.9초 대기
# [198 / 1540] 	 12.86% 	 error: 0
# 다음 기사 전 0.5초 대기
# [199 / 1540] 	 12.92% 	 error: 0
# 다음 기사 전 0.8초 대기
# [200 / 1540] 	 12.99% 	 error: 0
# 체크포인트 저장 — 200건 완료
# 다음 기사 전 0.9초 대기
# [201 / 1540] 	 13.05% 	 error: 0
# 다음 기사 전 1.2초 대기
# [202 / 1540] 	 13.12% 	 error: 0
# 다음 기사 전 0.4초 대기
# [203 / 1540] 	 13.18% 	 error: 0
# 다음 기사 전 0.8초 대기
# [204 / 1540] 	 13.25% 	 error: 0
# 다음 기사 전 1.1초 대기
# [205 / 1540] 	 13.31% 	 error: 0
# 다음 기사 전 0.7초 대기
# [206 / 1540] 	 13.38% 	 error: 0
# 다음 기사 전 0.8초 대기
# [207 / 1540] 	 13.44% 	 error: 0
# 다음 기사 전 0.8초 대기
# [208 / 1540] 	 13.51% 	 error: 0
# 다음 기사 전 0.4초 대기
# [209 / 1540] 	 13.57% 	 error: 0
# 다음 기사 전 1.0초 대기
# [210 / 1540] 	 13.64% 	 error: 0
# 다음 기사 전 0.7초 대기
# [211 / 1540] 	 13.70% 	 error: 0
# 다음 기사 전 1.1초 대기
# [212 / 1540] 	 13.77% 	 error: 0
# 다음 기사 전 1.0초 대기
# [213 / 1540] 	 13.83% 	 error: 0
# 다음 기사 전 0.7초 대기
# [214 / 1540] 	 13.90% 	 error: 0
# 다음 기사 전 0.4초 대기
# [215 / 1540] 	 13.96% 	 error: 0
# 다음 기사 전 0.8초 대기
# [216 / 1540] 	 14.03% 	 error: 0
# 다음 기사 전 1.0초 대기
# [217 / 1540] 	 14.09% 	 error: 0
# 다음 기사 전 1.1초 대기
# [218 / 1540] 	 14.16% 	 error: 0
# 다음 기사 전 0.9초 대기
# [219 / 1540] 	 14.22% 	 error: 0
# 다음 기사 전 0.9초 대기
# [220 / 1540] 	 14.29% 	 error: 0
# 다음 기사 전 0.5초 대기
# [221 / 1540] 	 14.35% 	 error: 0
# 다음 기사 전 1.1초 대기
# [222 / 1540] 	 14.42% 	 error: 0
# 다음 기사 전 1.2초 대기
# [223 / 1540] 	 14.48% 	 error: 0
# 다음 기사 전 0.4초 대기
# [224 / 1540] 	 14.55% 	 error: 0
# 다음 기사 전 1.1초 대기
# [225 / 1540] 	 14.61% 	 error: 0
# 다음 기사 전 0.5초 대기
# [226 / 1540] 	 14.68% 	 error: 0
# 다음 기사 전 1.2초 대기
# [227 / 1540] 	 14.74% 	 error: 0
# 다음 기사 전 0.5초 대기
# [228 / 1540] 	 14.81% 	 error: 0
# 다음 기사 전 0.7초 대기
# [229 / 1540] 	 14.87% 	 error: 0
# 다음 기사 전 0.8초 대기
# [230 / 1540] 	 14.94% 	 error: 0
# 다음 기사 전 0.5초 대기
# [231 / 1540] 	 15.00% 	 error: 0
# 다음 기사 전 0.6초 대기
# [232 / 1540] 	 15.06% 	 error: 0
# 다음 기사 전 0.8초 대기
# [233 / 1540] 	 15.13% 	 error: 0
# 다음 기사 전 1.0초 대기
# [234 / 1540] 	 15.19% 	 error: 0
# 다음 기사 전 1.0초 대기
# [235 / 1540] 	 15.26% 	 error: 0
# 다음 기사 전 0.6초 대기
# [236 / 1540] 	 15.32% 	 error: 0
# 다음 기사 전 0.8초 대기
# [237 / 1540] 	 15.39% 	 error: 0
# 다음 기사 전 0.5초 대기
# [238 / 1540] 	 15.45% 	 error: 0
# 다음 기사 전 1.0초 대기
# [239 / 1540] 	 15.52% 	 error: 0
# 다음 기사 전 0.7초 대기
# [240 / 1540] 	 15.58% 	 error: 0
# 다음 기사 전 0.6초 대기
# [241 / 1540] 	 15.65% 	 error: 0
# 다음 기사 전 0.9초 대기
# [242 / 1540] 	 15.71% 	 error: 0
# 다음 기사 전 0.6초 대기
# [243 / 1540] 	 15.78% 	 error: 0
# 다음 기사 전 1.0초 대기
# [244 / 1540] 	 15.84% 	 error: 0
# 다음 기사 전 0.4초 대기
# [245 / 1540] 	 15.91% 	 error: 0
# 다음 기사 전 1.1초 대기
# [246 / 1540] 	 15.97% 	 error: 0
# 다음 기사 전 0.7초 대기
# [247 / 1540] 	 16.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [248 / 1540] 	 16.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [249 / 1540] 	 16.17% 	 error: 0
# 다음 기사 전 0.5초 대기
# [250 / 1540] 	 16.23% 	 error: 0
# 다음 기사 전 0.4초 대기
# [251 / 1540] 	 16.30% 	 error: 0
# 다음 기사 전 0.6초 대기
# [252 / 1540] 	 16.36% 	 error: 0
# 다음 기사 전 0.8초 대기
# [253 / 1540] 	 16.43% 	 error: 0
# 다음 기사 전 1.1초 대기
# [254 / 1540] 	 16.49% 	 error: 0
# 다음 기사 전 0.7초 대기
# [255 / 1540] 	 16.56% 	 error: 0
# 다음 기사 전 0.5초 대기
# [256 / 1540] 	 16.62% 	 error: 0
# 다음 기사 전 1.2초 대기
# [257 / 1540] 	 16.69% 	 error: 0
# 다음 기사 전 0.8초 대기
# [258 / 1540] 	 16.75% 	 error: 0
# 다음 기사 전 0.9초 대기
# [259 / 1540] 	 16.82% 	 error: 0
# 다음 기사 전 0.8초 대기
# [260 / 1540] 	 16.88% 	 error: 0
# 다음 기사 전 1.1초 대기
# [261 / 1540] 	 16.95% 	 error: 0
# 다음 기사 전 0.7초 대기
# [262 / 1540] 	 17.01% 	 error: 0
# 다음 기사 전 0.9초 대기
# [263 / 1540] 	 17.08% 	 error: 0
# 다음 기사 전 0.8초 대기
# [264 / 1540] 	 17.14% 	 error: 0
# 다음 기사 전 0.5초 대기
# [265 / 1540] 	 17.21% 	 error: 0
# 다음 기사 전 0.5초 대기
# [266 / 1540] 	 17.27% 	 error: 0
# 다음 기사 전 0.9초 대기
# [267 / 1540] 	 17.34% 	 error: 0
# 다음 기사 전 0.6초 대기
# [268 / 1540] 	 17.40% 	 error: 0
# 다음 기사 전 1.1초 대기
# [269 / 1540] 	 17.47% 	 error: 0
# 다음 기사 전 1.0초 대기
# [270 / 1540] 	 17.53% 	 error: 0
# 다음 기사 전 0.4초 대기
# [271 / 1540] 	 17.60% 	 error: 0
# 다음 기사 전 0.8초 대기
# [272 / 1540] 	 17.66% 	 error: 0
# 다음 기사 전 0.7초 대기
# [273 / 1540] 	 17.73% 	 error: 0
# 다음 기사 전 1.1초 대기
# [274 / 1540] 	 17.79% 	 error: 0
# 다음 기사 전 1.2초 대기
# [275 / 1540] 	 17.86% 	 error: 0
# 다음 기사 전 0.5초 대기
# [276 / 1540] 	 17.92% 	 error: 0
# 다음 기사 전 1.0초 대기
# [277 / 1540] 	 17.99% 	 error: 0
# 다음 기사 전 0.7초 대기
# [278 / 1540] 	 18.05% 	 error: 0
# 다음 기사 전 0.6초 대기
# [279 / 1540] 	 18.12% 	 error: 0
# 다음 기사 전 0.9초 대기
# [280 / 1540] 	 18.18% 	 error: 0
# 다음 기사 전 0.9초 대기
# [281 / 1540] 	 18.25% 	 error: 0
# 다음 기사 전 0.6초 대기
# [282 / 1540] 	 18.31% 	 error: 0
# 다음 기사 전 0.5초 대기
# [283 / 1540] 	 18.38% 	 error: 0
# 다음 기사 전 0.5초 대기
# [284 / 1540] 	 18.44% 	 error: 0
# 다음 기사 전 0.7초 대기
# [285 / 1540] 	 18.51% 	 error: 0
# 다음 기사 전 0.6초 대기
# [286 / 1540] 	 18.57% 	 error: 0
# 다음 기사 전 0.4초 대기
# [287 / 1540] 	 18.64% 	 error: 0
# 다음 기사 전 0.7초 대기
# [288 / 1540] 	 18.70% 	 error: 0
# 다음 기사 전 1.0초 대기
# [289 / 1540] 	 18.77% 	 error: 0
# 다음 기사 전 0.4초 대기
# [290 / 1540] 	 18.83% 	 error: 0
# 다음 기사 전 0.7초 대기
# [291 / 1540] 	 18.90% 	 error: 0
# 다음 기사 전 0.7초 대기
# [292 / 1540] 	 18.96% 	 error: 0
# 다음 기사 전 1.1초 대기
# [293 / 1540] 	 19.03% 	 error: 0
# 다음 기사 전 0.6초 대기
# [294 / 1540] 	 19.09% 	 error: 0
# 다음 기사 전 0.9초 대기
# [295 / 1540] 	 19.16% 	 error: 0
# 다음 기사 전 1.0초 대기
# [296 / 1540] 	 19.22% 	 error: 0
# 다음 기사 전 1.0초 대기
# [297 / 1540] 	 19.29% 	 error: 0
# 다음 기사 전 0.9초 대기
# [298 / 1540] 	 19.35% 	 error: 0
# 다음 기사 전 1.1초 대기
# [299 / 1540] 	 19.42% 	 error: 0
# 다음 기사 전 0.7초 대기
# [300 / 1540] 	 19.48% 	 error: 0
# 다음 기사 전 1.0초 대기
# [301 / 1540] 	 19.55% 	 error: 0
# 다음 기사 전 1.2초 대기
# [302 / 1540] 	 19.61% 	 error: 0
# 다음 기사 전 1.1초 대기
# [303 / 1540] 	 19.68% 	 error: 0
# 다음 기사 전 0.5초 대기
# [304 / 1540] 	 19.74% 	 error: 0
# 다음 기사 전 1.0초 대기
# [305 / 1540] 	 19.81% 	 error: 0
# 다음 기사 전 0.5초 대기
# [306 / 1540] 	 19.87% 	 error: 0
# 다음 기사 전 0.4초 대기
# [307 / 1540] 	 19.94% 	 error: 0
# 다음 기사 전 1.0초 대기
# [308 / 1540] 	 20.00% 	 error: 0
# 다음 기사 전 0.6초 대기
# [309 / 1540] 	 20.06% 	 error: 0
# 다음 기사 전 0.6초 대기
# [310 / 1540] 	 20.13% 	 error: 0
# 다음 기사 전 0.9초 대기
# [311 / 1540] 	 20.19% 	 error: 0
# 다음 기사 전 1.2초 대기
# [312 / 1540] 	 20.26% 	 error: 0
# 다음 기사 전 1.1초 대기
# [313 / 1540] 	 20.32% 	 error: 0
# 다음 기사 전 0.7초 대기
# [314 / 1540] 	 20.39% 	 error: 0
# 다음 기사 전 0.6초 대기
# [315 / 1540] 	 20.45% 	 error: 0
# 다음 기사 전 0.5초 대기
# [316 / 1540] 	 20.52% 	 error: 0
# 다음 기사 전 0.8초 대기
# [317 / 1540] 	 20.58% 	 error: 0
# 다음 기사 전 1.0초 대기
# [318 / 1540] 	 20.65% 	 error: 0
# 다음 기사 전 0.9초 대기
# [319 / 1540] 	 20.71% 	 error: 0
# 다음 기사 전 0.6초 대기
# [320 / 1540] 	 20.78% 	 error: 0
# 다음 기사 전 0.8초 대기
# [321 / 1540] 	 20.84% 	 error: 0
# 다음 기사 전 0.6초 대기
# [322 / 1540] 	 20.91% 	 error: 0
# 다음 기사 전 0.9초 대기
# [323 / 1540] 	 20.97% 	 error: 0
# 다음 기사 전 0.9초 대기
# [324 / 1540] 	 21.04% 	 error: 0
# 다음 기사 전 0.8초 대기
# [325 / 1540] 	 21.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [326 / 1540] 	 21.17% 	 error: 0
# 다음 기사 전 0.4초 대기
# [327 / 1540] 	 21.23% 	 error: 0
# 다음 기사 전 1.2초 대기
# [328 / 1540] 	 21.30% 	 error: 0
# 다음 기사 전 1.0초 대기
# [329 / 1540] 	 21.36% 	 error: 0
# 다음 기사 전 0.8초 대기
# [330 / 1540] 	 21.43% 	 error: 0
# 다음 기사 전 0.6초 대기
# [331 / 1540] 	 21.49% 	 error: 0
# 다음 기사 전 1.2초 대기
# [332 / 1540] 	 21.56% 	 error: 0
# 다음 기사 전 0.7초 대기
# [333 / 1540] 	 21.62% 	 error: 0
# 다음 기사 전 0.6초 대기
# [334 / 1540] 	 21.69% 	 error: 0
# 다음 기사 전 1.2초 대기
# [335 / 1540] 	 21.75% 	 error: 0
# 다음 기사 전 1.1초 대기
# [336 / 1540] 	 21.82% 	 error: 0
# 다음 기사 전 0.9초 대기
# [337 / 1540] 	 21.88% 	 error: 0
# 다음 기사 전 1.1초 대기
# [338 / 1540] 	 21.95% 	 error: 0
# 다음 기사 전 0.7초 대기
# [339 / 1540] 	 22.01% 	 error: 0
# 다음 기사 전 0.8초 대기
# [340 / 1540] 	 22.08% 	 error: 0
# 다음 기사 전 0.6초 대기
# [341 / 1540] 	 22.14% 	 error: 0
# 다음 기사 전 0.7초 대기
# [342 / 1540] 	 22.21% 	 error: 0
# 다음 기사 전 0.4초 대기
# [343 / 1540] 	 22.27% 	 error: 0
# 다음 기사 전 0.6초 대기
# [344 / 1540] 	 22.34% 	 error: 0
# 다음 기사 전 0.7초 대기
# [345 / 1540] 	 22.40% 	 error: 0
# 다음 기사 전 0.9초 대기
# [346 / 1540] 	 22.47% 	 error: 0
# 다음 기사 전 0.9초 대기
# [347 / 1540] 	 22.53% 	 error: 0
# 다음 기사 전 1.0초 대기
# [348 / 1540] 	 22.60% 	 error: 0
# 다음 기사 전 1.0초 대기
# [349 / 1540] 	 22.66% 	 error: 0
# 다음 기사 전 0.8초 대기
# [350 / 1540] 	 22.73% 	 error: 0
# 다음 기사 전 0.9초 대기
# [351 / 1540] 	 22.79% 	 error: 0
# 다음 기사 전 1.1초 대기
# [352 / 1540] 	 22.86% 	 error: 0
# 다음 기사 전 0.7초 대기
# [353 / 1540] 	 22.92% 	 error: 0
# 다음 기사 전 1.1초 대기
# [354 / 1540] 	 22.99% 	 error: 0
# 다음 기사 전 0.7초 대기
# [355 / 1540] 	 23.05% 	 error: 0
# 다음 기사 전 0.6초 대기
# [356 / 1540] 	 23.12% 	 error: 0
# 다음 기사 전 0.8초 대기
# [357 / 1540] 	 23.18% 	 error: 0
# 다음 기사 전 1.2초 대기
# [358 / 1540] 	 23.25% 	 error: 0
# 다음 기사 전 0.9초 대기
# [359 / 1540] 	 23.31% 	 error: 0
# 다음 기사 전 0.7초 대기
# [360 / 1540] 	 23.38% 	 error: 0
# 다음 기사 전 0.6초 대기
# [361 / 1540] 	 23.44% 	 error: 0
# 다음 기사 전 0.7초 대기
# [362 / 1540] 	 23.51% 	 error: 0
# 다음 기사 전 0.6초 대기
# [363 / 1540] 	 23.57% 	 error: 0
# 다음 기사 전 1.0초 대기
# [364 / 1540] 	 23.64% 	 error: 0
# 다음 기사 전 1.1초 대기
# [365 / 1540] 	 23.70% 	 error: 0
# 다음 기사 전 0.9초 대기
# [366 / 1540] 	 23.77% 	 error: 0
# 다음 기사 전 0.6초 대기
# [367 / 1540] 	 23.83% 	 error: 0
# 다음 기사 전 0.9초 대기
# [368 / 1540] 	 23.90% 	 error: 0
# 다음 기사 전 0.6초 대기
# [369 / 1540] 	 23.96% 	 error: 0
# 다음 기사 전 1.0초 대기
# [370 / 1540] 	 24.03% 	 error: 0
# 다음 기사 전 0.9초 대기
# [371 / 1540] 	 24.09% 	 error: 0
# 다음 기사 전 0.9초 대기
# [372 / 1540] 	 24.16% 	 error: 0
# 다음 기사 전 0.7초 대기
# [373 / 1540] 	 24.22% 	 error: 0
# 다음 기사 전 1.1초 대기
# [374 / 1540] 	 24.29% 	 error: 0
# 다음 기사 전 0.9초 대기
# [375 / 1540] 	 24.35% 	 error: 0
# 다음 기사 전 0.5초 대기
# [376 / 1540] 	 24.42% 	 error: 0
# 다음 기사 전 0.6초 대기
# [377 / 1540] 	 24.48% 	 error: 0
# 다음 기사 전 0.9초 대기
# [378 / 1540] 	 24.55% 	 error: 0
# 다음 기사 전 0.6초 대기
# [379 / 1540] 	 24.61% 	 error: 0
# 다음 기사 전 0.7초 대기
# [380 / 1540] 	 24.68% 	 error: 0
# 다음 기사 전 0.5초 대기
# [381 / 1540] 	 24.74% 	 error: 0
# 다음 기사 전 1.1초 대기
# [382 / 1540] 	 24.81% 	 error: 0
# 다음 기사 전 0.9초 대기
# [383 / 1540] 	 24.87% 	 error: 0
# 다음 기사 전 1.1초 대기
# [384 / 1540] 	 24.94% 	 error: 0
# 다음 기사 전 1.1초 대기
# [385 / 1540] 	 25.00% 	 error: 0
# 다음 기사 전 1.1초 대기
# [386 / 1540] 	 25.06% 	 error: 0
# 다음 기사 전 1.0초 대기
# [387 / 1540] 	 25.13% 	 error: 0
# 다음 기사 전 1.2초 대기
# [388 / 1540] 	 25.19% 	 error: 0
# 다음 기사 전 1.0초 대기
# [389 / 1540] 	 25.26% 	 error: 0
# 다음 기사 전 0.6초 대기
# [390 / 1540] 	 25.32% 	 error: 0
# 다음 기사 전 0.8초 대기
# [391 / 1540] 	 25.39% 	 error: 0
# 다음 기사 전 0.8초 대기
# [392 / 1540] 	 25.45% 	 error: 0
# 다음 기사 전 0.4초 대기
# [393 / 1540] 	 25.52% 	 error: 0
# 다음 기사 전 0.5초 대기
# [394 / 1540] 	 25.58% 	 error: 0
# 다음 기사 전 1.0초 대기
# [395 / 1540] 	 25.65% 	 error: 0
# 다음 기사 전 0.7초 대기
# [396 / 1540] 	 25.71% 	 error: 0
# 다음 기사 전 0.8초 대기
# [397 / 1540] 	 25.78% 	 error: 0
# 다음 기사 전 1.2초 대기
# [398 / 1540] 	 25.84% 	 error: 0
# 다음 기사 전 0.8초 대기
# [399 / 1540] 	 25.91% 	 error: 0
# 다음 기사 전 1.1초 대기
# [400 / 1540] 	 25.97% 	 error: 0
# 체크포인트 저장 — 400건 완료
# 다음 기사 전 0.5초 대기
# [401 / 1540] 	 26.04% 	 error: 0
# 다음 기사 전 0.6초 대기
# [402 / 1540] 	 26.10% 	 error: 0
# 다음 기사 전 1.2초 대기
# [403 / 1540] 	 26.17% 	 error: 0
# 다음 기사 전 0.5초 대기
# [404 / 1540] 	 26.23% 	 error: 0
# 다음 기사 전 0.7초 대기
# [405 / 1540] 	 26.30% 	 error: 0
# 다음 기사 전 1.1초 대기
# [406 / 1540] 	 26.36% 	 error: 0
# 다음 기사 전 1.0초 대기
# [407 / 1540] 	 26.43% 	 error: 0
# 다음 기사 전 1.2초 대기
# [408 / 1540] 	 26.49% 	 error: 0
# 다음 기사 전 0.6초 대기
# [409 / 1540] 	 26.56% 	 error: 0
# 다음 기사 전 0.9초 대기
# [410 / 1540] 	 26.62% 	 error: 0
# 다음 기사 전 0.4초 대기
# [411 / 1540] 	 26.69% 	 error: 0
# 다음 기사 전 0.5초 대기
# [412 / 1540] 	 26.75% 	 error: 0
# 다음 기사 전 0.9초 대기
# [413 / 1540] 	 26.82% 	 error: 0
# 다음 기사 전 1.1초 대기
# [414 / 1540] 	 26.88% 	 error: 0
# 다음 기사 전 1.0초 대기
# [415 / 1540] 	 26.95% 	 error: 0
# 다음 기사 전 1.0초 대기
# [416 / 1540] 	 27.01% 	 error: 0
# 다음 기사 전 0.4초 대기
# [417 / 1540] 	 27.08% 	 error: 0
# 다음 기사 전 0.9초 대기
# [418 / 1540] 	 27.14% 	 error: 0
# 다음 기사 전 0.9초 대기
# [419 / 1540] 	 27.21% 	 error: 0
# 다음 기사 전 0.9초 대기
# [420 / 1540] 	 27.27% 	 error: 0
# 다음 기사 전 0.4초 대기
# [421 / 1540] 	 27.34% 	 error: 0
# 다음 기사 전 1.0초 대기
# [422 / 1540] 	 27.40% 	 error: 0
# 다음 기사 전 1.0초 대기
# [423 / 1540] 	 27.47% 	 error: 0
# 다음 기사 전 0.7초 대기
# [424 / 1540] 	 27.53% 	 error: 0
# 다음 기사 전 0.4초 대기
# [425 / 1540] 	 27.60% 	 error: 0
# 다음 기사 전 1.1초 대기
# [426 / 1540] 	 27.66% 	 error: 0
# 다음 기사 전 0.4초 대기
# [427 / 1540] 	 27.73% 	 error: 0
# 다음 기사 전 0.9초 대기
# [428 / 1540] 	 27.79% 	 error: 0
# 다음 기사 전 0.9초 대기
# [429 / 1540] 	 27.86% 	 error: 0
# 다음 기사 전 0.8초 대기
# [430 / 1540] 	 27.92% 	 error: 0
# 다음 기사 전 0.6초 대기
# [431 / 1540] 	 27.99% 	 error: 0
# 다음 기사 전 1.1초 대기
# [432 / 1540] 	 28.05% 	 error: 0
# 다음 기사 전 1.1초 대기
# [433 / 1540] 	 28.12% 	 error: 0
# 다음 기사 전 0.7초 대기
# [434 / 1540] 	 28.18% 	 error: 0
# 다음 기사 전 1.2초 대기
# [435 / 1540] 	 28.25% 	 error: 0
# 다음 기사 전 0.8초 대기
# [436 / 1540] 	 28.31% 	 error: 0
# 다음 기사 전 0.5초 대기
# [437 / 1540] 	 28.38% 	 error: 0
# 다음 기사 전 0.6초 대기
# [438 / 1540] 	 28.44% 	 error: 0
# 다음 기사 전 0.8초 대기
# [439 / 1540] 	 28.51% 	 error: 0
# 다음 기사 전 1.2초 대기
# [440 / 1540] 	 28.57% 	 error: 0
# 다음 기사 전 0.6초 대기
# [441 / 1540] 	 28.64% 	 error: 0
# 다음 기사 전 0.8초 대기
# [442 / 1540] 	 28.70% 	 error: 0
# 다음 기사 전 0.5초 대기
# [443 / 1540] 	 28.77% 	 error: 0
# 다음 기사 전 0.8초 대기
# [444 / 1540] 	 28.83% 	 error: 0
# 다음 기사 전 0.4초 대기
# [445 / 1540] 	 28.90% 	 error: 0
# 다음 기사 전 1.1초 대기
# [446 / 1540] 	 28.96% 	 error: 0
# 다음 기사 전 0.6초 대기
# [447 / 1540] 	 29.03% 	 error: 0
# 다음 기사 전 0.5초 대기
# [448 / 1540] 	 29.09% 	 error: 0
# 다음 기사 전 0.6초 대기
# [449 / 1540] 	 29.16% 	 error: 0
# 다음 기사 전 1.1초 대기
# [450 / 1540] 	 29.22% 	 error: 0
# 다음 기사 전 0.8초 대기
# [451 / 1540] 	 29.29% 	 error: 0
# 다음 기사 전 0.5초 대기
# [452 / 1540] 	 29.35% 	 error: 0
# 다음 기사 전 0.8초 대기
# [453 / 1540] 	 29.42% 	 error: 0
# 다음 기사 전 0.9초 대기
# [454 / 1540] 	 29.48% 	 error: 0
# 다음 기사 전 0.8초 대기
# [455 / 1540] 	 29.55% 	 error: 0
# 다음 기사 전 0.8초 대기
# [456 / 1540] 	 29.61% 	 error: 0
# 다음 기사 전 1.1초 대기
# [457 / 1540] 	 29.68% 	 error: 0
# 다음 기사 전 0.5초 대기
# [458 / 1540] 	 29.74% 	 error: 0
# 다음 기사 전 0.5초 대기
# [459 / 1540] 	 29.81% 	 error: 0
# 다음 기사 전 1.0초 대기
# [460 / 1540] 	 29.87% 	 error: 0
# 다음 기사 전 0.6초 대기
# [461 / 1540] 	 29.94% 	 error: 0
# 다음 기사 전 0.5초 대기
# [462 / 1540] 	 30.00% 	 error: 0
# 다음 기사 전 1.1초 대기
# [463 / 1540] 	 30.06% 	 error: 0
# 다음 기사 전 0.5초 대기
# [464 / 1540] 	 30.13% 	 error: 0
# 다음 기사 전 0.8초 대기
# [465 / 1540] 	 30.19% 	 error: 0
# 다음 기사 전 1.1초 대기
# [466 / 1540] 	 30.26% 	 error: 0
# 다음 기사 전 0.6초 대기
# [467 / 1540] 	 30.32% 	 error: 0
# 다음 기사 전 0.7초 대기
# [468 / 1540] 	 30.39% 	 error: 0
# 다음 기사 전 0.8초 대기
# [469 / 1540] 	 30.45% 	 error: 0
# 다음 기사 전 0.7초 대기
# [470 / 1540] 	 30.52% 	 error: 0
# 다음 기사 전 0.5초 대기
# [471 / 1540] 	 30.58% 	 error: 0
# 다음 기사 전 1.2초 대기
# [472 / 1540] 	 30.65% 	 error: 0
# 다음 기사 전 1.0초 대기
# [473 / 1540] 	 30.71% 	 error: 0
# 다음 기사 전 1.0초 대기
# [474 / 1540] 	 30.78% 	 error: 0
# 다음 기사 전 0.5초 대기
# [475 / 1540] 	 30.84% 	 error: 0
# 다음 기사 전 0.8초 대기
# [476 / 1540] 	 30.91% 	 error: 0
# 다음 기사 전 0.7초 대기
# [477 / 1540] 	 30.97% 	 error: 0
# 다음 기사 전 1.0초 대기
# [478 / 1540] 	 31.04% 	 error: 0
# 다음 기사 전 0.9초 대기
# [479 / 1540] 	 31.10% 	 error: 0
# 다음 기사 전 1.2초 대기
# [480 / 1540] 	 31.17% 	 error: 0
# 다음 기사 전 0.9초 대기
# [481 / 1540] 	 31.23% 	 error: 0
# 다음 기사 전 0.9초 대기
# [482 / 1540] 	 31.30% 	 error: 0
# 다음 기사 전 0.9초 대기
# [483 / 1540] 	 31.36% 	 error: 0
# 다음 기사 전 0.6초 대기
# [484 / 1540] 	 31.43% 	 error: 0
# 다음 기사 전 0.7초 대기
# [485 / 1540] 	 31.49% 	 error: 0
# 다음 기사 전 0.6초 대기
# [486 / 1540] 	 31.56% 	 error: 0
# 다음 기사 전 0.7초 대기
# [487 / 1540] 	 31.62% 	 error: 0
# 다음 기사 전 1.1초 대기
# [488 / 1540] 	 31.69% 	 error: 0
# 다음 기사 전 0.6초 대기
# [489 / 1540] 	 31.75% 	 error: 0
# 다음 기사 전 0.9초 대기
# [490 / 1540] 	 31.82% 	 error: 0
# 다음 기사 전 0.9초 대기
# [491 / 1540] 	 31.88% 	 error: 0
# 다음 기사 전 0.6초 대기
# [492 / 1540] 	 31.95% 	 error: 0
# 다음 기사 전 0.7초 대기
# [493 / 1540] 	 32.01% 	 error: 0
# 다음 기사 전 0.7초 대기
# [494 / 1540] 	 32.08% 	 error: 0
# 다음 기사 전 0.7초 대기
# [495 / 1540] 	 32.14% 	 error: 0
# 다음 기사 전 0.4초 대기
# [496 / 1540] 	 32.21% 	 error: 0
# 다음 기사 전 0.7초 대기
# [497 / 1540] 	 32.27% 	 error: 0
# 다음 기사 전 1.2초 대기
# [498 / 1540] 	 32.34% 	 error: 0
# 다음 기사 전 1.1초 대기
# [499 / 1540] 	 32.40% 	 error: 0
# 다음 기사 전 0.9초 대기
# [500 / 1540] 	 32.47% 	 error: 0
# 다음 기사 전 0.7초 대기
# [501 / 1540] 	 32.53% 	 error: 0
# 다음 기사 전 0.5초 대기
# [502 / 1540] 	 32.60% 	 error: 0
# 다음 기사 전 1.1초 대기
# [503 / 1540] 	 32.66% 	 error: 0
# 다음 기사 전 0.9초 대기
# [504 / 1540] 	 32.73% 	 error: 0
# 다음 기사 전 0.4초 대기
# [505 / 1540] 	 32.79% 	 error: 0
# 다음 기사 전 0.8초 대기
# [506 / 1540] 	 32.86% 	 error: 0
# 다음 기사 전 0.4초 대기
# [507 / 1540] 	 32.92% 	 error: 0
# 다음 기사 전 0.9초 대기
# [508 / 1540] 	 32.99% 	 error: 0
# 다음 기사 전 0.8초 대기
# [509 / 1540] 	 33.05% 	 error: 0
# 다음 기사 전 0.8초 대기
# [510 / 1540] 	 33.12% 	 error: 0
# 다음 기사 전 0.6초 대기
# [511 / 1540] 	 33.18% 	 error: 0
# 다음 기사 전 0.9초 대기
# [512 / 1540] 	 33.25% 	 error: 0
# 다음 기사 전 0.8초 대기
# [513 / 1540] 	 33.31% 	 error: 0
# 다음 기사 전 0.4초 대기
# [514 / 1540] 	 33.38% 	 error: 0
# 다음 기사 전 1.2초 대기
# [515 / 1540] 	 33.44% 	 error: 0
# 다음 기사 전 0.8초 대기
# [516 / 1540] 	 33.51% 	 error: 0
# 다음 기사 전 0.5초 대기
# [517 / 1540] 	 33.57% 	 error: 0
# 다음 기사 전 0.6초 대기
# [518 / 1540] 	 33.64% 	 error: 0
# 다음 기사 전 1.0초 대기
# [519 / 1540] 	 33.70% 	 error: 0
# 다음 기사 전 0.6초 대기
# [520 / 1540] 	 33.77% 	 error: 0
# 다음 기사 전 1.0초 대기
# [521 / 1540] 	 33.83% 	 error: 0
# 다음 기사 전 0.7초 대기
# [522 / 1540] 	 33.90% 	 error: 0
# 다음 기사 전 0.4초 대기
# [523 / 1540] 	 33.96% 	 error: 0
# 다음 기사 전 0.7초 대기
# [524 / 1540] 	 34.03% 	 error: 0
# 다음 기사 전 0.5초 대기
# [525 / 1540] 	 34.09% 	 error: 0
# 다음 기사 전 0.7초 대기
# [526 / 1540] 	 34.16% 	 error: 0
# 다음 기사 전 1.1초 대기
# [527 / 1540] 	 34.22% 	 error: 0
# 다음 기사 전 0.5초 대기
# [528 / 1540] 	 34.29% 	 error: 0
# 다음 기사 전 1.2초 대기
# [529 / 1540] 	 34.35% 	 error: 0
# 다음 기사 전 1.0초 대기
# [530 / 1540] 	 34.42% 	 error: 0
# 다음 기사 전 0.9초 대기
# [531 / 1540] 	 34.48% 	 error: 0
# 다음 기사 전 0.9초 대기
# [532 / 1540] 	 34.55% 	 error: 0
# 다음 기사 전 1.1초 대기
# [533 / 1540] 	 34.61% 	 error: 0
# 다음 기사 전 0.6초 대기
# [534 / 1540] 	 34.68% 	 error: 0
# 다음 기사 전 0.8초 대기
# [535 / 1540] 	 34.74% 	 error: 0
# 다음 기사 전 1.1초 대기
# [536 / 1540] 	 34.81% 	 error: 0
# 다음 기사 전 1.1초 대기
# [537 / 1540] 	 34.87% 	 error: 0
# 다음 기사 전 0.6초 대기
# [538 / 1540] 	 34.94% 	 error: 0
# 다음 기사 전 0.9초 대기
# [539 / 1540] 	 35.00% 	 error: 0
# 다음 기사 전 0.8초 대기
# [540 / 1540] 	 35.06% 	 error: 0
# 다음 기사 전 0.8초 대기
# [541 / 1540] 	 35.13% 	 error: 0
# 다음 기사 전 0.7초 대기
# [542 / 1540] 	 35.19% 	 error: 0
# 다음 기사 전 0.4초 대기
# [543 / 1540] 	 35.26% 	 error: 0
# 다음 기사 전 0.5초 대기
# [544 / 1540] 	 35.32% 	 error: 0
# 다음 기사 전 0.5초 대기
# [545 / 1540] 	 35.39% 	 error: 0
# 다음 기사 전 0.6초 대기
# [546 / 1540] 	 35.45% 	 error: 0
# 다음 기사 전 1.2초 대기
# [547 / 1540] 	 35.52% 	 error: 0
# 다음 기사 전 0.6초 대기
# [548 / 1540] 	 35.58% 	 error: 0
# 다음 기사 전 0.9초 대기
# [549 / 1540] 	 35.65% 	 error: 0
# 다음 기사 전 0.8초 대기
# [550 / 1540] 	 35.71% 	 error: 0
# 다음 기사 전 0.9초 대기
# [551 / 1540] 	 35.78% 	 error: 0
# 다음 기사 전 1.0초 대기
# [552 / 1540] 	 35.84% 	 error: 0
# 다음 기사 전 0.7초 대기
# [553 / 1540] 	 35.91% 	 error: 0
# 다음 기사 전 0.6초 대기
# [554 / 1540] 	 35.97% 	 error: 0
# 다음 기사 전 0.5초 대기
# [555 / 1540] 	 36.04% 	 error: 0
# 다음 기사 전 1.0초 대기
# [556 / 1540] 	 36.10% 	 error: 0
# 다음 기사 전 1.1초 대기
# [557 / 1540] 	 36.17% 	 error: 0
# 다음 기사 전 0.4초 대기
# [558 / 1540] 	 36.23% 	 error: 0
# 다음 기사 전 0.8초 대기
# [559 / 1540] 	 36.30% 	 error: 0
# 다음 기사 전 1.0초 대기
# [560 / 1540] 	 36.36% 	 error: 0
# 다음 기사 전 0.5초 대기
# [561 / 1540] 	 36.43% 	 error: 0
# 다음 기사 전 0.5초 대기
# [562 / 1540] 	 36.49% 	 error: 0
# 다음 기사 전 0.7초 대기
# [563 / 1540] 	 36.56% 	 error: 0
# 다음 기사 전 0.5초 대기
# [564 / 1540] 	 36.62% 	 error: 0
# 다음 기사 전 0.9초 대기
# [565 / 1540] 	 36.69% 	 error: 0
# 다음 기사 전 0.8초 대기
# [566 / 1540] 	 36.75% 	 error: 0
# 다음 기사 전 0.6초 대기
# [567 / 1540] 	 36.82% 	 error: 0
# 다음 기사 전 0.5초 대기
# [568 / 1540] 	 36.88% 	 error: 0
# 다음 기사 전 1.1초 대기
# [569 / 1540] 	 36.95% 	 error: 0
# 다음 기사 전 0.6초 대기
# [570 / 1540] 	 37.01% 	 error: 0
# 다음 기사 전 1.2초 대기
# [571 / 1540] 	 37.08% 	 error: 0
# 다음 기사 전 0.8초 대기
# [572 / 1540] 	 37.14% 	 error: 0
# 다음 기사 전 0.7초 대기
# [573 / 1540] 	 37.21% 	 error: 0
# 다음 기사 전 1.2초 대기
# [574 / 1540] 	 37.27% 	 error: 0
# 다음 기사 전 0.9초 대기
# [575 / 1540] 	 37.34% 	 error: 0
# 다음 기사 전 0.9초 대기
# [576 / 1540] 	 37.40% 	 error: 0
# 다음 기사 전 0.5초 대기
# [577 / 1540] 	 37.47% 	 error: 0
# 다음 기사 전 1.1초 대기
# [578 / 1540] 	 37.53% 	 error: 0
# 다음 기사 전 0.6초 대기
# [579 / 1540] 	 37.60% 	 error: 0
# 다음 기사 전 0.8초 대기
# [580 / 1540] 	 37.66% 	 error: 0
# 다음 기사 전 0.5초 대기
# [581 / 1540] 	 37.73% 	 error: 0
# 다음 기사 전 1.0초 대기
# [582 / 1540] 	 37.79% 	 error: 0
# 다음 기사 전 0.6초 대기
# [583 / 1540] 	 37.86% 	 error: 0
# 다음 기사 전 0.7초 대기
# [584 / 1540] 	 37.92% 	 error: 0
# 다음 기사 전 1.2초 대기
# [585 / 1540] 	 37.99% 	 error: 0
# 다음 기사 전 0.5초 대기
# [586 / 1540] 	 38.05% 	 error: 0
# 다음 기사 전 0.7초 대기
# [587 / 1540] 	 38.12% 	 error: 0
# 다음 기사 전 1.1초 대기
# [588 / 1540] 	 38.18% 	 error: 0
# 다음 기사 전 0.4초 대기
# [589 / 1540] 	 38.25% 	 error: 0
# 다음 기사 전 0.4초 대기
# [590 / 1540] 	 38.31% 	 error: 0
# 다음 기사 전 0.8초 대기
# [591 / 1540] 	 38.38% 	 error: 0
# 다음 기사 전 1.1초 대기
# [592 / 1540] 	 38.44% 	 error: 0
# 다음 기사 전 1.0초 대기
# [593 / 1540] 	 38.51% 	 error: 0
# 다음 기사 전 0.9초 대기
# [594 / 1540] 	 38.57% 	 error: 0
# 다음 기사 전 1.1초 대기
# [595 / 1540] 	 38.64% 	 error: 0
# 다음 기사 전 0.9초 대기
# [596 / 1540] 	 38.70% 	 error: 0
# 다음 기사 전 0.6초 대기
# [597 / 1540] 	 38.77% 	 error: 0
# 다음 기사 전 0.9초 대기
# [598 / 1540] 	 38.83% 	 error: 0
# 다음 기사 전 1.2초 대기
# [599 / 1540] 	 38.90% 	 error: 0
# 다음 기사 전 1.1초 대기
# [600 / 1540] 	 38.96% 	 error: 0
# 체크포인트 저장 — 600건 완료
# 다음 기사 전 0.6초 대기
# [601 / 1540] 	 39.03% 	 error: 0
# 다음 기사 전 0.5초 대기
# [602 / 1540] 	 39.09% 	 error: 0
# 다음 기사 전 1.0초 대기
# [603 / 1540] 	 39.16% 	 error: 0
# 다음 기사 전 1.2초 대기
# [604 / 1540] 	 39.22% 	 error: 0
# 다음 기사 전 0.5초 대기
# [605 / 1540] 	 39.29% 	 error: 0
# 다음 기사 전 1.0초 대기
# [606 / 1540] 	 39.35% 	 error: 0
# 다음 기사 전 0.7초 대기
# [607 / 1540] 	 39.42% 	 error: 0
# 다음 기사 전 0.6초 대기
# [608 / 1540] 	 39.48% 	 error: 0
# 다음 기사 전 1.0초 대기
# [609 / 1540] 	 39.55% 	 error: 0
# 다음 기사 전 0.8초 대기
# [610 / 1540] 	 39.61% 	 error: 0
# 다음 기사 전 0.8초 대기
# [611 / 1540] 	 39.68% 	 error: 0
# 다음 기사 전 0.8초 대기
# [612 / 1540] 	 39.74% 	 error: 0
# 다음 기사 전 1.2초 대기
# [613 / 1540] 	 39.81% 	 error: 0
# 다음 기사 전 0.5초 대기
# [614 / 1540] 	 39.87% 	 error: 0
# 다음 기사 전 0.7초 대기
# [615 / 1540] 	 39.94% 	 error: 0
# 다음 기사 전 0.4초 대기
# [616 / 1540] 	 40.00% 	 error: 0
# 다음 기사 전 0.7초 대기
# [617 / 1540] 	 40.06% 	 error: 0
# 다음 기사 전 0.7초 대기
# [618 / 1540] 	 40.13% 	 error: 0
# 다음 기사 전 0.6초 대기
# [619 / 1540] 	 40.19% 	 error: 0
# 다음 기사 전 1.1초 대기
# [620 / 1540] 	 40.26% 	 error: 0
# 다음 기사 전 0.5초 대기
# [621 / 1540] 	 40.32% 	 error: 0
# 다음 기사 전 0.8초 대기
# [622 / 1540] 	 40.39% 	 error: 0
# 다음 기사 전 0.7초 대기
# [623 / 1540] 	 40.45% 	 error: 0
# 다음 기사 전 0.6초 대기
# [624 / 1540] 	 40.52% 	 error: 0
# 다음 기사 전 0.4초 대기
# [625 / 1540] 	 40.58% 	 error: 0
# 다음 기사 전 0.6초 대기
# [626 / 1540] 	 40.65% 	 error: 0
# 다음 기사 전 0.4초 대기
# [627 / 1540] 	 40.71% 	 error: 0
# 다음 기사 전 0.4초 대기
# [628 / 1540] 	 40.78% 	 error: 0
# 다음 기사 전 0.9초 대기
# [629 / 1540] 	 40.84% 	 error: 0
# 다음 기사 전 0.6초 대기
# [630 / 1540] 	 40.91% 	 error: 0
# 다음 기사 전 1.0초 대기
# [631 / 1540] 	 40.97% 	 error: 0
# 다음 기사 전 0.4초 대기
# [632 / 1540] 	 41.04% 	 error: 0
# 다음 기사 전 0.5초 대기
# [633 / 1540] 	 41.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [634 / 1540] 	 41.17% 	 error: 0
# 다음 기사 전 0.8초 대기
# [635 / 1540] 	 41.23% 	 error: 0
# 다음 기사 전 1.0초 대기
# [636 / 1540] 	 41.30% 	 error: 0
# 다음 기사 전 1.1초 대기
# [637 / 1540] 	 41.36% 	 error: 0
# 다음 기사 전 0.8초 대기
# [638 / 1540] 	 41.43% 	 error: 0
# 다음 기사 전 1.0초 대기
# [639 / 1540] 	 41.49% 	 error: 0
# 다음 기사 전 0.7초 대기
# [640 / 1540] 	 41.56% 	 error: 0
# 다음 기사 전 0.5초 대기
# [641 / 1540] 	 41.62% 	 error: 0
# 다음 기사 전 0.8초 대기
# [642 / 1540] 	 41.69% 	 error: 0
# 다음 기사 전 0.9초 대기
# [643 / 1540] 	 41.75% 	 error: 0
# 다음 기사 전 0.4초 대기
# [644 / 1540] 	 41.82% 	 error: 0
# 다음 기사 전 0.9초 대기
# [645 / 1540] 	 41.88% 	 error: 0
# 다음 기사 전 1.0초 대기
# [646 / 1540] 	 41.95% 	 error: 0
# 다음 기사 전 0.9초 대기
# [647 / 1540] 	 42.01% 	 error: 0
# 다음 기사 전 0.9초 대기
# [648 / 1540] 	 42.08% 	 error: 0
# 다음 기사 전 0.9초 대기
# [649 / 1540] 	 42.14% 	 error: 0
# 다음 기사 전 0.5초 대기
# [650 / 1540] 	 42.21% 	 error: 0
# 다음 기사 전 0.6초 대기
# [651 / 1540] 	 42.27% 	 error: 0
# 다음 기사 전 0.9초 대기
# [652 / 1540] 	 42.34% 	 error: 0
# 다음 기사 전 1.1초 대기
# [653 / 1540] 	 42.40% 	 error: 0
# 다음 기사 전 1.1초 대기
# [654 / 1540] 	 42.47% 	 error: 0
# 다음 기사 전 0.8초 대기
# [655 / 1540] 	 42.53% 	 error: 0
# 다음 기사 전 0.8초 대기
# [656 / 1540] 	 42.60% 	 error: 0
# 다음 기사 전 1.0초 대기
# [657 / 1540] 	 42.66% 	 error: 0
# 다음 기사 전 0.4초 대기
# [658 / 1540] 	 42.73% 	 error: 0
# 다음 기사 전 0.6초 대기
# [659 / 1540] 	 42.79% 	 error: 0
# 다음 기사 전 0.7초 대기
# [660 / 1540] 	 42.86% 	 error: 0
# 다음 기사 전 1.1초 대기
# [661 / 1540] 	 42.92% 	 error: 0
# 다음 기사 전 0.5초 대기
# [662 / 1540] 	 42.99% 	 error: 0
# 다음 기사 전 1.1초 대기
# [663 / 1540] 	 43.05% 	 error: 0
# 다음 기사 전 1.0초 대기
# [664 / 1540] 	 43.12% 	 error: 0
# 다음 기사 전 1.1초 대기
# [665 / 1540] 	 43.18% 	 error: 0
# 다음 기사 전 0.8초 대기
# [666 / 1540] 	 43.25% 	 error: 0
# 다음 기사 전 0.5초 대기
# [667 / 1540] 	 43.31% 	 error: 0
# 다음 기사 전 1.1초 대기
# [668 / 1540] 	 43.38% 	 error: 0
# 다음 기사 전 0.5초 대기
# [669 / 1540] 	 43.44% 	 error: 0
# 다음 기사 전 0.6초 대기
# [670 / 1540] 	 43.51% 	 error: 0
# 다음 기사 전 1.0초 대기
# [671 / 1540] 	 43.57% 	 error: 0
# 다음 기사 전 0.8초 대기
# [672 / 1540] 	 43.64% 	 error: 0
# 다음 기사 전 1.1초 대기
# [673 / 1540] 	 43.70% 	 error: 0
# 다음 기사 전 0.9초 대기
# [674 / 1540] 	 43.77% 	 error: 0
# 다음 기사 전 0.5초 대기
# [675 / 1540] 	 43.83% 	 error: 0
# 다음 기사 전 0.9초 대기
# [676 / 1540] 	 43.90% 	 error: 0
# 다음 기사 전 0.4초 대기
# [677 / 1540] 	 43.96% 	 error: 0
# 다음 기사 전 1.1초 대기
# [678 / 1540] 	 44.03% 	 error: 0
# 다음 기사 전 0.6초 대기
# [679 / 1540] 	 44.09% 	 error: 0
# 다음 기사 전 0.5초 대기
# [680 / 1540] 	 44.16% 	 error: 0
# 다음 기사 전 0.6초 대기
# [681 / 1540] 	 44.22% 	 error: 0
# 다음 기사 전 0.9초 대기
# [682 / 1540] 	 44.29% 	 error: 0
# 다음 기사 전 1.0초 대기
# [683 / 1540] 	 44.35% 	 error: 0
# 다음 기사 전 0.8초 대기
# [684 / 1540] 	 44.42% 	 error: 0
# 다음 기사 전 0.5초 대기
# [685 / 1540] 	 44.48% 	 error: 0
# 다음 기사 전 0.9초 대기
# [686 / 1540] 	 44.55% 	 error: 0
# 다음 기사 전 0.7초 대기
# [687 / 1540] 	 44.61% 	 error: 0
# 다음 기사 전 0.4초 대기
# [688 / 1540] 	 44.68% 	 error: 0
# 다음 기사 전 1.0초 대기
# [689 / 1540] 	 44.74% 	 error: 0
# 다음 기사 전 0.6초 대기
# [690 / 1540] 	 44.81% 	 error: 0
# 다음 기사 전 0.8초 대기
# [691 / 1540] 	 44.87% 	 error: 0
# 다음 기사 전 1.1초 대기
# [692 / 1540] 	 44.94% 	 error: 0
# 다음 기사 전 1.1초 대기
# [693 / 1540] 	 45.00% 	 error: 0
# 다음 기사 전 1.2초 대기
# [694 / 1540] 	 45.06% 	 error: 0
# 다음 기사 전 0.6초 대기
# [695 / 1540] 	 45.13% 	 error: 0
# 다음 기사 전 1.0초 대기
# [696 / 1540] 	 45.19% 	 error: 0
# 다음 기사 전 0.7초 대기
# [697 / 1540] 	 45.26% 	 error: 0
# 다음 기사 전 0.5초 대기
# [698 / 1540] 	 45.32% 	 error: 0
# 다음 기사 전 0.7초 대기
# [699 / 1540] 	 45.39% 	 error: 0
# 다음 기사 전 1.2초 대기
# [700 / 1540] 	 45.45% 	 error: 0
# 다음 기사 전 0.5초 대기
# [701 / 1540] 	 45.52% 	 error: 0
# 다음 기사 전 0.6초 대기
# [702 / 1540] 	 45.58% 	 error: 0
# 다음 기사 전 0.9초 대기
# [703 / 1540] 	 45.65% 	 error: 0
# 다음 기사 전 0.8초 대기
# [704 / 1540] 	 45.71% 	 error: 0
# 다음 기사 전 0.6초 대기
# [705 / 1540] 	 45.78% 	 error: 0
# 다음 기사 전 0.4초 대기
# [706 / 1540] 	 45.84% 	 error: 0
# 다음 기사 전 0.6초 대기
# [707 / 1540] 	 45.91% 	 error: 0
# 다음 기사 전 1.1초 대기
# [708 / 1540] 	 45.97% 	 error: 0
# 다음 기사 전 0.5초 대기
# [709 / 1540] 	 46.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [710 / 1540] 	 46.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [711 / 1540] 	 46.17% 	 error: 0
# 다음 기사 전 1.0초 대기
# [712 / 1540] 	 46.23% 	 error: 0
# 다음 기사 전 0.7초 대기
# [713 / 1540] 	 46.30% 	 error: 0
# 다음 기사 전 1.2초 대기
# [714 / 1540] 	 46.36% 	 error: 0
# 다음 기사 전 0.9초 대기
# [715 / 1540] 	 46.43% 	 error: 0
# 다음 기사 전 1.1초 대기
# [716 / 1540] 	 46.49% 	 error: 0
# 다음 기사 전 1.1초 대기
# [717 / 1540] 	 46.56% 	 error: 0
# 다음 기사 전 0.8초 대기
# [718 / 1540] 	 46.62% 	 error: 0
# 다음 기사 전 0.8초 대기
# [719 / 1540] 	 46.69% 	 error: 0
# 다음 기사 전 0.5초 대기
# [720 / 1540] 	 46.75% 	 error: 0
# 다음 기사 전 0.4초 대기
# [721 / 1540] 	 46.82% 	 error: 0
# 다음 기사 전 1.0초 대기
# [722 / 1540] 	 46.88% 	 error: 0
# 다음 기사 전 0.5초 대기
# [723 / 1540] 	 46.95% 	 error: 0
# 다음 기사 전 1.2초 대기
# [724 / 1540] 	 47.01% 	 error: 0
# 다음 기사 전 1.0초 대기
# [725 / 1540] 	 47.08% 	 error: 0
# 다음 기사 전 1.1초 대기
# [726 / 1540] 	 47.14% 	 error: 0
# 다음 기사 전 0.8초 대기
# [727 / 1540] 	 47.21% 	 error: 0
# 다음 기사 전 1.1초 대기
# [728 / 1540] 	 47.27% 	 error: 0
# 다음 기사 전 1.2초 대기
# [729 / 1540] 	 47.34% 	 error: 0
# 다음 기사 전 1.1초 대기
# [730 / 1540] 	 47.40% 	 error: 0
# 다음 기사 전 0.6초 대기
# [731 / 1540] 	 47.47% 	 error: 0
# 다음 기사 전 0.8초 대기
# [732 / 1540] 	 47.53% 	 error: 0
# 다음 기사 전 1.2초 대기
# [733 / 1540] 	 47.60% 	 error: 0
# 다음 기사 전 0.7초 대기
# [734 / 1540] 	 47.66% 	 error: 0
# 다음 기사 전 1.0초 대기
# [735 / 1540] 	 47.73% 	 error: 0
# 다음 기사 전 0.5초 대기
# [736 / 1540] 	 47.79% 	 error: 0
# 다음 기사 전 0.4초 대기
# [737 / 1540] 	 47.86% 	 error: 0
# 다음 기사 전 0.8초 대기
# [738 / 1540] 	 47.92% 	 error: 0
# 다음 기사 전 0.6초 대기
# [739 / 1540] 	 47.99% 	 error: 0
# 다음 기사 전 1.2초 대기
# [740 / 1540] 	 48.05% 	 error: 0
# 다음 기사 전 1.1초 대기
# [741 / 1540] 	 48.12% 	 error: 0
# 다음 기사 전 1.0초 대기
# [742 / 1540] 	 48.18% 	 error: 0
# 다음 기사 전 0.5초 대기
# [743 / 1540] 	 48.25% 	 error: 0
# 다음 기사 전 1.1초 대기
# [744 / 1540] 	 48.31% 	 error: 0
# 다음 기사 전 0.6초 대기
# [745 / 1540] 	 48.38% 	 error: 0
# 다음 기사 전 0.7초 대기
# [746 / 1540] 	 48.44% 	 error: 0
# 다음 기사 전 1.0초 대기
# [747 / 1540] 	 48.51% 	 error: 0
# 다음 기사 전 0.9초 대기
# [748 / 1540] 	 48.57% 	 error: 0
# 다음 기사 전 1.2초 대기
# [749 / 1540] 	 48.64% 	 error: 0
# 다음 기사 전 0.6초 대기
# [750 / 1540] 	 48.70% 	 error: 0
# 다음 기사 전 0.7초 대기
# [751 / 1540] 	 48.77% 	 error: 0
# 다음 기사 전 0.6초 대기
# [752 / 1540] 	 48.83% 	 error: 0
# 다음 기사 전 1.1초 대기
# [753 / 1540] 	 48.90% 	 error: 0
# 다음 기사 전 0.5초 대기
# [754 / 1540] 	 48.96% 	 error: 0
# 다음 기사 전 0.7초 대기
# [755 / 1540] 	 49.03% 	 error: 0
# 다음 기사 전 0.4초 대기
# [756 / 1540] 	 49.09% 	 error: 0
# 다음 기사 전 1.0초 대기
# [757 / 1540] 	 49.16% 	 error: 0
# 다음 기사 전 0.9초 대기
# [758 / 1540] 	 49.22% 	 error: 0
# 다음 기사 전 1.0초 대기
# [759 / 1540] 	 49.29% 	 error: 0
# 다음 기사 전 1.0초 대기
# [760 / 1540] 	 49.35% 	 error: 0
# 다음 기사 전 0.9초 대기
# [761 / 1540] 	 49.42% 	 error: 0
# 다음 기사 전 0.7초 대기
# [762 / 1540] 	 49.48% 	 error: 0
# 다음 기사 전 0.9초 대기
# [763 / 1540] 	 49.55% 	 error: 0
# 다음 기사 전 0.6초 대기
# [764 / 1540] 	 49.61% 	 error: 0
# 다음 기사 전 1.1초 대기
# [765 / 1540] 	 49.68% 	 error: 0
# 다음 기사 전 0.9초 대기
# [766 / 1540] 	 49.74% 	 error: 0
# 다음 기사 전 0.7초 대기
# [767 / 1540] 	 49.81% 	 error: 0
# 다음 기사 전 0.7초 대기
# [768 / 1540] 	 49.87% 	 error: 0
# 다음 기사 전 1.1초 대기
# [769 / 1540] 	 49.94% 	 error: 0
# 다음 기사 전 1.2초 대기
# [770 / 1540] 	 50.00% 	 error: 0
# 다음 기사 전 0.5초 대기
# [771 / 1540] 	 50.06% 	 error: 0
# 다음 기사 전 0.6초 대기
# [772 / 1540] 	 50.13% 	 error: 0
# 다음 기사 전 0.8초 대기
# [773 / 1540] 	 50.19% 	 error: 0
# 다음 기사 전 0.8초 대기
# [774 / 1540] 	 50.26% 	 error: 0
# 다음 기사 전 0.4초 대기
# [775 / 1540] 	 50.32% 	 error: 0
# 다음 기사 전 0.7초 대기
# [776 / 1540] 	 50.39% 	 error: 0
# 다음 기사 전 0.6초 대기
# [777 / 1540] 	 50.45% 	 error: 0
# 다음 기사 전 1.0초 대기
# [778 / 1540] 	 50.52% 	 error: 0
# 다음 기사 전 1.0초 대기
# [779 / 1540] 	 50.58% 	 error: 0
# 다음 기사 전 0.9초 대기
# [780 / 1540] 	 50.65% 	 error: 0
# 다음 기사 전 0.7초 대기
# [781 / 1540] 	 50.71% 	 error: 0
# 다음 기사 전 1.2초 대기
# [782 / 1540] 	 50.78% 	 error: 0
# 다음 기사 전 1.2초 대기
# [783 / 1540] 	 50.84% 	 error: 0
# 다음 기사 전 0.8초 대기
# [784 / 1540] 	 50.91% 	 error: 0
# 다음 기사 전 0.8초 대기
# [785 / 1540] 	 50.97% 	 error: 0
# 다음 기사 전 0.5초 대기
# [786 / 1540] 	 51.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [787 / 1540] 	 51.10% 	 error: 0
# 다음 기사 전 1.2초 대기
# [788 / 1540] 	 51.17% 	 error: 0
# 다음 기사 전 0.5초 대기
# [789 / 1540] 	 51.23% 	 error: 0
# 다음 기사 전 0.9초 대기
# [790 / 1540] 	 51.30% 	 error: 0
# 다음 기사 전 0.6초 대기
# [791 / 1540] 	 51.36% 	 error: 0
# 다음 기사 전 1.2초 대기
# [792 / 1540] 	 51.43% 	 error: 0
# 다음 기사 전 1.2초 대기
# [793 / 1540] 	 51.49% 	 error: 0
# 다음 기사 전 1.0초 대기
# [794 / 1540] 	 51.56% 	 error: 0
# 다음 기사 전 1.0초 대기
# [795 / 1540] 	 51.62% 	 error: 0
# 다음 기사 전 0.9초 대기
# [796 / 1540] 	 51.69% 	 error: 0
# 다음 기사 전 0.5초 대기
# [797 / 1540] 	 51.75% 	 error: 0
# 다음 기사 전 0.8초 대기
# [798 / 1540] 	 51.82% 	 error: 0
# 다음 기사 전 0.6초 대기
# [799 / 1540] 	 51.88% 	 error: 0
# 다음 기사 전 0.4초 대기
# [800 / 1540] 	 51.95% 	 error: 0
# 체크포인트 저장 — 800건 완료
# 다음 기사 전 0.6초 대기
# [801 / 1540] 	 52.01% 	 error: 0
# 다음 기사 전 0.6초 대기
# [802 / 1540] 	 52.08% 	 error: 0
# 다음 기사 전 0.5초 대기
# [803 / 1540] 	 52.14% 	 error: 0
# 다음 기사 전 0.6초 대기
# [804 / 1540] 	 52.21% 	 error: 0
# 다음 기사 전 0.8초 대기
# [805 / 1540] 	 52.27% 	 error: 0
# 다음 기사 전 0.9초 대기
# [806 / 1540] 	 52.34% 	 error: 0
# 다음 기사 전 0.6초 대기
# [807 / 1540] 	 52.40% 	 error: 0
# 다음 기사 전 1.1초 대기
# [808 / 1540] 	 52.47% 	 error: 0
# 다음 기사 전 1.2초 대기
# [809 / 1540] 	 52.53% 	 error: 0
# 다음 기사 전 0.5초 대기
# [810 / 1540] 	 52.60% 	 error: 0
# 다음 기사 전 1.2초 대기
# [811 / 1540] 	 52.66% 	 error: 0
# 다음 기사 전 0.9초 대기
# [812 / 1540] 	 52.73% 	 error: 0
# 다음 기사 전 1.1초 대기
# [813 / 1540] 	 52.79% 	 error: 0
# 다음 기사 전 0.5초 대기
# [814 / 1540] 	 52.86% 	 error: 0
# 다음 기사 전 1.0초 대기
# [815 / 1540] 	 52.92% 	 error: 0
# 다음 기사 전 0.7초 대기
# [816 / 1540] 	 52.99% 	 error: 0
# 다음 기사 전 0.8초 대기
# [817 / 1540] 	 53.05% 	 error: 0
# 다음 기사 전 1.0초 대기
# [818 / 1540] 	 53.12% 	 error: 0
# 다음 기사 전 0.9초 대기
# [819 / 1540] 	 53.18% 	 error: 0
# 다음 기사 전 0.7초 대기
# [820 / 1540] 	 53.25% 	 error: 0
# 다음 기사 전 0.7초 대기
# [821 / 1540] 	 53.31% 	 error: 0
# 다음 기사 전 1.1초 대기
# [822 / 1540] 	 53.38% 	 error: 0
# 다음 기사 전 1.2초 대기
# [823 / 1540] 	 53.44% 	 error: 0
# 다음 기사 전 0.6초 대기
# [824 / 1540] 	 53.51% 	 error: 0
# 다음 기사 전 1.0초 대기
# [825 / 1540] 	 53.57% 	 error: 0
# 다음 기사 전 0.5초 대기
# [826 / 1540] 	 53.64% 	 error: 0
# 다음 기사 전 0.8초 대기
# [827 / 1540] 	 53.70% 	 error: 0
# 다음 기사 전 1.1초 대기
# [828 / 1540] 	 53.77% 	 error: 0
# 다음 기사 전 0.8초 대기
# [829 / 1540] 	 53.83% 	 error: 0
# 다음 기사 전 0.7초 대기
# [830 / 1540] 	 53.90% 	 error: 0
# 다음 기사 전 0.9초 대기
# [831 / 1540] 	 53.96% 	 error: 0
# 다음 기사 전 0.5초 대기
# [832 / 1540] 	 54.03% 	 error: 0
# 다음 기사 전 0.9초 대기
# [833 / 1540] 	 54.09% 	 error: 0
# 다음 기사 전 0.4초 대기
# [834 / 1540] 	 54.16% 	 error: 0
# 다음 기사 전 0.6초 대기
# [835 / 1540] 	 54.22% 	 error: 0
# 다음 기사 전 0.8초 대기
# [836 / 1540] 	 54.29% 	 error: 0
# 다음 기사 전 1.1초 대기
# [837 / 1540] 	 54.35% 	 error: 0
# 다음 기사 전 1.2초 대기
# [838 / 1540] 	 54.42% 	 error: 0
# 다음 기사 전 0.5초 대기
# [839 / 1540] 	 54.48% 	 error: 0
# 다음 기사 전 1.1초 대기
# [840 / 1540] 	 54.55% 	 error: 0
# 다음 기사 전 1.0초 대기
# [841 / 1540] 	 54.61% 	 error: 0
# 다음 기사 전 0.9초 대기
# [842 / 1540] 	 54.68% 	 error: 0
# 다음 기사 전 0.9초 대기
# [843 / 1540] 	 54.74% 	 error: 0
# 다음 기사 전 0.6초 대기
# [844 / 1540] 	 54.81% 	 error: 0
# 다음 기사 전 0.6초 대기
# [845 / 1540] 	 54.87% 	 error: 0
# 다음 기사 전 0.8초 대기
# [846 / 1540] 	 54.94% 	 error: 0
# 다음 기사 전 0.9초 대기
# [847 / 1540] 	 55.00% 	 error: 0
# 다음 기사 전 1.0초 대기
# [848 / 1540] 	 55.06% 	 error: 0
# 다음 기사 전 0.5초 대기
# [849 / 1540] 	 55.13% 	 error: 0
# 다음 기사 전 1.0초 대기
# [850 / 1540] 	 55.19% 	 error: 0
# 다음 기사 전 0.9초 대기
# [851 / 1540] 	 55.26% 	 error: 0
# 다음 기사 전 1.0초 대기
# [852 / 1540] 	 55.32% 	 error: 0
# 다음 기사 전 0.9초 대기
# [853 / 1540] 	 55.39% 	 error: 0
# 다음 기사 전 1.1초 대기
# [854 / 1540] 	 55.45% 	 error: 0
# 다음 기사 전 1.1초 대기
# [855 / 1540] 	 55.52% 	 error: 0
# 다음 기사 전 0.9초 대기
# [856 / 1540] 	 55.58% 	 error: 0
# 다음 기사 전 0.6초 대기
# [857 / 1540] 	 55.65% 	 error: 0
# 다음 기사 전 0.9초 대기
# [858 / 1540] 	 55.71% 	 error: 0
# 다음 기사 전 1.0초 대기
# [859 / 1540] 	 55.78% 	 error: 0
# 다음 기사 전 1.1초 대기
# [860 / 1540] 	 55.84% 	 error: 0
# 다음 기사 전 0.7초 대기
# [861 / 1540] 	 55.91% 	 error: 0
# 다음 기사 전 1.0초 대기
# [862 / 1540] 	 55.97% 	 error: 0
# 다음 기사 전 0.5초 대기
# [863 / 1540] 	 56.04% 	 error: 0
# 다음 기사 전 0.5초 대기
# [864 / 1540] 	 56.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [865 / 1540] 	 56.17% 	 error: 0
# 다음 기사 전 0.8초 대기
# [866 / 1540] 	 56.23% 	 error: 0
# 다음 기사 전 0.8초 대기
# [867 / 1540] 	 56.30% 	 error: 0
# 다음 기사 전 0.6초 대기
# [868 / 1540] 	 56.36% 	 error: 0
# 다음 기사 전 0.5초 대기
# [869 / 1540] 	 56.43% 	 error: 0
# 다음 기사 전 1.0초 대기
# [870 / 1540] 	 56.49% 	 error: 0
# 다음 기사 전 0.5초 대기
# [871 / 1540] 	 56.56% 	 error: 0
# 다음 기사 전 1.0초 대기
# [872 / 1540] 	 56.62% 	 error: 0
# 다음 기사 전 0.6초 대기
# [873 / 1540] 	 56.69% 	 error: 0
# 다음 기사 전 0.9초 대기
# [874 / 1540] 	 56.75% 	 error: 0
# 다음 기사 전 0.9초 대기
# [875 / 1540] 	 56.82% 	 error: 0
# 다음 기사 전 0.9초 대기
# [876 / 1540] 	 56.88% 	 error: 0
# 다음 기사 전 1.1초 대기
# [877 / 1540] 	 56.95% 	 error: 0
# 다음 기사 전 0.5초 대기
# [878 / 1540] 	 57.01% 	 error: 0
# 다음 기사 전 0.8초 대기
# [879 / 1540] 	 57.08% 	 error: 0
# 다음 기사 전 0.7초 대기
# [880 / 1540] 	 57.14% 	 error: 0
# 다음 기사 전 0.5초 대기
# [881 / 1540] 	 57.21% 	 error: 0
# 다음 기사 전 0.5초 대기
# [882 / 1540] 	 57.27% 	 error: 0
# 다음 기사 전 0.5초 대기
# [883 / 1540] 	 57.34% 	 error: 0
# 다음 기사 전 0.4초 대기
# [884 / 1540] 	 57.40% 	 error: 0
# 다음 기사 전 0.4초 대기
# [885 / 1540] 	 57.47% 	 error: 0
# 다음 기사 전 1.1초 대기
# [886 / 1540] 	 57.53% 	 error: 0
# 다음 기사 전 0.5초 대기
# [887 / 1540] 	 57.60% 	 error: 0
# 다음 기사 전 0.5초 대기
# [888 / 1540] 	 57.66% 	 error: 0
# 다음 기사 전 0.4초 대기
# [889 / 1540] 	 57.73% 	 error: 0
# 다음 기사 전 0.9초 대기
# [890 / 1540] 	 57.79% 	 error: 0
# 다음 기사 전 0.6초 대기
# [891 / 1540] 	 57.86% 	 error: 0
# 다음 기사 전 1.1초 대기
# [892 / 1540] 	 57.92% 	 error: 0
# 다음 기사 전 0.9초 대기
# [893 / 1540] 	 57.99% 	 error: 0
# 다음 기사 전 0.5초 대기
# [894 / 1540] 	 58.05% 	 error: 0
# 다음 기사 전 0.9초 대기
# [895 / 1540] 	 58.12% 	 error: 0
# 다음 기사 전 1.0초 대기
# [896 / 1540] 	 58.18% 	 error: 0
# 다음 기사 전 0.9초 대기
# [897 / 1540] 	 58.25% 	 error: 0
# 다음 기사 전 0.5초 대기
# [898 / 1540] 	 58.31% 	 error: 0
# 다음 기사 전 1.1초 대기
# [899 / 1540] 	 58.38% 	 error: 0
# 다음 기사 전 0.5초 대기
# [900 / 1540] 	 58.44% 	 error: 0
# 다음 기사 전 0.9초 대기
# [901 / 1540] 	 58.51% 	 error: 0
# 다음 기사 전 0.9초 대기
# [902 / 1540] 	 58.57% 	 error: 0
# 다음 기사 전 0.8초 대기
# [903 / 1540] 	 58.64% 	 error: 0
# 다음 기사 전 0.8초 대기
# [904 / 1540] 	 58.70% 	 error: 0
# 다음 기사 전 0.7초 대기
# [905 / 1540] 	 58.77% 	 error: 0
# 다음 기사 전 0.5초 대기
# [906 / 1540] 	 58.83% 	 error: 0
# 다음 기사 전 1.0초 대기
# [907 / 1540] 	 58.90% 	 error: 0
# 다음 기사 전 0.6초 대기
# [908 / 1540] 	 58.96% 	 error: 0
# 다음 기사 전 0.9초 대기
# [909 / 1540] 	 59.03% 	 error: 0
# 다음 기사 전 0.5초 대기
# [910 / 1540] 	 59.09% 	 error: 0
# 다음 기사 전 0.5초 대기
# [911 / 1540] 	 59.16% 	 error: 0
# 다음 기사 전 1.2초 대기
# [912 / 1540] 	 59.22% 	 error: 0
# 다음 기사 전 0.7초 대기
# [913 / 1540] 	 59.29% 	 error: 0
# 다음 기사 전 1.2초 대기
# [914 / 1540] 	 59.35% 	 error: 0
# 다음 기사 전 0.6초 대기
# [915 / 1540] 	 59.42% 	 error: 0
# 다음 기사 전 0.7초 대기
# [916 / 1540] 	 59.48% 	 error: 0
# 다음 기사 전 0.6초 대기
# [917 / 1540] 	 59.55% 	 error: 0
# 다음 기사 전 1.1초 대기
# [918 / 1540] 	 59.61% 	 error: 0
# 다음 기사 전 1.1초 대기
# [919 / 1540] 	 59.68% 	 error: 0
# 다음 기사 전 0.8초 대기
# [920 / 1540] 	 59.74% 	 error: 0
# 다음 기사 전 0.6초 대기
# [921 / 1540] 	 59.81% 	 error: 0
# 다음 기사 전 0.4초 대기
# [922 / 1540] 	 59.87% 	 error: 0
# 다음 기사 전 0.5초 대기
# [923 / 1540] 	 59.94% 	 error: 0
# 다음 기사 전 0.8초 대기
# [924 / 1540] 	 60.00% 	 error: 0
# 다음 기사 전 0.4초 대기
# [925 / 1540] 	 60.06% 	 error: 0
# 다음 기사 전 0.6초 대기
# [926 / 1540] 	 60.13% 	 error: 0
# 다음 기사 전 0.8초 대기
# [927 / 1540] 	 60.19% 	 error: 0
# 다음 기사 전 1.2초 대기
# [928 / 1540] 	 60.26% 	 error: 0
# 다음 기사 전 0.7초 대기
# [929 / 1540] 	 60.32% 	 error: 0
# 다음 기사 전 0.7초 대기
# [930 / 1540] 	 60.39% 	 error: 0
# 다음 기사 전 1.1초 대기
# [931 / 1540] 	 60.45% 	 error: 0
# 다음 기사 전 1.2초 대기
# [932 / 1540] 	 60.52% 	 error: 0
# 다음 기사 전 0.7초 대기
# [933 / 1540] 	 60.58% 	 error: 0
# 다음 기사 전 0.8초 대기
# [934 / 1540] 	 60.65% 	 error: 0
# 다음 기사 전 1.1초 대기
# [935 / 1540] 	 60.71% 	 error: 0
# 다음 기사 전 1.1초 대기
# [936 / 1540] 	 60.78% 	 error: 0
# 다음 기사 전 0.5초 대기
# [937 / 1540] 	 60.84% 	 error: 0
# 다음 기사 전 1.2초 대기
# [938 / 1540] 	 60.91% 	 error: 0
# 다음 기사 전 0.5초 대기
# [939 / 1540] 	 60.97% 	 error: 0
# 다음 기사 전 0.8초 대기
# ...
# 다음 기사 전 0.6초 대기
# [1245 / 1540] 	 80.84% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1246 / 1540] 	 80.91% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1247 / 1540] 	 80.97% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1248 / 1540] 	 81.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1249 / 1540] 	 81.10% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1250 / 1540] 	 81.17% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1251 / 1540] 	 81.23% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1252 / 1540] 	 81.30% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1253 / 1540] 	 81.36% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1254 / 1540] 	 81.43% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1255 / 1540] 	 81.49% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1256 / 1540] 	 81.56% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1257 / 1540] 	 81.62% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1258 / 1540] 	 81.69% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1259 / 1540] 	 81.75% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1260 / 1540] 	 81.82% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1261 / 1540] 	 81.88% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1262 / 1540] 	 81.95% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1263 / 1540] 	 82.01% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1264 / 1540] 	 82.08% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1265 / 1540] 	 82.14% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1266 / 1540] 	 82.21% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1267 / 1540] 	 82.27% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1268 / 1540] 	 82.34% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1269 / 1540] 	 82.40% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1270 / 1540] 	 82.47% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1271 / 1540] 	 82.53% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1272 / 1540] 	 82.60% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1273 / 1540] 	 82.66% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1274 / 1540] 	 82.73% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1275 / 1540] 	 82.79% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1276 / 1540] 	 82.86% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1277 / 1540] 	 82.92% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1278 / 1540] 	 82.99% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1279 / 1540] 	 83.05% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1280 / 1540] 	 83.12% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1281 / 1540] 	 83.18% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1282 / 1540] 	 83.25% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1283 / 1540] 	 83.31% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1284 / 1540] 	 83.38% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1285 / 1540] 	 83.44% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1286 / 1540] 	 83.51% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1287 / 1540] 	 83.57% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1288 / 1540] 	 83.64% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1289 / 1540] 	 83.70% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1290 / 1540] 	 83.77% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1291 / 1540] 	 83.83% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1292 / 1540] 	 83.90% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1293 / 1540] 	 83.96% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1294 / 1540] 	 84.03% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1295 / 1540] 	 84.09% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1296 / 1540] 	 84.16% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1297 / 1540] 	 84.22% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1298 / 1540] 	 84.29% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1299 / 1540] 	 84.35% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1300 / 1540] 	 84.42% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1301 / 1540] 	 84.48% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1302 / 1540] 	 84.55% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1303 / 1540] 	 84.61% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1304 / 1540] 	 84.68% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1305 / 1540] 	 84.74% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1306 / 1540] 	 84.81% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1307 / 1540] 	 84.87% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1308 / 1540] 	 84.94% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1309 / 1540] 	 85.00% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1310 / 1540] 	 85.06% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1311 / 1540] 	 85.13% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1312 / 1540] 	 85.19% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1313 / 1540] 	 85.26% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1314 / 1540] 	 85.32% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1315 / 1540] 	 85.39% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1316 / 1540] 	 85.45% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1317 / 1540] 	 85.52% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1318 / 1540] 	 85.58% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1319 / 1540] 	 85.65% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1320 / 1540] 	 85.71% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1321 / 1540] 	 85.78% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1322 / 1540] 	 85.84% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1323 / 1540] 	 85.91% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1324 / 1540] 	 85.97% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1325 / 1540] 	 86.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1326 / 1540] 	 86.10% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1327 / 1540] 	 86.17% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1328 / 1540] 	 86.23% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1329 / 1540] 	 86.30% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1330 / 1540] 	 86.36% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1331 / 1540] 	 86.43% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1332 / 1540] 	 86.49% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1333 / 1540] 	 86.56% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1334 / 1540] 	 86.62% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1335 / 1540] 	 86.69% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1336 / 1540] 	 86.75% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1337 / 1540] 	 86.82% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1338 / 1540] 	 86.88% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1339 / 1540] 	 86.95% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1340 / 1540] 	 87.01% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1341 / 1540] 	 87.08% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1342 / 1540] 	 87.14% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1343 / 1540] 	 87.21% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1344 / 1540] 	 87.27% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1345 / 1540] 	 87.34% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1346 / 1540] 	 87.40% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1347 / 1540] 	 87.47% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1348 / 1540] 	 87.53% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1349 / 1540] 	 87.60% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1350 / 1540] 	 87.66% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1351 / 1540] 	 87.73% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1352 / 1540] 	 87.79% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1353 / 1540] 	 87.86% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1354 / 1540] 	 87.92% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1355 / 1540] 	 87.99% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1356 / 1540] 	 88.05% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1357 / 1540] 	 88.12% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1358 / 1540] 	 88.18% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1359 / 1540] 	 88.25% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1360 / 1540] 	 88.31% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1361 / 1540] 	 88.38% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1362 / 1540] 	 88.44% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1363 / 1540] 	 88.51% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1364 / 1540] 	 88.57% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1365 / 1540] 	 88.64% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1366 / 1540] 	 88.70% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1367 / 1540] 	 88.77% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1368 / 1540] 	 88.83% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1369 / 1540] 	 88.90% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1370 / 1540] 	 88.96% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1371 / 1540] 	 89.03% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1372 / 1540] 	 89.09% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1373 / 1540] 	 89.16% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1374 / 1540] 	 89.22% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1375 / 1540] 	 89.29% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1376 / 1540] 	 89.35% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1377 / 1540] 	 89.42% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1378 / 1540] 	 89.48% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1379 / 1540] 	 89.55% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1380 / 1540] 	 89.61% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1381 / 1540] 	 89.68% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1382 / 1540] 	 89.74% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1383 / 1540] 	 89.81% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1384 / 1540] 	 89.87% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1385 / 1540] 	 89.94% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1386 / 1540] 	 90.00% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1387 / 1540] 	 90.06% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1388 / 1540] 	 90.13% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1389 / 1540] 	 90.19% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1390 / 1540] 	 90.26% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1391 / 1540] 	 90.32% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1392 / 1540] 	 90.39% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1393 / 1540] 	 90.45% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1394 / 1540] 	 90.52% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1395 / 1540] 	 90.58% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1396 / 1540] 	 90.65% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1397 / 1540] 	 90.71% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1398 / 1540] 	 90.78% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1399 / 1540] 	 90.84% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1400 / 1540] 	 90.91% 	 error: 0
# 체크포인트 저장 — 1400건 완료
# 다음 기사 전 1.2초 대기
# [1401 / 1540] 	 90.97% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1402 / 1540] 	 91.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1403 / 1540] 	 91.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1404 / 1540] 	 91.17% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1405 / 1540] 	 91.23% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1406 / 1540] 	 91.30% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1407 / 1540] 	 91.36% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1408 / 1540] 	 91.43% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1409 / 1540] 	 91.49% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1410 / 1540] 	 91.56% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1411 / 1540] 	 91.62% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1412 / 1540] 	 91.69% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1413 / 1540] 	 91.75% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1414 / 1540] 	 91.82% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1415 / 1540] 	 91.88% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1416 / 1540] 	 91.95% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1417 / 1540] 	 92.01% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1418 / 1540] 	 92.08% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1419 / 1540] 	 92.14% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1420 / 1540] 	 92.21% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1421 / 1540] 	 92.27% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1422 / 1540] 	 92.34% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1423 / 1540] 	 92.40% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1424 / 1540] 	 92.47% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1425 / 1540] 	 92.53% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1426 / 1540] 	 92.60% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1427 / 1540] 	 92.66% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1428 / 1540] 	 92.73% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1429 / 1540] 	 92.79% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1430 / 1540] 	 92.86% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1431 / 1540] 	 92.92% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1432 / 1540] 	 92.99% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1433 / 1540] 	 93.05% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1434 / 1540] 	 93.12% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1435 / 1540] 	 93.18% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1436 / 1540] 	 93.25% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1437 / 1540] 	 93.31% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1438 / 1540] 	 93.38% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1439 / 1540] 	 93.44% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1440 / 1540] 	 93.51% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1441 / 1540] 	 93.57% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1442 / 1540] 	 93.64% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1443 / 1540] 	 93.70% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1444 / 1540] 	 93.77% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1445 / 1540] 	 93.83% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1446 / 1540] 	 93.90% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1447 / 1540] 	 93.96% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1448 / 1540] 	 94.03% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1449 / 1540] 	 94.09% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1450 / 1540] 	 94.16% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1451 / 1540] 	 94.22% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1452 / 1540] 	 94.29% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1453 / 1540] 	 94.35% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1454 / 1540] 	 94.42% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1455 / 1540] 	 94.48% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1456 / 1540] 	 94.55% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1457 / 1540] 	 94.61% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1458 / 1540] 	 94.68% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1459 / 1540] 	 94.74% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1460 / 1540] 	 94.81% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1461 / 1540] 	 94.87% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1462 / 1540] 	 94.94% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1463 / 1540] 	 95.00% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1464 / 1540] 	 95.06% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1465 / 1540] 	 95.13% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1466 / 1540] 	 95.19% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1467 / 1540] 	 95.26% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1468 / 1540] 	 95.32% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1469 / 1540] 	 95.39% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1470 / 1540] 	 95.45% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1471 / 1540] 	 95.52% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1472 / 1540] 	 95.58% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1473 / 1540] 	 95.65% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1474 / 1540] 	 95.71% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1475 / 1540] 	 95.78% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1476 / 1540] 	 95.84% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1477 / 1540] 	 95.91% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1478 / 1540] 	 95.97% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1479 / 1540] 	 96.04% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1480 / 1540] 	 96.10% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1481 / 1540] 	 96.17% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1482 / 1540] 	 96.23% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1483 / 1540] 	 96.30% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1484 / 1540] 	 96.36% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1485 / 1540] 	 96.43% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1486 / 1540] 	 96.49% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1487 / 1540] 	 96.56% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1488 / 1540] 	 96.62% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1489 / 1540] 	 96.69% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1490 / 1540] 	 96.75% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1491 / 1540] 	 96.82% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1492 / 1540] 	 96.88% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1493 / 1540] 	 96.95% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1494 / 1540] 	 97.01% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1495 / 1540] 	 97.08% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1496 / 1540] 	 97.14% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1497 / 1540] 	 97.21% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1498 / 1540] 	 97.27% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1499 / 1540] 	 97.34% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1500 / 1540] 	 97.40% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1501 / 1540] 	 97.47% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1502 / 1540] 	 97.53% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1503 / 1540] 	 97.60% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1504 / 1540] 	 97.66% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1505 / 1540] 	 97.73% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1506 / 1540] 	 97.79% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1507 / 1540] 	 97.86% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1508 / 1540] 	 97.92% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1509 / 1540] 	 97.99% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1510 / 1540] 	 98.05% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1511 / 1540] 	 98.12% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1512 / 1540] 	 98.18% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1513 / 1540] 	 98.25% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1514 / 1540] 	 98.31% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1515 / 1540] 	 98.38% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1516 / 1540] 	 98.44% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1517 / 1540] 	 98.51% 	 error: 0
# 다음 기사 전 0.6초 대기
# [1518 / 1540] 	 98.57% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1519 / 1540] 	 98.64% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1520 / 1540] 	 98.70% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1521 / 1540] 	 98.77% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1522 / 1540] 	 98.83% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1523 / 1540] 	 98.90% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1524 / 1540] 	 98.96% 	 error: 0
# 다음 기사 전 0.7초 대기
# [1525 / 1540] 	 99.03% 	 error: 0
# 다음 기사 전 0.9초 대기
# [1526 / 1540] 	 99.09% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1527 / 1540] 	 99.16% 	 error: 0
# 다음 기사 전 0.4초 대기
# [1528 / 1540] 	 99.22% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1529 / 1540] 	 99.29% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1530 / 1540] 	 99.35% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1531 / 1540] 	 99.42% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1532 / 1540] 	 99.48% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1533 / 1540] 	 99.55% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1534 / 1540] 	 99.61% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1535 / 1540] 	 99.68% 	 error: 0
# 다음 기사 전 1.0초 대기
# [1536 / 1540] 	 99.74% 	 error: 0
# 다음 기사 전 1.2초 대기
# [1537 / 1540] 	 99.81% 	 error: 0
# 다음 기사 전 0.8초 대기
# [1538 / 1540] 	 99.87% 	 error: 0
# 다음 기사 전 1.1초 대기
# [1539 / 1540] 	 99.94% 	 error: 0
# 다음 기사 전 0.5초 대기
# [1540 / 1540] 	 100.00% 	 error: 0
# 다음 기사 전 0.5초 대기
# 저장 완료: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_YTN_260505_260511.csv
# 본문 수집 완료 — 총 1540건 / 오류 0건
#
# 전체 작업 완료
# 성공/건너뜀: 9개, 실패: 0개
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_SBS_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_KBS_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_MBC_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_한국경제_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_매일경제_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_한겨레_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_조선일보_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_연합뉴스_260505_260511.csv
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_YTN_260505_260511.csv

# %% [markdown]
# ## press별 본문 CSV 통합
#
# 위에서 만든 `본문_bs4_{press}_{기간}.csv` 파일들을 하나로 합치는 단계임.
# 각 행에 언론사 이름과 매체 그룹을 붙이고, 전처리·분석 단계에서 사용할 통합 CSV 저장.
#
# - 입력: 언론사별 `본문_bs4_{press}_{기간}.csv`
# - 출력: `통합_본문_bs4_언론사_{기간}.csv`
# - `_direct`가 붙은 방송사 직접 수집 파일은 통합에서 제외
# - 같은 기사 주소가 중복으로 들어온 경우 한 번 더 제거

# %%
# === press별 본문 CSV 통합 (+ media_group 부착) ===
import re
import unicodedata

# press와 media_group을 연결하는 표. 새 매체를 수집하면 여기만 추가
MEDIA_GROUP_MAP = {
    'KBS': '지상파', 'MBC': '지상파', 'SBS': '지상파',
    'YTN': '통신·보도', '연합뉴스': '통신·보도',
    '한국경제': '경제', '매일경제': '경제',
    '조선일보': '정치색', '한겨레': '정치색',
}
EXCLUDE_DIRECT = True  # 방송사 직접 수집(_direct) 결과물은 통합에서 제외


def _nfc(name):
    # 한글 파일명이 환경에 따라 다를 수 있어 비교 전에 이름을 정리
    return unicodedata.normalize('NFC', name)

# SAVE_DIR의 본문_bs4_{press}_{YYMMDD}_{YYMMDD}.csv를 모두 모음
# 현재 press_ranges 기간만 통합 (폴더에 다른 기간 파일이 남아 섞이는 것 방지)
target_periods = {make_period_suffix(r['start_date'], r['end_date']) for r in press_ranges}
print(f'통합 대상 기간: {sorted(target_periods)}')

infos = []
for path in SAVE_DIR.iterdir():
    if not path.is_file():
        continue
    m = re.match(r'^본문_bs4_(.+)_(\d{6})_(\d{6})\.csv$', _nfc(path.name))
    if not m:
        continue
    press, s, e = m.groups()
    if EXCLUDE_DIRECT and press.endswith('_direct'):
        print(f'제외(_direct): {_nfc(path.name)}')
        continue
    if f'{s}_{e}' not in target_periods:
        print(f'기간 불일치 제외: {_nfc(path.name)} (대상 {sorted(target_periods)})')
        continue
    infos.append((press, s, e, path))

infos.sort(key=lambda x: (x[0], x[1]))
if not infos:
    raise FileNotFoundError(f'통합할 본문_bs4_*.csv가 없습니다: {SAVE_DIR}')

frames = []
for press, s, e, path in infos:
    d = pd.read_csv(path, encoding='utf-8-sig')
    d['press'] = press                       # 파일명에서 떼어낸 press를 행마다 부착
    d['source_period'] = f'{s}_{e}'
    d['source_file'] = _nfc(path.name)
    frames.append(d)
    print(f'  {press} {s}_{e}: {len(d)}행')

merged = pd.concat(frames, ignore_index=True)

# media_group 붙이기 — 연결표에 없는 press는 미분류로 두고 경고 (수집 이름과 키를 맞추세요)
merged['media_group'] = merged['press'].map(MEDIA_GROUP_MAP)
unmapped = sorted(merged.loc[merged['media_group'].isna(), 'press'].unique())
if unmapped:
    print(f'\n[경고] media_group 매핑 없는 press: {unmapped} -> 미분류 (MEDIA_GROUP_MAP에 추가하세요)')
merged['media_group'] = merged['media_group'].fillna('미분류')

before = len(merged)
if 'link' in merged.columns:
    merged = merged.drop_duplicates(subset=['link'], keep='first').reset_index(drop=True)
if 'pubdate' in merged.columns:
    merged['pubdate'] = pd.to_datetime(merged['pubdate'], errors='coerce')
    merged = merged.sort_values(['media_group', 'press', 'pubdate']).reset_index(drop=True)

period_suffix = f"{min(s for _, s, _, _ in infos)}_{max(e for _, _, e, _ in infos)}"
combined_path = SAVE_DIR / f'통합_본문_bs4_언론사_{period_suffix}.csv'
merged.to_csv(combined_path, index=False, encoding='utf-8-sig')

print(f'\n통합 저장 완료: {combined_path}')
print(f'행 수: {before} -> {len(merged)} (중복 {before - len(merged)}건 제거)')
print('media_group별:', merged['media_group'].value_counts().to_dict())
print('press별:', merged['press'].value_counts().to_dict())
# Out:
# 통합 대상 기간: ['260505_260511']
# 제외(_direct): 본문_bs4_SBS_direct_260505_260505.csv
# 제외(_direct): 본문_bs4_SBS_direct_260505_260511.csv
# 제외(_direct): 본문_bs4_KBS_direct_260505_260511.csv
#   KBS 260505_260511: 1514행
#   MBC 260505_260511: 1212행
#   SBS 260505_260511: 1339행
#   YTN 260505_260511: 1540행
#   매일경제 260505_260511: 1415행
#   연합뉴스 260505_260511: 1540행
#   조선일보 260505_260511: 1216행
#   한겨레 260505_260511: 926행
#   한국경제 260505_260511: 1420행
#
# 통합 저장 완료: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/통합_본문_bs4_언론사_260505_260511.csv
# 행 수: 12122 -> 12122 (중복 0건 제거)
# media_group별: {'지상파': 4065, '통신·보도': 3080, '경제': 2835, '정치색': 2142}
# press별: {'YTN': 1540, '연합뉴스': 1540, 'KBS': 1514, '한국경제': 1420, '매일경제': 1415, 'SBS': 1339, '조선일보': 1216, 'MBC': 1212, '한겨레': 926}
