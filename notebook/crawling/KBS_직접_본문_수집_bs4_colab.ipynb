# %% [markdown]
# # KBS 뉴스 본문 수집 (BS4 Colab용) — 사이트 직접 / 기간 모드
#
# URL 수집 노트북에서 만든 `링크_{press}_*.json` 파일을 읽어 KBS 사이트(`news.kbs.co.kr`) view.do 페이지를 BS4로 파싱한다. 통신3사/LPOD/SBS 트랙과 동일하게 **기간 단위 통합 CSV** 1개를 만든다 (입력 JSON 1개 → 출력 CSV 1개).
#
# - 입력: `data/링크_{press}_{YYMMDD}_{YYMMDD}.json` (기간 통합)
# - 출력: `data/본문_bs4_{press}_{YYMMDD}_{YYMMDD}.csv`
# - 보조 출력: 중간 재개용 체크포인트 JSON, 재실패 URL JSON
# - 특징: 기간 단위 통합 수집, 중간 재개, 오류 URL 1회 재시도, 완료 파일 건너뛰기
# - 셀렉터: title=h4.headline-title, body=div#cont_newstext, pubdate=em.input-date 텍스트 파싱, category=a.category-name

# %%
# Colab 환경 세팅 — requests, BeautifulSoup 설치
# KBS view.do는 정적 HTML이라 Selenium 불필요, requests + BS4로 충분
# !pip install -q requests beautifulsoup4 pandas

# %%
# Google Drive 마운트 — 중간에 끊겨도 데이터 보존
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Drive 안의 프로젝트 폴더로 이동
# 통신3사 트리와 분리하기 위해 KBS/SBS 등 언론사 직접 수집은 news/ 하위에 보관
import os
PROJECT_DIR = '/content/drive/MyDrive/Text-data-Analysis_26-Spring/news'
os.chdir(PROJECT_DIR)
print(f'현재 작업 폴더: {os.getcwd()}')
# Out:
# 현재 작업 폴더: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news

# %%
import json
import os
import random
import re
import time
from datetime import datetime, timedelta
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup

# 로컬/Colab 비교를 위해 User-Agent 고정
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36'

# 담당 언론사와 수집 기간 지정 — 날짜 형식: 'YYYY.MM.DD'
# URL 수집 노트북과 동일한 press_ranges를 그대로 사용
# press 하나당 start_date ~ end_date 안의 일자를 한 통합 CSV로 묶어 저장 (통신3사/LPOD/SBS 트랙과 동일 패턴)
# _direct 접미사로 네이버 경유본 본문(`본문_bs4_KBS_*.csv`)과 출력 파일 분리
press_ranges = [
    {'press': 'KBS_direct', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
]


# 기간 단위 작업 목록 생성 — press_ranges 한 항목당 jobs 1개
# URL 수집 노트북과 같은 시그니처(press/start_date/end_date)를 본문 수집에 그대로 전달
def build_period_jobs(press_ranges):
    jobs = []
    for item in press_ranges:
        # 'YYYY.MM.DD' 문자열을 datetime으로 파싱 — 기간 유효성 검사용
        start = datetime.strptime(item['start_date'], '%Y.%m.%d')
        end = datetime.strptime(item['end_date'], '%Y.%m.%d')
        # 시작 일자가 끝 일자보다 늦으면 작업 범위가 잘못된 것이므로 즉시 중단
        if start > end:
            raise ValueError(f"시작 일자가 끝 일자보다 늦습니다: {item}")
        jobs.append({
            'press': item['press'],
            'start_date': item['start_date'],
            'end_date': item['end_date'],
        })
    return jobs


# 변수 정의 (날짜 형식: 'YYYY.MM.DD')
jobs = build_period_jobs(press_ranges)

print(f'총 작업 수: {len(jobs)}')
for job in jobs:
    print(job)

# 셀 3을 건너뛰고 실행해도 기본 프로젝트 경로를 사용할 수 있게 보완
try:
    PROJECT_DIR
except NameError:
    PROJECT_DIR = '/content/drive/MyDrive/Text-data-Analysis_26-Spring/news'

# 저장할 폴더 지정 — 링크 파일, 체크포인트, 본문 CSV, 실패 목록이 모두 이 폴더에 저장
SAVE_DIR = Path(PROJECT_DIR) / 'notebook' / 'crawling' / 'data'
SAVE_DIR.mkdir(parents=True, exist_ok=True)
print(f'저장 위치: {SAVE_DIR}')

# requests 세션 — User-Agent/Accept-Language를 반복 요청에 일관 적용, TCP/TLS 핸드셰이크 비용 절감
session = requests.Session()
session.headers.update({
    'User-Agent': USER_AGENT,
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
})
print(f'User-Agent: {USER_AGENT}')
# Out:
# 총 작업 수: 1
# {'press': 'KBS_direct', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# 저장 위치: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36

# %%
# 봇 탐지 방지를 위해 기사/job 사이에 랜덤한 시간을 기다림
ARTICLE_PAUSE_RANGE_SEC = (0.4, 1.2)
JOB_PAUSE_RANGE_SEC = (8, 20)

# 중간에 끊겨도 이어서 수집할 수 있도록 일정 건수마다 체크포인트 저장
CHECKPOINT_INTERVAL = 200
# requests 응답 대기 상한 — KBS 페이지가 늦게 뜨면 끊고 err_idx에 기록
REQUEST_TIMEOUT_SEC = 15
SKIP_COMPLETED = True


# 랜덤 대기 후 로그 출력
def polite_sleep(label, pause_range):
    pause_sec = random.uniform(*pause_range)
    print(f"{label} {pause_sec:.1f}초 대기")
    time.sleep(pause_sec)


# 파일명에 사용할 YYMMDD_YYMMDD 형식 기간 문자열 생성 (통신3사 트랙과 동일 시그니처)
# 예: 2026.05.01 ~ 2026.05.07 -> '260501_260507'
def make_period_suffix(start_date, end_date):
    return f"{start_date.replace('.', '')[2:]}_{end_date.replace('.', '')[2:]}"


# 본문 안의 줄바꿈/연속 공백을 하나의 공백으로 정리 (CSV/분석 단계 일관성 위해)
def normalize_body_text(text):
    return re.sub(r'\s+', ' ', text).strip()


# KBS 페이지의 '입력 YYYY.MM.DD (HH:mm)' 텍스트를 다른 트랙과 동일한 'YYYY-MM-DD HH:MM:00' 포맷으로 변환
# KBS는 24시간 표기이므로 오전/오후 변환은 필요 없음 (네이버 스포츠/연예와 다름)
def parse_kbs_datetime(text):
    m = re.search(r'(\d{4})\.(\d{2})\.(\d{2})\s*\((\d{1,2}):(\d{2})\)', text)
    if not m:
        return ''
    y, mo, d, h, mi = m.groups()
    return f'{y}-{mo}-{d} {int(h):02d}:{mi}:00'


# 기사 한 건에서 title/body/pubdate/category 추출 (KBS view.do 셀렉터 사용)
# title/body/pubdate 중 하나라도 비면 호출부에서 err_idx로 기록할 수 있도록 ValueError 발생
def extract_article_bs4(link, session=session):
    # KBS 사이트 기사 페이지 HTML 요청 — 정적 HTML이라 requests로 충분
    response = session.get(link, timeout=REQUEST_TIMEOUT_SEC)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')

    # 제목 추출하기 — h4.headline-title
    title_el = soup.select_one('h4.headline-title')
    title = title_el.get_text(strip=True) if title_el else ''

    # 본문 추출하기 — div#cont_newstext (KBS는 id로 본문 컨테이너 지정)
    # <br> 태그는 BS4가 자동으로 공백 처리, normalize_body_text가 연속 공백 정리
    body_el = soup.select_one('div#cont_newstext')
    body = normalize_body_text(body_el.get_text(' ', strip=True)) if body_el else ''

    # 날짜 추출하기 — em.input-date 텍스트 (예: '입력 2026.05.05 (23:52)')
    # em.edit-date(수정일)는 무시 — 정렬·필터링은 입력 시각 기준
    date_el = soup.select_one('em.input-date')
    pubdate = parse_kbs_datetime(date_el.get_text(strip=True)) if date_el else ''

    # 카테고리 추출하기 — a.category-name ('정치', '국제' 등 한글 라벨)
    cat_el = soup.select_one('a.category-name')
    category = cat_el.get_text(strip=True) if cat_el else ''

    # 제목/본문/날짜 중 하나라도 없으면 실패 — 호출부에서 err_idx로 기록
    if not title or not body or not pubdate:
        raise ValueError('title/body/pubdate 중 일부를 추출하지 못함')

    return {
        'link': link,
        'pubdate': pubdate,
        'category': category,
        'title': title,
        'body': body,
    }


# 한 언론사의 기간 통합 링크 JSON을 읽어 본문을 수집하고 통합 CSV로 저장
# 체크포인트 기반 재개 + 오류 자동 1회 재시도 + 재실패 URL JSON 저장
def collect_bodies_bs4(press, start_date, end_date, save_dir=SAVE_DIR):
    # 파일명 키로 쓸 기간 접미사 (예: 260501_260507)
    period = make_period_suffix(start_date, end_date)
    # 입력: URL 수집 단계가 만들어 둔 기간 통합 KBS 링크 JSON
    links_path = save_dir / f"링크_{press}_{period}.json"
    # 체크포인트: 중간 결과(all_results) + 오류 인덱스 + 다음 인덱스를 보관
    checkpoint_path = save_dir / f"체크포인트_본문_bs4_{press}_{period}.json"
    # 최종 출력: 기간 통합 본문 CSV (네이버 경유본과 분리하기 위해 press에 _direct 접미사가 붙음)
    csv_save_path = save_dir / f"본문_bs4_{press}_{period}.csv"

    # 최종 CSV가 이미 있으면 같은 기간은 건너뜀 (재실행 시 idempotent)
    if SKIP_COMPLETED and csv_save_path.exists():
        print()
        print(f"=== {press} / {start_date} ~ {end_date} 이미 완료됨, 건너뜀 ===")
        print(f"기존 파일: {csv_save_path}")
        return csv_save_path

    # 링크 파일 불러오기
    if links_path.exists():
        with links_path.open('r', encoding='utf-8') as f:
            kbs_news_links = json.load(f)
        # 기사 한 건당 대략 (랜덤 대기 평균 + 0.7s) 잡은 거친 예상치 — 로그 확인용
        avg_pause_sec = sum(ARTICLE_PAUSE_RANGE_SEC) / 2
        est_sec_per_article = avg_pause_sec + 0.7
        est_min = len(kbs_news_links) * est_sec_per_article / 60
        print()
        print(f"=== {press} / {start_date} ~ {end_date} BS4 본문 수집 시작 ===")
        print(f'링크 {len(kbs_news_links)}개 불러옴: {links_path}')
        print(f'예상 소요 시간: 약 {est_min:.0f}분')
    else:
        raise FileNotFoundError(f'링크 파일 없음 — KBS_직접_url_수집_colab.ipynb를 먼저 실행하세요\n경로: {links_path}')

    # 이전에 중단된 작업이 있으면 이어받기 — next_i 인덱스 다음부터 시작
    if checkpoint_path.exists():
        with checkpoint_path.open('r', encoding='utf-8') as f:
            checkpoint = json.load(f)
        # JSON은 dict 키를 문자열로 저장하므로 int로 다시 변환
        all_results = {int(k): v for k, v in checkpoint.get('all_results', {}).items()}
        err_idx = checkpoint.get('err_idx', [])
        i = checkpoint.get('next_i', 0)
        print(f'체크포인트 발견 — {i}번째부터 이어서 시작 (이미 수집: {len(all_results)}건)')
    else:
        all_results = dict()
        i = 0
        err_idx = []
        print('새로 시작')

    # 본문 수집 메인 루프 — i 인덱스를 함께 들고 다녀 체크포인트와 동기화
    for link in kbs_news_links[i:]:
        try:
            all_results[i] = extract_article_bs4(link)
            # 진행 상황 확인용 코드
            print(f'[{i+1} / {len(kbs_news_links)}] \t {(i+1)/len(kbs_news_links)*100:.2f}% \t error: {len(err_idx)}')
            i += 1
            # 중간저장 — N건마다 체크포인트 갱신해 중간 중단에도 진행 보존
            if i % CHECKPOINT_INTERVAL == 0:
                with checkpoint_path.open('w', encoding='utf-8') as f:
                    json.dump({'all_results': all_results, 'err_idx': err_idx, 'next_i': i}, f, ensure_ascii=False, indent=2)
                print(f'체크포인트 저장 — {i}건 완료')
            polite_sleep('다음 기사 전', ARTICLE_PAUSE_RANGE_SEC)
        except Exception as exc:
            # 오류 인덱스를 err_idx에 누적해두고 즉시 체크포인트도 갱신
            print(f'오류 발생 — index {i}: {exc!r}')
            err_idx.append(i)
            i += 1
            with checkpoint_path.open('w', encoding='utf-8') as f:
                json.dump({'all_results': all_results, 'err_idx': err_idx, 'next_i': i}, f, ensure_ascii=False, indent=2)

    # 1차 오류 자동 재시도 — 페이지가 늦게 떴거나 일시적 네트워크 문제였던 경우를 한 번 더 시도
    if err_idx:
        print()
        print(f'오류 {len(err_idx)}건 재시도 시작...')
        re_err_idx = []
        for retry_i in err_idx:
            try:
                link = kbs_news_links[retry_i]
                all_results[retry_i] = extract_article_bs4(link)
                print(f'재시도 성공 — index {retry_i}')
                polite_sleep('다음 재시도 전', ARTICLE_PAUSE_RANGE_SEC)
            except Exception as exc:
                print(f'재시도 실패 — index {retry_i}: {exc!r}')
                re_err_idx.append(retry_i)
        # 재시도 후에도 실패한 인덱스만 남김 — 본문_bs4_재실패_*.json으로 저장 대상
        err_idx = re_err_idx
        print(f'재시도 완료 — 재실패: {len(err_idx)}건')

    # 수집한 정보들을 dataframe으로 변환
    df = pd.DataFrame(all_results).T
    if df.empty:
        raise ValueError('수집된 본문 데이터가 없습니다.')

    # 수집한 기사들 중 중복인 경우 이를 제거
    df_no_duplicates = df.drop_duplicates().reset_index(drop=True)
    # 오래된 순부터 수집했으나 혹시 모를 상황을 방지하기 위해 pubdate를 datetime으로 변환 후 정렬
    df_no_duplicates['pubdate'] = pd.to_datetime(df_no_duplicates['pubdate'], errors='coerce')
    df_sorted = df_no_duplicates.sort_values(by='pubdate')

    # 수집한 정보들을 csv로 저장 (Google Drive에 저장)
    df_sorted.to_csv(csv_save_path, index=False, encoding='utf-8-sig')
    print(f'저장 완료: {csv_save_path}')

    if err_idx:
        # 재시도 후에도 실패한 URL은 별 JSON으로 떨어뜨려 Selenium 재시도 노트북에서 다시 시도 가능
        failed_path = save_dir / f"본문_bs4_재실패_{press}_{period}.json"
        with failed_path.open('w', encoding='utf-8') as f:
            json.dump({'err_idx': err_idx, 'links': [kbs_news_links[x] for x in err_idx]}, f, ensure_ascii=False, indent=2)
        print(f'재실패 목록 저장: {failed_path}')
    elif checkpoint_path.exists():
        # 재실패가 없을 때만 체크포인트 삭제 — 실패가 남아있으면 디버깅용으로 보존
        checkpoint_path.unlink()

    print(f'본문 수집 완료 — 총 {len(df_sorted)}건 / 오류 {len(err_idx)}건')
    return csv_save_path


# 생성된 jobs를 순서대로 실행
# 한 작업이 실패해도 실패 목록에 기록하고 다음 작업으로 넘어감
results = []
failures = []
for index, job in enumerate(jobs, start=1):
    print()
    print(f"[{index}/{len(jobs)}] 작업 실행: {job}")
    try:
        # job 딕셔너리의 press/start_date/end_date를 collect_bodies_bs4 인자로 전달
        results.append(collect_bodies_bs4(**job))
    except Exception as exc:
        # 한 언론사에서 오류가 나도 전체 작업이 멈추지 않도록 실패 정보만 저장
        failures.append({'job': job, 'error': repr(exc)})
        print(f"작업 실패, 다음 작업으로 넘어감: {exc!r}")
    finally:
        if index < len(jobs):
            # 다음 언론사 job으로 넘어가기 전 대기
            polite_sleep('다음 작업 전', JOB_PAUSE_RANGE_SEC)

# 실패한 작업이 있으면 나중에 다시 돌릴 수 있게 파일로 저장
if failures:
    failures_path = SAVE_DIR / '본문_bs4_수집실패목록_KBS_direct.json'
    with failures_path.open('w', encoding='utf-8') as f:
        json.dump(failures, f, ensure_ascii=False, indent=2)
    print()
    print(f"실패 작업 {len(failures)}개 저장: {failures_path}")

print()
print('전체 작업 완료')
print(f'성공/건너뜀: {len(results)}개, 실패: {len(failures)}개')
for result_path in results:
    print(result_path)
# Out:
# [1/1] 작업 실행: {'press': 'KBS_direct', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === KBS_direct / 2026.05.05 ~ 2026.05.11 BS4 본문 수집 시작 ===
# 링크 2703개 불러옴: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/링크_KBS_direct_260505_260511.json
# 예상 소요 시간: 약 68분
# 새로 시작
# [1 / 2703] 	 0.04% 	 error: 0
# 다음 기사 전 1.1초 대기
# [2 / 2703] 	 0.07% 	 error: 0
# 다음 기사 전 0.9초 대기
# [3 / 2703] 	 0.11% 	 error: 0
# 다음 기사 전 1.0초 대기
# [4 / 2703] 	 0.15% 	 error: 0
# 다음 기사 전 0.6초 대기
# [5 / 2703] 	 0.18% 	 error: 0
# 다음 기사 전 0.9초 대기
# 오류 발생 — index 5: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [7 / 2703] 	 0.26% 	 error: 1
# 다음 기사 전 1.0초 대기
# [8 / 2703] 	 0.30% 	 error: 1
# 다음 기사 전 0.7초 대기
# [9 / 2703] 	 0.33% 	 error: 1
# 다음 기사 전 0.4초 대기
# [10 / 2703] 	 0.37% 	 error: 1
# 다음 기사 전 0.4초 대기
# 오류 발생 — index 10: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [12 / 2703] 	 0.44% 	 error: 2
# 다음 기사 전 0.8초 대기
# [13 / 2703] 	 0.48% 	 error: 2
# 다음 기사 전 0.6초 대기
# [14 / 2703] 	 0.52% 	 error: 2
# 다음 기사 전 0.9초 대기
# [15 / 2703] 	 0.55% 	 error: 2
# 다음 기사 전 1.1초 대기
# [16 / 2703] 	 0.59% 	 error: 2
# 다음 기사 전 0.5초 대기
# [17 / 2703] 	 0.63% 	 error: 2
# 다음 기사 전 1.1초 대기
# [18 / 2703] 	 0.67% 	 error: 2
# 다음 기사 전 0.5초 대기
# [19 / 2703] 	 0.70% 	 error: 2
# 다음 기사 전 1.2초 대기
# [20 / 2703] 	 0.74% 	 error: 2
# 다음 기사 전 0.6초 대기
# [21 / 2703] 	 0.78% 	 error: 2
# 다음 기사 전 0.7초 대기
# [22 / 2703] 	 0.81% 	 error: 2
# 다음 기사 전 0.9초 대기
# [23 / 2703] 	 0.85% 	 error: 2
# 다음 기사 전 0.9초 대기
# [24 / 2703] 	 0.89% 	 error: 2
# 다음 기사 전 0.6초 대기
# [25 / 2703] 	 0.92% 	 error: 2
# 다음 기사 전 0.5초 대기
# [26 / 2703] 	 0.96% 	 error: 2
# 다음 기사 전 1.1초 대기
# [27 / 2703] 	 1.00% 	 error: 2
# 다음 기사 전 0.6초 대기
# [28 / 2703] 	 1.04% 	 error: 2
# 다음 기사 전 0.8초 대기
# [29 / 2703] 	 1.07% 	 error: 2
# 다음 기사 전 0.9초 대기
# [30 / 2703] 	 1.11% 	 error: 2
# 다음 기사 전 0.5초 대기
# [31 / 2703] 	 1.15% 	 error: 2
# 다음 기사 전 1.0초 대기
# [32 / 2703] 	 1.18% 	 error: 2
# 다음 기사 전 0.8초 대기
# [33 / 2703] 	 1.22% 	 error: 2
# 다음 기사 전 1.1초 대기
# [34 / 2703] 	 1.26% 	 error: 2
# 다음 기사 전 0.8초 대기
# [35 / 2703] 	 1.29% 	 error: 2
# 다음 기사 전 0.5초 대기
# [36 / 2703] 	 1.33% 	 error: 2
# 다음 기사 전 1.2초 대기
# [37 / 2703] 	 1.37% 	 error: 2
# 다음 기사 전 0.8초 대기
# [38 / 2703] 	 1.41% 	 error: 2
# 다음 기사 전 0.9초 대기
# [39 / 2703] 	 1.44% 	 error: 2
# 다음 기사 전 0.6초 대기
# [40 / 2703] 	 1.48% 	 error: 2
# 다음 기사 전 0.6초 대기
# [41 / 2703] 	 1.52% 	 error: 2
# 다음 기사 전 0.6초 대기
# [42 / 2703] 	 1.55% 	 error: 2
# 다음 기사 전 0.7초 대기
# [43 / 2703] 	 1.59% 	 error: 2
# 다음 기사 전 0.7초 대기
# [44 / 2703] 	 1.63% 	 error: 2
# 다음 기사 전 1.1초 대기
# [45 / 2703] 	 1.66% 	 error: 2
# 다음 기사 전 1.0초 대기
# [46 / 2703] 	 1.70% 	 error: 2
# 다음 기사 전 0.6초 대기
# [47 / 2703] 	 1.74% 	 error: 2
# 다음 기사 전 0.6초 대기
# [48 / 2703] 	 1.78% 	 error: 2
# 다음 기사 전 0.6초 대기
# [49 / 2703] 	 1.81% 	 error: 2
# 다음 기사 전 0.7초 대기
# [50 / 2703] 	 1.85% 	 error: 2
# 다음 기사 전 0.4초 대기
# [51 / 2703] 	 1.89% 	 error: 2
# 다음 기사 전 0.9초 대기
# [52 / 2703] 	 1.92% 	 error: 2
# 다음 기사 전 0.9초 대기
# [53 / 2703] 	 1.96% 	 error: 2
# 다음 기사 전 1.1초 대기
# [54 / 2703] 	 2.00% 	 error: 2
# 다음 기사 전 0.6초 대기
# [55 / 2703] 	 2.03% 	 error: 2
# 다음 기사 전 0.6초 대기
# [56 / 2703] 	 2.07% 	 error: 2
# 다음 기사 전 0.8초 대기
# [57 / 2703] 	 2.11% 	 error: 2
# 다음 기사 전 0.6초 대기
# [58 / 2703] 	 2.15% 	 error: 2
# 다음 기사 전 1.1초 대기
# [59 / 2703] 	 2.18% 	 error: 2
# 다음 기사 전 1.0초 대기
# [60 / 2703] 	 2.22% 	 error: 2
# 다음 기사 전 0.4초 대기
# [61 / 2703] 	 2.26% 	 error: 2
# 다음 기사 전 0.9초 대기
# [62 / 2703] 	 2.29% 	 error: 2
# 다음 기사 전 1.0초 대기
# [63 / 2703] 	 2.33% 	 error: 2
# 다음 기사 전 0.8초 대기
# [64 / 2703] 	 2.37% 	 error: 2
# 다음 기사 전 0.8초 대기
# [65 / 2703] 	 2.40% 	 error: 2
# 다음 기사 전 0.5초 대기
# [66 / 2703] 	 2.44% 	 error: 2
# 다음 기사 전 0.6초 대기
# [67 / 2703] 	 2.48% 	 error: 2
# 다음 기사 전 0.4초 대기
# [68 / 2703] 	 2.52% 	 error: 2
# 다음 기사 전 0.6초 대기
# [69 / 2703] 	 2.55% 	 error: 2
# 다음 기사 전 1.1초 대기
# [70 / 2703] 	 2.59% 	 error: 2
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 70: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [72 / 2703] 	 2.66% 	 error: 3
# 다음 기사 전 0.9초 대기
# [73 / 2703] 	 2.70% 	 error: 3
# 다음 기사 전 0.6초 대기
# [74 / 2703] 	 2.74% 	 error: 3
# 다음 기사 전 0.4초 대기
# [75 / 2703] 	 2.77% 	 error: 3
# 다음 기사 전 0.8초 대기
# [76 / 2703] 	 2.81% 	 error: 3
# 다음 기사 전 0.8초 대기
# [77 / 2703] 	 2.85% 	 error: 3
# 다음 기사 전 0.9초 대기
# [78 / 2703] 	 2.89% 	 error: 3
# 다음 기사 전 1.0초 대기
# [79 / 2703] 	 2.92% 	 error: 3
# 다음 기사 전 1.1초 대기
# [80 / 2703] 	 2.96% 	 error: 3
# 다음 기사 전 0.7초 대기
# [81 / 2703] 	 3.00% 	 error: 3
# 다음 기사 전 0.7초 대기
# [82 / 2703] 	 3.03% 	 error: 3
# 다음 기사 전 0.6초 대기
# [83 / 2703] 	 3.07% 	 error: 3
# 다음 기사 전 0.7초 대기
# [84 / 2703] 	 3.11% 	 error: 3
# 다음 기사 전 0.8초 대기
# [85 / 2703] 	 3.14% 	 error: 3
# 다음 기사 전 0.9초 대기
# [86 / 2703] 	 3.18% 	 error: 3
# 다음 기사 전 1.0초 대기
# [87 / 2703] 	 3.22% 	 error: 3
# 다음 기사 전 0.8초 대기
# [88 / 2703] 	 3.26% 	 error: 3
# 다음 기사 전 0.9초 대기
# [89 / 2703] 	 3.29% 	 error: 3
# 다음 기사 전 0.4초 대기
# [90 / 2703] 	 3.33% 	 error: 3
# 다음 기사 전 0.9초 대기
# [91 / 2703] 	 3.37% 	 error: 3
# 다음 기사 전 1.2초 대기
# [92 / 2703] 	 3.40% 	 error: 3
# 다음 기사 전 0.8초 대기
# [93 / 2703] 	 3.44% 	 error: 3
# 다음 기사 전 0.9초 대기
# [94 / 2703] 	 3.48% 	 error: 3
# 다음 기사 전 0.9초 대기
# [95 / 2703] 	 3.51% 	 error: 3
# 다음 기사 전 0.9초 대기
# [96 / 2703] 	 3.55% 	 error: 3
# 다음 기사 전 0.9초 대기
# [97 / 2703] 	 3.59% 	 error: 3
# 다음 기사 전 0.5초 대기
# [98 / 2703] 	 3.63% 	 error: 3
# 다음 기사 전 1.2초 대기
# [99 / 2703] 	 3.66% 	 error: 3
# 다음 기사 전 0.8초 대기
# [100 / 2703] 	 3.70% 	 error: 3
# 다음 기사 전 1.1초 대기
# [101 / 2703] 	 3.74% 	 error: 3
# 다음 기사 전 0.6초 대기
# [102 / 2703] 	 3.77% 	 error: 3
# 다음 기사 전 0.4초 대기
# [103 / 2703] 	 3.81% 	 error: 3
# 다음 기사 전 0.8초 대기
# [104 / 2703] 	 3.85% 	 error: 3
# 다음 기사 전 0.6초 대기
# [105 / 2703] 	 3.88% 	 error: 3
# 다음 기사 전 1.1초 대기
# [106 / 2703] 	 3.92% 	 error: 3
# 다음 기사 전 0.5초 대기
# [107 / 2703] 	 3.96% 	 error: 3
# 다음 기사 전 1.0초 대기
# [108 / 2703] 	 4.00% 	 error: 3
# 다음 기사 전 0.4초 대기
# [109 / 2703] 	 4.03% 	 error: 3
# 다음 기사 전 0.4초 대기
# [110 / 2703] 	 4.07% 	 error: 3
# 다음 기사 전 0.6초 대기
# [111 / 2703] 	 4.11% 	 error: 3
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 111: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 112: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 113: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 114: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 115: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 116: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 117: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 118: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 119: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 120: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 121: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 122: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [124 / 2703] 	 4.59% 	 error: 15
# 다음 기사 전 0.8초 대기
# [125 / 2703] 	 4.62% 	 error: 15
# 다음 기사 전 0.6초 대기
# [126 / 2703] 	 4.66% 	 error: 15
# 다음 기사 전 0.5초 대기
# [127 / 2703] 	 4.70% 	 error: 15
# 다음 기사 전 0.6초 대기
# [128 / 2703] 	 4.74% 	 error: 15
# 다음 기사 전 0.8초 대기
# [129 / 2703] 	 4.77% 	 error: 15
# 다음 기사 전 0.4초 대기
# [130 / 2703] 	 4.81% 	 error: 15
# 다음 기사 전 0.8초 대기
# [131 / 2703] 	 4.85% 	 error: 15
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 131: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [133 / 2703] 	 4.92% 	 error: 16
# 다음 기사 전 1.0초 대기
# [134 / 2703] 	 4.96% 	 error: 16
# 다음 기사 전 0.6초 대기
# [135 / 2703] 	 4.99% 	 error: 16
# 다음 기사 전 0.6초 대기
# [136 / 2703] 	 5.03% 	 error: 16
# 다음 기사 전 0.4초 대기
# [137 / 2703] 	 5.07% 	 error: 16
# 다음 기사 전 1.0초 대기
# [138 / 2703] 	 5.11% 	 error: 16
# 다음 기사 전 0.8초 대기
# [139 / 2703] 	 5.14% 	 error: 16
# 다음 기사 전 0.5초 대기
# [140 / 2703] 	 5.18% 	 error: 16
# 다음 기사 전 0.4초 대기
# [141 / 2703] 	 5.22% 	 error: 16
# 다음 기사 전 0.9초 대기
# [142 / 2703] 	 5.25% 	 error: 16
# 다음 기사 전 0.5초 대기
# [143 / 2703] 	 5.29% 	 error: 16
# 다음 기사 전 0.9초 대기
# [144 / 2703] 	 5.33% 	 error: 16
# 다음 기사 전 0.9초 대기
# [145 / 2703] 	 5.36% 	 error: 16
# 다음 기사 전 0.5초 대기
# [146 / 2703] 	 5.40% 	 error: 16
# 다음 기사 전 0.9초 대기
# [147 / 2703] 	 5.44% 	 error: 16
# 다음 기사 전 0.4초 대기
# [148 / 2703] 	 5.48% 	 error: 16
# 다음 기사 전 1.0초 대기
# [149 / 2703] 	 5.51% 	 error: 16
# 다음 기사 전 0.6초 대기
# [150 / 2703] 	 5.55% 	 error: 16
# 다음 기사 전 1.2초 대기
# 오류 발생 — index 150: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 151: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [153 / 2703] 	 5.66% 	 error: 18
# 다음 기사 전 1.2초 대기
# [154 / 2703] 	 5.70% 	 error: 18
# 다음 기사 전 0.8초 대기
# [155 / 2703] 	 5.73% 	 error: 18
# 다음 기사 전 0.5초 대기
# [156 / 2703] 	 5.77% 	 error: 18
# 다음 기사 전 0.7초 대기
# [157 / 2703] 	 5.81% 	 error: 18
# 다음 기사 전 1.2초 대기
# [158 / 2703] 	 5.85% 	 error: 18
# 다음 기사 전 0.5초 대기
# [159 / 2703] 	 5.88% 	 error: 18
# 다음 기사 전 0.7초 대기
# [160 / 2703] 	 5.92% 	 error: 18
# 다음 기사 전 0.5초 대기
# [161 / 2703] 	 5.96% 	 error: 18
# 다음 기사 전 0.6초 대기
# [162 / 2703] 	 5.99% 	 error: 18
# 다음 기사 전 0.8초 대기
# [163 / 2703] 	 6.03% 	 error: 18
# 다음 기사 전 1.0초 대기
# [164 / 2703] 	 6.07% 	 error: 18
# 다음 기사 전 0.6초 대기
# [165 / 2703] 	 6.10% 	 error: 18
# 다음 기사 전 0.6초 대기
# [166 / 2703] 	 6.14% 	 error: 18
# 다음 기사 전 0.6초 대기
# [167 / 2703] 	 6.18% 	 error: 18
# 다음 기사 전 0.6초 대기
# [168 / 2703] 	 6.22% 	 error: 18
# 다음 기사 전 1.0초 대기
# [169 / 2703] 	 6.25% 	 error: 18
# 다음 기사 전 0.6초 대기
# [170 / 2703] 	 6.29% 	 error: 18
# 다음 기사 전 1.0초 대기
# [171 / 2703] 	 6.33% 	 error: 18
# 다음 기사 전 0.5초 대기
# [172 / 2703] 	 6.36% 	 error: 18
# 다음 기사 전 0.9초 대기
# [173 / 2703] 	 6.40% 	 error: 18
# 다음 기사 전 0.4초 대기
# [174 / 2703] 	 6.44% 	 error: 18
# 다음 기사 전 1.1초 대기
# [175 / 2703] 	 6.47% 	 error: 18
# 다음 기사 전 0.9초 대기
# [176 / 2703] 	 6.51% 	 error: 18
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 176: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [178 / 2703] 	 6.59% 	 error: 19
# 다음 기사 전 0.4초 대기
# [179 / 2703] 	 6.62% 	 error: 19
# 다음 기사 전 0.6초 대기
# [180 / 2703] 	 6.66% 	 error: 19
# 다음 기사 전 0.9초 대기
# [181 / 2703] 	 6.70% 	 error: 19
# 다음 기사 전 0.6초 대기
# [182 / 2703] 	 6.73% 	 error: 19
# 다음 기사 전 1.1초 대기
# [183 / 2703] 	 6.77% 	 error: 19
# 다음 기사 전 1.0초 대기
# [184 / 2703] 	 6.81% 	 error: 19
# 다음 기사 전 1.1초 대기
# [185 / 2703] 	 6.84% 	 error: 19
# 다음 기사 전 0.7초 대기
# [186 / 2703] 	 6.88% 	 error: 19
# 다음 기사 전 0.5초 대기
# [187 / 2703] 	 6.92% 	 error: 19
# 다음 기사 전 0.4초 대기
# [188 / 2703] 	 6.96% 	 error: 19
# 다음 기사 전 0.6초 대기
# [189 / 2703] 	 6.99% 	 error: 19
# 다음 기사 전 1.0초 대기
# 오류 발생 — index 189: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [191 / 2703] 	 7.07% 	 error: 20
# 다음 기사 전 0.4초 대기
# [192 / 2703] 	 7.10% 	 error: 20
# 다음 기사 전 0.4초 대기
# [193 / 2703] 	 7.14% 	 error: 20
# 다음 기사 전 0.8초 대기
# [194 / 2703] 	 7.18% 	 error: 20
# 다음 기사 전 0.8초 대기
# [195 / 2703] 	 7.21% 	 error: 20
# 다음 기사 전 0.5초 대기
# [196 / 2703] 	 7.25% 	 error: 20
# 다음 기사 전 1.2초 대기
# [197 / 2703] 	 7.29% 	 error: 20
# 다음 기사 전 0.5초 대기
# [198 / 2703] 	 7.33% 	 error: 20
# 다음 기사 전 0.5초 대기
# [199 / 2703] 	 7.36% 	 error: 20
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 199: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [201 / 2703] 	 7.44% 	 error: 21
# 다음 기사 전 1.2초 대기
# 오류 발생 — index 201: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 202: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [204 / 2703] 	 7.55% 	 error: 23
# 다음 기사 전 0.9초 대기
# 오류 발생 — index 204: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 205: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [207 / 2703] 	 7.66% 	 error: 25
# 다음 기사 전 1.2초 대기
# 오류 발생 — index 207: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [209 / 2703] 	 7.73% 	 error: 26
# 다음 기사 전 0.7초 대기
# [210 / 2703] 	 7.77% 	 error: 26
# 다음 기사 전 1.1초 대기
# [211 / 2703] 	 7.81% 	 error: 26
# 다음 기사 전 1.0초 대기
# [212 / 2703] 	 7.84% 	 error: 26
# 다음 기사 전 0.6초 대기
# [213 / 2703] 	 7.88% 	 error: 26
# 다음 기사 전 0.9초 대기
# [214 / 2703] 	 7.92% 	 error: 26
# 다음 기사 전 1.0초 대기
# [215 / 2703] 	 7.95% 	 error: 26
# 다음 기사 전 1.2초 대기
# [216 / 2703] 	 7.99% 	 error: 26
# 다음 기사 전 0.9초 대기
# 오류 발생 — index 216: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 217: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [219 / 2703] 	 8.10% 	 error: 28
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 219: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [221 / 2703] 	 8.18% 	 error: 29
# 다음 기사 전 1.0초 대기
# 오류 발생 — index 221: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [223 / 2703] 	 8.25% 	 error: 30
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 223: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 224: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [226 / 2703] 	 8.36% 	 error: 32
# 다음 기사 전 0.6초 대기
# [227 / 2703] 	 8.40% 	 error: 32
# 다음 기사 전 1.1초 대기
# [228 / 2703] 	 8.44% 	 error: 32
# 다음 기사 전 0.8초 대기
# [229 / 2703] 	 8.47% 	 error: 32
# 다음 기사 전 0.5초 대기
# [230 / 2703] 	 8.51% 	 error: 32
# 다음 기사 전 0.7초 대기
# [231 / 2703] 	 8.55% 	 error: 32
# 다음 기사 전 0.8초 대기
# [232 / 2703] 	 8.58% 	 error: 32
# 다음 기사 전 1.1초 대기
# [233 / 2703] 	 8.62% 	 error: 32
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 233: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [235 / 2703] 	 8.69% 	 error: 33
# 다음 기사 전 0.9초 대기
# 오류 발생 — index 235: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [237 / 2703] 	 8.77% 	 error: 34
# 다음 기사 전 0.6초 대기
# [238 / 2703] 	 8.81% 	 error: 34
# 다음 기사 전 0.6초 대기
# [239 / 2703] 	 8.84% 	 error: 34
# 다음 기사 전 0.5초 대기
# [240 / 2703] 	 8.88% 	 error: 34
# 다음 기사 전 0.5초 대기
# [241 / 2703] 	 8.92% 	 error: 34
# 다음 기사 전 1.0초 대기
# [242 / 2703] 	 8.95% 	 error: 34
# 다음 기사 전 0.9초 대기
# [243 / 2703] 	 8.99% 	 error: 34
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 243: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [245 / 2703] 	 9.06% 	 error: 35
# 다음 기사 전 0.9초 대기
# [246 / 2703] 	 9.10% 	 error: 35
# 다음 기사 전 0.7초 대기
# [247 / 2703] 	 9.14% 	 error: 35
# 다음 기사 전 0.4초 대기
# [248 / 2703] 	 9.17% 	 error: 35
# 다음 기사 전 0.8초 대기
# [249 / 2703] 	 9.21% 	 error: 35
# 다음 기사 전 0.7초 대기
# [250 / 2703] 	 9.25% 	 error: 35
# 다음 기사 전 0.8초 대기
# [251 / 2703] 	 9.29% 	 error: 35
# 다음 기사 전 0.6초 대기
# [252 / 2703] 	 9.32% 	 error: 35
# 다음 기사 전 0.5초 대기
# [253 / 2703] 	 9.36% 	 error: 35
# 다음 기사 전 0.5초 대기
# [254 / 2703] 	 9.40% 	 error: 35
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 254: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [256 / 2703] 	 9.47% 	 error: 36
# 다음 기사 전 1.0초 대기
# [257 / 2703] 	 9.51% 	 error: 36
# 다음 기사 전 1.2초 대기
# [258 / 2703] 	 9.54% 	 error: 36
# 다음 기사 전 1.1초 대기
# [259 / 2703] 	 9.58% 	 error: 36
# 다음 기사 전 0.6초 대기
# [260 / 2703] 	 9.62% 	 error: 36
# 다음 기사 전 0.9초 대기
# [261 / 2703] 	 9.66% 	 error: 36
# 다음 기사 전 0.9초 대기
# [262 / 2703] 	 9.69% 	 error: 36
# 다음 기사 전 0.5초 대기
# [263 / 2703] 	 9.73% 	 error: 36
# 다음 기사 전 0.5초 대기
# [264 / 2703] 	 9.77% 	 error: 36
# 다음 기사 전 1.1초 대기
# [265 / 2703] 	 9.80% 	 error: 36
# 다음 기사 전 1.0초 대기
# [266 / 2703] 	 9.84% 	 error: 36
# 다음 기사 전 1.1초 대기
# [267 / 2703] 	 9.88% 	 error: 36
# 다음 기사 전 0.4초 대기
# [268 / 2703] 	 9.91% 	 error: 36
# 다음 기사 전 0.9초 대기
# [269 / 2703] 	 9.95% 	 error: 36
# 다음 기사 전 0.7초 대기
# [270 / 2703] 	 9.99% 	 error: 36
# 다음 기사 전 1.0초 대기
# [271 / 2703] 	 10.03% 	 error: 36
# 다음 기사 전 0.4초 대기
# [272 / 2703] 	 10.06% 	 error: 36
# 다음 기사 전 0.7초 대기
# [273 / 2703] 	 10.10% 	 error: 36
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 273: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 274: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [276 / 2703] 	 10.21% 	 error: 38
# 다음 기사 전 1.0초 대기
# [277 / 2703] 	 10.25% 	 error: 38
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 277: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 278: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 279: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 280: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 281: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [283 / 2703] 	 10.47% 	 error: 43
# 다음 기사 전 0.8초 대기
# [284 / 2703] 	 10.51% 	 error: 43
# 다음 기사 전 0.7초 대기
# [285 / 2703] 	 10.54% 	 error: 43
# 다음 기사 전 0.6초 대기
# [286 / 2703] 	 10.58% 	 error: 43
# 다음 기사 전 0.6초 대기
# [287 / 2703] 	 10.62% 	 error: 43
# 다음 기사 전 1.1초 대기
# [288 / 2703] 	 10.65% 	 error: 43
# 다음 기사 전 1.2초 대기
# [289 / 2703] 	 10.69% 	 error: 43
# 다음 기사 전 0.8초 대기
# [290 / 2703] 	 10.73% 	 error: 43
# 다음 기사 전 1.1초 대기
# [291 / 2703] 	 10.77% 	 error: 43
# 다음 기사 전 1.2초 대기
# [292 / 2703] 	 10.80% 	 error: 43
# 다음 기사 전 0.6초 대기
# [293 / 2703] 	 10.84% 	 error: 43
# 다음 기사 전 0.9초 대기
# [294 / 2703] 	 10.88% 	 error: 43
# 다음 기사 전 0.4초 대기
# [295 / 2703] 	 10.91% 	 error: 43
# 다음 기사 전 1.2초 대기
# [296 / 2703] 	 10.95% 	 error: 43
# 다음 기사 전 0.7초 대기
# [297 / 2703] 	 10.99% 	 error: 43
# 다음 기사 전 0.9초 대기
# [298 / 2703] 	 11.02% 	 error: 43
# 다음 기사 전 1.2초 대기
# [299 / 2703] 	 11.06% 	 error: 43
# 다음 기사 전 0.5초 대기
# [300 / 2703] 	 11.10% 	 error: 43
# 다음 기사 전 0.4초 대기
# [301 / 2703] 	 11.14% 	 error: 43
# 다음 기사 전 1.1초 대기
# [302 / 2703] 	 11.17% 	 error: 43
# 다음 기사 전 1.2초 대기
# [303 / 2703] 	 11.21% 	 error: 43
# 다음 기사 전 0.5초 대기
# [304 / 2703] 	 11.25% 	 error: 43
# 다음 기사 전 0.5초 대기
# [305 / 2703] 	 11.28% 	 error: 43
# 다음 기사 전 1.2초 대기
# [306 / 2703] 	 11.32% 	 error: 43
# 다음 기사 전 0.7초 대기
# [307 / 2703] 	 11.36% 	 error: 43
# 다음 기사 전 0.7초 대기
# [308 / 2703] 	 11.39% 	 error: 43
# 다음 기사 전 0.6초 대기
# [309 / 2703] 	 11.43% 	 error: 43
# 다음 기사 전 0.8초 대기
# [310 / 2703] 	 11.47% 	 error: 43
# 다음 기사 전 0.6초 대기
# [311 / 2703] 	 11.51% 	 error: 43
# 다음 기사 전 0.5초 대기
# [312 / 2703] 	 11.54% 	 error: 43
# 다음 기사 전 1.0초 대기
# [313 / 2703] 	 11.58% 	 error: 43
# 다음 기사 전 0.8초 대기
# [314 / 2703] 	 11.62% 	 error: 43
# 다음 기사 전 0.7초 대기
# [315 / 2703] 	 11.65% 	 error: 43
# 다음 기사 전 0.4초 대기
# [316 / 2703] 	 11.69% 	 error: 43
# 다음 기사 전 0.8초 대기
# [317 / 2703] 	 11.73% 	 error: 43
# 다음 기사 전 1.0초 대기
# [318 / 2703] 	 11.76% 	 error: 43
# 다음 기사 전 1.2초 대기
# [319 / 2703] 	 11.80% 	 error: 43
# 다음 기사 전 0.5초 대기
# [320 / 2703] 	 11.84% 	 error: 43
# 다음 기사 전 1.1초 대기
# [321 / 2703] 	 11.88% 	 error: 43
# 다음 기사 전 0.5초 대기
# [322 / 2703] 	 11.91% 	 error: 43
# 다음 기사 전 0.5초 대기
# [323 / 2703] 	 11.95% 	 error: 43
# 다음 기사 전 0.9초 대기
# [324 / 2703] 	 11.99% 	 error: 43
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 324: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [326 / 2703] 	 12.06% 	 error: 44
# 다음 기사 전 1.1초 대기
# [327 / 2703] 	 12.10% 	 error: 44
# 다음 기사 전 1.1초 대기
# [328 / 2703] 	 12.13% 	 error: 44
# 다음 기사 전 0.5초 대기
# [329 / 2703] 	 12.17% 	 error: 44
# 다음 기사 전 1.0초 대기
# [330 / 2703] 	 12.21% 	 error: 44
# 다음 기사 전 0.6초 대기
# [331 / 2703] 	 12.25% 	 error: 44
# 다음 기사 전 0.5초 대기
# [332 / 2703] 	 12.28% 	 error: 44
# 다음 기사 전 0.8초 대기
# [333 / 2703] 	 12.32% 	 error: 44
# 다음 기사 전 0.6초 대기
# [334 / 2703] 	 12.36% 	 error: 44
# 다음 기사 전 0.8초 대기
# [335 / 2703] 	 12.39% 	 error: 44
# 다음 기사 전 0.9초 대기
# [336 / 2703] 	 12.43% 	 error: 44
# 다음 기사 전 0.9초 대기
# [337 / 2703] 	 12.47% 	 error: 44
# 다음 기사 전 0.4초 대기
# [338 / 2703] 	 12.50% 	 error: 44
# 다음 기사 전 0.7초 대기
# [339 / 2703] 	 12.54% 	 error: 44
# 다음 기사 전 0.6초 대기
# [340 / 2703] 	 12.58% 	 error: 44
# 다음 기사 전 0.7초 대기
# [341 / 2703] 	 12.62% 	 error: 44
# 다음 기사 전 0.6초 대기
# [342 / 2703] 	 12.65% 	 error: 44
# 다음 기사 전 0.9초 대기
# [343 / 2703] 	 12.69% 	 error: 44
# 다음 기사 전 0.8초 대기
# [344 / 2703] 	 12.73% 	 error: 44
# 다음 기사 전 1.0초 대기
# [345 / 2703] 	 12.76% 	 error: 44
# 다음 기사 전 0.7초 대기
# [346 / 2703] 	 12.80% 	 error: 44
# 다음 기사 전 0.5초 대기
# [347 / 2703] 	 12.84% 	 error: 44
# 다음 기사 전 0.7초 대기
# [348 / 2703] 	 12.87% 	 error: 44
# 다음 기사 전 0.7초 대기
# [349 / 2703] 	 12.91% 	 error: 44
# 다음 기사 전 0.9초 대기
# [350 / 2703] 	 12.95% 	 error: 44
# 다음 기사 전 0.7초 대기
# [351 / 2703] 	 12.99% 	 error: 44
# 다음 기사 전 1.1초 대기
# [352 / 2703] 	 13.02% 	 error: 44
# 다음 기사 전 1.1초 대기
# [353 / 2703] 	 13.06% 	 error: 44
# 다음 기사 전 1.1초 대기
# [354 / 2703] 	 13.10% 	 error: 44
# 다음 기사 전 0.6초 대기
# [355 / 2703] 	 13.13% 	 error: 44
# 다음 기사 전 0.4초 대기
# 오류 발생 — index 355: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [357 / 2703] 	 13.21% 	 error: 45
# 다음 기사 전 0.5초 대기
# [358 / 2703] 	 13.24% 	 error: 45
# 다음 기사 전 1.1초 대기
# [359 / 2703] 	 13.28% 	 error: 45
# 다음 기사 전 0.4초 대기
# [360 / 2703] 	 13.32% 	 error: 45
# 다음 기사 전 0.8초 대기
# [361 / 2703] 	 13.36% 	 error: 45
# 다음 기사 전 1.0초 대기
# [362 / 2703] 	 13.39% 	 error: 45
# 다음 기사 전 0.5초 대기
# [363 / 2703] 	 13.43% 	 error: 45
# 다음 기사 전 1.0초 대기
# [364 / 2703] 	 13.47% 	 error: 45
# 다음 기사 전 0.5초 대기
# [365 / 2703] 	 13.50% 	 error: 45
# 다음 기사 전 0.6초 대기
# [366 / 2703] 	 13.54% 	 error: 45
# 다음 기사 전 0.9초 대기
# [367 / 2703] 	 13.58% 	 error: 45
# 다음 기사 전 0.7초 대기
# [368 / 2703] 	 13.61% 	 error: 45
# 다음 기사 전 1.2초 대기
# [369 / 2703] 	 13.65% 	 error: 45
# 다음 기사 전 0.6초 대기
# [370 / 2703] 	 13.69% 	 error: 45
# 다음 기사 전 1.0초 대기
# [371 / 2703] 	 13.73% 	 error: 45
# 다음 기사 전 0.9초 대기
# [372 / 2703] 	 13.76% 	 error: 45
# 다음 기사 전 0.7초 대기
# [373 / 2703] 	 13.80% 	 error: 45
# 다음 기사 전 1.0초 대기
# 오류 발생 — index 373: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [375 / 2703] 	 13.87% 	 error: 46
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 375: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 376: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 377: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [379 / 2703] 	 14.02% 	 error: 49
# 다음 기사 전 1.0초 대기
# 오류 발생 — index 379: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [381 / 2703] 	 14.10% 	 error: 50
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 381: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [383 / 2703] 	 14.17% 	 error: 51
# 다음 기사 전 0.5초 대기
# [384 / 2703] 	 14.21% 	 error: 51
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 384: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 385: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [387 / 2703] 	 14.32% 	 error: 53
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 387: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 388: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 389: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [391 / 2703] 	 14.47% 	 error: 56
# 다음 기사 전 0.5초 대기
# [392 / 2703] 	 14.50% 	 error: 56
# 다음 기사 전 0.8초 대기
# [393 / 2703] 	 14.54% 	 error: 56
# 다음 기사 전 0.9초 대기
# [394 / 2703] 	 14.58% 	 error: 56
# 다음 기사 전 1.0초 대기
# [395 / 2703] 	 14.61% 	 error: 56
# 다음 기사 전 1.0초 대기
# [396 / 2703] 	 14.65% 	 error: 56
# 다음 기사 전 1.1초 대기
# [397 / 2703] 	 14.69% 	 error: 56
# 다음 기사 전 1.1초 대기
# [398 / 2703] 	 14.72% 	 error: 56
# 다음 기사 전 0.8초 대기
# [399 / 2703] 	 14.76% 	 error: 56
# 다음 기사 전 0.5초 대기
# [400 / 2703] 	 14.80% 	 error: 56
# 체크포인트 저장 — 400건 완료
# 다음 기사 전 1.2초 대기
# [401 / 2703] 	 14.84% 	 error: 56
# 다음 기사 전 1.0초 대기
# [402 / 2703] 	 14.87% 	 error: 56
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 402: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [404 / 2703] 	 14.95% 	 error: 57
# 다음 기사 전 1.1초 대기
# [405 / 2703] 	 14.98% 	 error: 57
# 다음 기사 전 0.7초 대기
# [406 / 2703] 	 15.02% 	 error: 57
# 다음 기사 전 0.5초 대기
# [407 / 2703] 	 15.06% 	 error: 57
# 다음 기사 전 0.5초 대기
# [408 / 2703] 	 15.09% 	 error: 57
# 다음 기사 전 0.7초 대기
# [409 / 2703] 	 15.13% 	 error: 57
# 다음 기사 전 1.0초 대기
# [410 / 2703] 	 15.17% 	 error: 57
# 다음 기사 전 1.1초 대기
# [411 / 2703] 	 15.21% 	 error: 57
# 다음 기사 전 0.5초 대기
# [412 / 2703] 	 15.24% 	 error: 57
# 다음 기사 전 0.9초 대기
# [413 / 2703] 	 15.28% 	 error: 57
# 다음 기사 전 0.8초 대기
# [414 / 2703] 	 15.32% 	 error: 57
# 다음 기사 전 0.8초 대기
# [415 / 2703] 	 15.35% 	 error: 57
# 다음 기사 전 0.6초 대기
# [416 / 2703] 	 15.39% 	 error: 57
# 다음 기사 전 0.9초 대기
# [417 / 2703] 	 15.43% 	 error: 57
# 다음 기사 전 0.5초 대기
# [418 / 2703] 	 15.46% 	 error: 57
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 418: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [420 / 2703] 	 15.54% 	 error: 58
# 다음 기사 전 1.1초 대기
# [421 / 2703] 	 15.58% 	 error: 58
# 다음 기사 전 0.4초 대기
# [422 / 2703] 	 15.61% 	 error: 58
# 다음 기사 전 0.8초 대기
# [423 / 2703] 	 15.65% 	 error: 58
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 423: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [425 / 2703] 	 15.72% 	 error: 59
# 다음 기사 전 1.0초 대기
# [426 / 2703] 	 15.76% 	 error: 59
# 다음 기사 전 1.1초 대기
# [427 / 2703] 	 15.80% 	 error: 59
# 다음 기사 전 0.6초 대기
# [428 / 2703] 	 15.83% 	 error: 59
# 다음 기사 전 0.6초 대기
# [429 / 2703] 	 15.87% 	 error: 59
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 429: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [431 / 2703] 	 15.95% 	 error: 60
# 다음 기사 전 0.9초 대기
# [432 / 2703] 	 15.98% 	 error: 60
# 다음 기사 전 0.8초 대기
# [433 / 2703] 	 16.02% 	 error: 60
# 다음 기사 전 1.0초 대기
# [434 / 2703] 	 16.06% 	 error: 60
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 434: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [436 / 2703] 	 16.13% 	 error: 61
# 다음 기사 전 1.1초 대기
# [437 / 2703] 	 16.17% 	 error: 61
# 다음 기사 전 0.5초 대기
# [438 / 2703] 	 16.20% 	 error: 61
# 다음 기사 전 0.9초 대기
# [439 / 2703] 	 16.24% 	 error: 61
# 다음 기사 전 0.7초 대기
# [440 / 2703] 	 16.28% 	 error: 61
# 다음 기사 전 1.0초 대기
# [441 / 2703] 	 16.32% 	 error: 61
# 다음 기사 전 0.6초 대기
# [442 / 2703] 	 16.35% 	 error: 61
# 다음 기사 전 1.1초 대기
# [443 / 2703] 	 16.39% 	 error: 61
# 다음 기사 전 1.2초 대기
# [444 / 2703] 	 16.43% 	 error: 61
# 다음 기사 전 0.8초 대기
# [445 / 2703] 	 16.46% 	 error: 61
# 다음 기사 전 0.8초 대기
# [446 / 2703] 	 16.50% 	 error: 61
# 다음 기사 전 0.5초 대기
# [447 / 2703] 	 16.54% 	 error: 61
# 다음 기사 전 0.4초 대기
# [448 / 2703] 	 16.57% 	 error: 61
# 다음 기사 전 0.9초 대기
# [449 / 2703] 	 16.61% 	 error: 61
# 다음 기사 전 0.4초 대기
# [450 / 2703] 	 16.65% 	 error: 61
# 다음 기사 전 1.0초 대기
# [451 / 2703] 	 16.69% 	 error: 61
# 다음 기사 전 1.1초 대기
# [452 / 2703] 	 16.72% 	 error: 61
# 다음 기사 전 0.7초 대기
# [453 / 2703] 	 16.76% 	 error: 61
# 다음 기사 전 0.9초 대기
# 오류 발생 — index 453: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [455 / 2703] 	 16.83% 	 error: 62
# 다음 기사 전 0.5초 대기
# [456 / 2703] 	 16.87% 	 error: 62
# 다음 기사 전 0.4초 대기
# [457 / 2703] 	 16.91% 	 error: 62
# 다음 기사 전 1.0초 대기
# [458 / 2703] 	 16.94% 	 error: 62
# 다음 기사 전 0.4초 대기
# [459 / 2703] 	 16.98% 	 error: 62
# 다음 기사 전 0.7초 대기
# [460 / 2703] 	 17.02% 	 error: 62
# 다음 기사 전 0.6초 대기
# [461 / 2703] 	 17.06% 	 error: 62
# 다음 기사 전 1.1초 대기
# [462 / 2703] 	 17.09% 	 error: 62
# 다음 기사 전 0.4초 대기
# [463 / 2703] 	 17.13% 	 error: 62
# 다음 기사 전 0.6초 대기
# [464 / 2703] 	 17.17% 	 error: 62
# 다음 기사 전 0.9초 대기
# [465 / 2703] 	 17.20% 	 error: 62
# 다음 기사 전 0.7초 대기
# [466 / 2703] 	 17.24% 	 error: 62
# 다음 기사 전 1.1초 대기
# [467 / 2703] 	 17.28% 	 error: 62
# 다음 기사 전 0.7초 대기
# [468 / 2703] 	 17.31% 	 error: 62
# 다음 기사 전 0.6초 대기
# [469 / 2703] 	 17.35% 	 error: 62
# 다음 기사 전 0.8초 대기
# [470 / 2703] 	 17.39% 	 error: 62
# 다음 기사 전 0.7초 대기
# [471 / 2703] 	 17.43% 	 error: 62
# 다음 기사 전 0.5초 대기
# [472 / 2703] 	 17.46% 	 error: 62
# 다음 기사 전 0.4초 대기
# [473 / 2703] 	 17.50% 	 error: 62
# 다음 기사 전 1.1초 대기
# [474 / 2703] 	 17.54% 	 error: 62
# 다음 기사 전 0.9초 대기
# [475 / 2703] 	 17.57% 	 error: 62
# 다음 기사 전 1.1초 대기
# [476 / 2703] 	 17.61% 	 error: 62
# 다음 기사 전 0.9초 대기
# [477 / 2703] 	 17.65% 	 error: 62
# 다음 기사 전 0.5초 대기
# [478 / 2703] 	 17.68% 	 error: 62
# 다음 기사 전 1.1초 대기
# [479 / 2703] 	 17.72% 	 error: 62
# 다음 기사 전 1.1초 대기
# [480 / 2703] 	 17.76% 	 error: 62
# 다음 기사 전 0.8초 대기
# [481 / 2703] 	 17.80% 	 error: 62
# 다음 기사 전 0.6초 대기
# [482 / 2703] 	 17.83% 	 error: 62
# 다음 기사 전 0.8초 대기
# [483 / 2703] 	 17.87% 	 error: 62
# 다음 기사 전 1.1초 대기
# [484 / 2703] 	 17.91% 	 error: 62
# 다음 기사 전 1.1초 대기
# [485 / 2703] 	 17.94% 	 error: 62
# 다음 기사 전 0.4초 대기
# [486 / 2703] 	 17.98% 	 error: 62
# 다음 기사 전 1.0초 대기
# [487 / 2703] 	 18.02% 	 error: 62
# 다음 기사 전 0.9초 대기
# [488 / 2703] 	 18.05% 	 error: 62
# 다음 기사 전 0.6초 대기
# [489 / 2703] 	 18.09% 	 error: 62
# 다음 기사 전 0.4초 대기
# [490 / 2703] 	 18.13% 	 error: 62
# 다음 기사 전 0.8초 대기
# [491 / 2703] 	 18.17% 	 error: 62
# 다음 기사 전 0.9초 대기
# [492 / 2703] 	 18.20% 	 error: 62
# 다음 기사 전 0.8초 대기
# [493 / 2703] 	 18.24% 	 error: 62
# 다음 기사 전 1.0초 대기
# [494 / 2703] 	 18.28% 	 error: 62
# 다음 기사 전 0.9초 대기
# [495 / 2703] 	 18.31% 	 error: 62
# 다음 기사 전 0.6초 대기
# [496 / 2703] 	 18.35% 	 error: 62
# 다음 기사 전 1.1초 대기
# [497 / 2703] 	 18.39% 	 error: 62
# 다음 기사 전 0.8초 대기
# [498 / 2703] 	 18.42% 	 error: 62
# 다음 기사 전 0.7초 대기
# [499 / 2703] 	 18.46% 	 error: 62
# 다음 기사 전 1.2초 대기
# [500 / 2703] 	 18.50% 	 error: 62
# 다음 기사 전 0.7초 대기
# [501 / 2703] 	 18.53% 	 error: 62
# 다음 기사 전 0.7초 대기
# [502 / 2703] 	 18.57% 	 error: 62
# 다음 기사 전 0.9초 대기
# [503 / 2703] 	 18.61% 	 error: 62
# 다음 기사 전 0.8초 대기
# [504 / 2703] 	 18.65% 	 error: 62
# 다음 기사 전 0.6초 대기
# [505 / 2703] 	 18.68% 	 error: 62
# 다음 기사 전 0.8초 대기
# [506 / 2703] 	 18.72% 	 error: 62
# 다음 기사 전 0.4초 대기
# [507 / 2703] 	 18.76% 	 error: 62
# 다음 기사 전 0.6초 대기
# [508 / 2703] 	 18.79% 	 error: 62
# 다음 기사 전 0.7초 대기
# [509 / 2703] 	 18.83% 	 error: 62
# 다음 기사 전 1.0초 대기
# [510 / 2703] 	 18.87% 	 error: 62
# 다음 기사 전 0.8초 대기
# [511 / 2703] 	 18.90% 	 error: 62
# 다음 기사 전 0.6초 대기
# [512 / 2703] 	 18.94% 	 error: 62
# 다음 기사 전 0.7초 대기
# [513 / 2703] 	 18.98% 	 error: 62
# 다음 기사 전 1.2초 대기
# [514 / 2703] 	 19.02% 	 error: 62
# 다음 기사 전 1.0초 대기
# [515 / 2703] 	 19.05% 	 error: 62
# 다음 기사 전 0.5초 대기
# [516 / 2703] 	 19.09% 	 error: 62
# 다음 기사 전 1.0초 대기
# [517 / 2703] 	 19.13% 	 error: 62
# 다음 기사 전 0.6초 대기
# [518 / 2703] 	 19.16% 	 error: 62
# 다음 기사 전 0.7초 대기
# [519 / 2703] 	 19.20% 	 error: 62
# 다음 기사 전 1.0초 대기
# [520 / 2703] 	 19.24% 	 error: 62
# 다음 기사 전 0.9초 대기
# [521 / 2703] 	 19.27% 	 error: 62
# 다음 기사 전 0.9초 대기
# [522 / 2703] 	 19.31% 	 error: 62
# 다음 기사 전 1.1초 대기
# [523 / 2703] 	 19.35% 	 error: 62
# 다음 기사 전 0.4초 대기
# [524 / 2703] 	 19.39% 	 error: 62
# 다음 기사 전 0.8초 대기
# [525 / 2703] 	 19.42% 	 error: 62
# 다음 기사 전 0.9초 대기
# [526 / 2703] 	 19.46% 	 error: 62
# 다음 기사 전 0.7초 대기
# [527 / 2703] 	 19.50% 	 error: 62
# 다음 기사 전 0.9초 대기
# 오류 발생 — index 527: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 528: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [530 / 2703] 	 19.61% 	 error: 64
# 다음 기사 전 0.7초 대기
# [531 / 2703] 	 19.64% 	 error: 64
# 다음 기사 전 0.9초 대기
# [532 / 2703] 	 19.68% 	 error: 64
# 다음 기사 전 0.6초 대기
# [533 / 2703] 	 19.72% 	 error: 64
# 다음 기사 전 0.7초 대기
# [534 / 2703] 	 19.76% 	 error: 64
# 다음 기사 전 0.9초 대기
# [535 / 2703] 	 19.79% 	 error: 64
# 다음 기사 전 1.0초 대기
# [536 / 2703] 	 19.83% 	 error: 64
# 다음 기사 전 0.5초 대기
# [537 / 2703] 	 19.87% 	 error: 64
# 다음 기사 전 1.0초 대기
# [538 / 2703] 	 19.90% 	 error: 64
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 538: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [540 / 2703] 	 19.98% 	 error: 65
# 다음 기사 전 0.7초 대기
# [541 / 2703] 	 20.01% 	 error: 65
# 다음 기사 전 0.5초 대기
# [542 / 2703] 	 20.05% 	 error: 65
# 다음 기사 전 0.5초 대기
# [543 / 2703] 	 20.09% 	 error: 65
# 다음 기사 전 0.7초 대기
# [544 / 2703] 	 20.13% 	 error: 65
# 다음 기사 전 0.4초 대기
# [545 / 2703] 	 20.16% 	 error: 65
# 다음 기사 전 0.7초 대기
# [546 / 2703] 	 20.20% 	 error: 65
# 다음 기사 전 0.4초 대기
# [547 / 2703] 	 20.24% 	 error: 65
# 다음 기사 전 0.6초 대기
# [548 / 2703] 	 20.27% 	 error: 65
# 다음 기사 전 0.9초 대기
# [549 / 2703] 	 20.31% 	 error: 65
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 549: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [551 / 2703] 	 20.38% 	 error: 66
# 다음 기사 전 1.0초 대기
# [552 / 2703] 	 20.42% 	 error: 66
# 다음 기사 전 1.0초 대기
# [553 / 2703] 	 20.46% 	 error: 66
# 다음 기사 전 0.9초 대기
# [554 / 2703] 	 20.50% 	 error: 66
# 다음 기사 전 0.7초 대기
# [555 / 2703] 	 20.53% 	 error: 66
# 다음 기사 전 0.5초 대기
# [556 / 2703] 	 20.57% 	 error: 66
# 다음 기사 전 0.7초 대기
# [557 / 2703] 	 20.61% 	 error: 66
# 다음 기사 전 0.6초 대기
# [558 / 2703] 	 20.64% 	 error: 66
# 다음 기사 전 0.4초 대기
# [559 / 2703] 	 20.68% 	 error: 66
# 다음 기사 전 0.4초 대기
# [560 / 2703] 	 20.72% 	 error: 66
# 다음 기사 전 0.4초 대기
# [561 / 2703] 	 20.75% 	 error: 66
# 다음 기사 전 0.6초 대기
# [562 / 2703] 	 20.79% 	 error: 66
# 다음 기사 전 0.7초 대기
# [563 / 2703] 	 20.83% 	 error: 66
# 다음 기사 전 1.1초 대기
# [564 / 2703] 	 20.87% 	 error: 66
# 다음 기사 전 0.7초 대기
# [565 / 2703] 	 20.90% 	 error: 66
# 다음 기사 전 0.7초 대기
# [566 / 2703] 	 20.94% 	 error: 66
# 다음 기사 전 1.0초 대기
# [567 / 2703] 	 20.98% 	 error: 66
# 다음 기사 전 1.2초 대기
# 오류 발생 — index 567: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [569 / 2703] 	 21.05% 	 error: 67
# 다음 기사 전 1.1초 대기
# [570 / 2703] 	 21.09% 	 error: 67
# 다음 기사 전 0.5초 대기
# [571 / 2703] 	 21.12% 	 error: 67
# 다음 기사 전 0.9초 대기
# [572 / 2703] 	 21.16% 	 error: 67
# 다음 기사 전 1.2초 대기
# [573 / 2703] 	 21.20% 	 error: 67
# 다음 기사 전 1.0초 대기
# [574 / 2703] 	 21.24% 	 error: 67
# 다음 기사 전 0.6초 대기
# [575 / 2703] 	 21.27% 	 error: 67
# 다음 기사 전 1.1초 대기
# [576 / 2703] 	 21.31% 	 error: 67
# 다음 기사 전 0.5초 대기
# [577 / 2703] 	 21.35% 	 error: 67
# 다음 기사 전 0.4초 대기
# [578 / 2703] 	 21.38% 	 error: 67
# 다음 기사 전 0.9초 대기
# [579 / 2703] 	 21.42% 	 error: 67
# 다음 기사 전 0.9초 대기
# [580 / 2703] 	 21.46% 	 error: 67
# 다음 기사 전 1.2초 대기
# [581 / 2703] 	 21.49% 	 error: 67
# 다음 기사 전 1.2초 대기
# [582 / 2703] 	 21.53% 	 error: 67
# 다음 기사 전 0.7초 대기
# [583 / 2703] 	 21.57% 	 error: 67
# 다음 기사 전 0.6초 대기
# [584 / 2703] 	 21.61% 	 error: 67
# 다음 기사 전 1.0초 대기
# [585 / 2703] 	 21.64% 	 error: 67
# 다음 기사 전 1.1초 대기
# [586 / 2703] 	 21.68% 	 error: 67
# 다음 기사 전 0.7초 대기
# [587 / 2703] 	 21.72% 	 error: 67
# 다음 기사 전 0.8초 대기
# [588 / 2703] 	 21.75% 	 error: 67
# 다음 기사 전 0.7초 대기
# [589 / 2703] 	 21.79% 	 error: 67
# 다음 기사 전 1.2초 대기
# [590 / 2703] 	 21.83% 	 error: 67
# 다음 기사 전 0.6초 대기
# [591 / 2703] 	 21.86% 	 error: 67
# 다음 기사 전 0.4초 대기
# [592 / 2703] 	 21.90% 	 error: 67
# 다음 기사 전 0.5초 대기
# [593 / 2703] 	 21.94% 	 error: 67
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 593: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [595 / 2703] 	 22.01% 	 error: 68
# 다음 기사 전 0.9초 대기
# [596 / 2703] 	 22.05% 	 error: 68
# 다음 기사 전 0.4초 대기
# [597 / 2703] 	 22.09% 	 error: 68
# 다음 기사 전 0.9초 대기
# [598 / 2703] 	 22.12% 	 error: 68
# 다음 기사 전 0.7초 대기
# [599 / 2703] 	 22.16% 	 error: 68
# 다음 기사 전 0.9초 대기
# [600 / 2703] 	 22.20% 	 error: 68
# 체크포인트 저장 — 600건 완료
# 다음 기사 전 0.4초 대기
# [601 / 2703] 	 22.23% 	 error: 68
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 601: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [603 / 2703] 	 22.31% 	 error: 69
# 다음 기사 전 0.9초 대기
# [604 / 2703] 	 22.35% 	 error: 69
# 다음 기사 전 0.7초 대기
# [605 / 2703] 	 22.38% 	 error: 69
# 다음 기사 전 0.7초 대기
# [606 / 2703] 	 22.42% 	 error: 69
# 다음 기사 전 0.5초 대기
# [607 / 2703] 	 22.46% 	 error: 69
# 다음 기사 전 0.5초 대기
# [608 / 2703] 	 22.49% 	 error: 69
# 다음 기사 전 0.6초 대기
# [609 / 2703] 	 22.53% 	 error: 69
# 다음 기사 전 0.8초 대기
# [610 / 2703] 	 22.57% 	 error: 69
# 다음 기사 전 0.4초 대기
# [611 / 2703] 	 22.60% 	 error: 69
# 다음 기사 전 0.9초 대기
# [612 / 2703] 	 22.64% 	 error: 69
# 다음 기사 전 1.1초 대기
# [613 / 2703] 	 22.68% 	 error: 69
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 613: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [615 / 2703] 	 22.75% 	 error: 70
# 다음 기사 전 1.2초 대기
# [616 / 2703] 	 22.79% 	 error: 70
# 다음 기사 전 0.7초 대기
# [617 / 2703] 	 22.83% 	 error: 70
# 다음 기사 전 0.8초 대기
# [618 / 2703] 	 22.86% 	 error: 70
# 다음 기사 전 0.5초 대기
# [619 / 2703] 	 22.90% 	 error: 70
# 다음 기사 전 0.7초 대기
# [620 / 2703] 	 22.94% 	 error: 70
# 다음 기사 전 1.0초 대기
# [621 / 2703] 	 22.97% 	 error: 70
# 다음 기사 전 0.9초 대기
# [622 / 2703] 	 23.01% 	 error: 70
# 다음 기사 전 0.9초 대기
# [623 / 2703] 	 23.05% 	 error: 70
# 다음 기사 전 0.8초 대기
# [624 / 2703] 	 23.09% 	 error: 70
# 다음 기사 전 1.2초 대기
# [625 / 2703] 	 23.12% 	 error: 70
# 다음 기사 전 0.8초 대기
# [626 / 2703] 	 23.16% 	 error: 70
# 다음 기사 전 0.6초 대기
# [627 / 2703] 	 23.20% 	 error: 70
# 다음 기사 전 0.5초 대기
# [628 / 2703] 	 23.23% 	 error: 70
# 다음 기사 전 0.4초 대기
# [629 / 2703] 	 23.27% 	 error: 70
# 다음 기사 전 1.0초 대기
# [630 / 2703] 	 23.31% 	 error: 70
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 630: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [632 / 2703] 	 23.38% 	 error: 71
# 다음 기사 전 0.7초 대기
# [633 / 2703] 	 23.42% 	 error: 71
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 633: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 634: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 635: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [637 / 2703] 	 23.57% 	 error: 74
# 다음 기사 전 0.9초 대기
# [638 / 2703] 	 23.60% 	 error: 74
# 다음 기사 전 1.1초 대기
# [639 / 2703] 	 23.64% 	 error: 74
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 639: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [641 / 2703] 	 23.71% 	 error: 75
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 641: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [643 / 2703] 	 23.79% 	 error: 76
# 다음 기사 전 0.8초 대기
# [644 / 2703] 	 23.83% 	 error: 76
# 다음 기사 전 0.9초 대기
# [645 / 2703] 	 23.86% 	 error: 76
# 다음 기사 전 1.1초 대기
# [646 / 2703] 	 23.90% 	 error: 76
# 다음 기사 전 1.1초 대기
# [647 / 2703] 	 23.94% 	 error: 76
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 647: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [649 / 2703] 	 24.01% 	 error: 77
# 다음 기사 전 1.2초 대기
# [650 / 2703] 	 24.05% 	 error: 77
# 다음 기사 전 1.1초 대기
# [651 / 2703] 	 24.08% 	 error: 77
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 651: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [653 / 2703] 	 24.16% 	 error: 78
# 다음 기사 전 0.4초 대기
# 오류 발생 — index 653: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [655 / 2703] 	 24.23% 	 error: 79
# 다음 기사 전 0.8초 대기
# 오류 발생 — index 655: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 656: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [658 / 2703] 	 24.34% 	 error: 81
# 다음 기사 전 0.5초 대기
# [659 / 2703] 	 24.38% 	 error: 81
# 다음 기사 전 0.4초 대기
# [660 / 2703] 	 24.42% 	 error: 81
# 다음 기사 전 0.8초 대기
# [661 / 2703] 	 24.45% 	 error: 81
# 다음 기사 전 0.8초 대기
# [662 / 2703] 	 24.49% 	 error: 81
# 다음 기사 전 0.6초 대기
# [663 / 2703] 	 24.53% 	 error: 81
# 다음 기사 전 0.7초 대기
# [664 / 2703] 	 24.57% 	 error: 81
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 664: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [666 / 2703] 	 24.64% 	 error: 82
# 다음 기사 전 0.8초 대기
# [667 / 2703] 	 24.68% 	 error: 82
# 다음 기사 전 0.9초 대기
# [668 / 2703] 	 24.71% 	 error: 82
# 다음 기사 전 0.5초 대기
# [669 / 2703] 	 24.75% 	 error: 82
# 다음 기사 전 0.9초 대기
# [670 / 2703] 	 24.79% 	 error: 82
# 다음 기사 전 1.0초 대기
# [671 / 2703] 	 24.82% 	 error: 82
# 다음 기사 전 0.4초 대기
# [672 / 2703] 	 24.86% 	 error: 82
# 다음 기사 전 1.0초 대기
# [673 / 2703] 	 24.90% 	 error: 82
# 다음 기사 전 0.4초 대기
# [674 / 2703] 	 24.94% 	 error: 82
# 다음 기사 전 1.1초 대기
# [675 / 2703] 	 24.97% 	 error: 82
# 다음 기사 전 0.8초 대기
# [676 / 2703] 	 25.01% 	 error: 82
# 다음 기사 전 0.5초 대기
# [677 / 2703] 	 25.05% 	 error: 82
# 다음 기사 전 0.5초 대기
# [678 / 2703] 	 25.08% 	 error: 82
# 다음 기사 전 0.5초 대기
# [679 / 2703] 	 25.12% 	 error: 82
# 다음 기사 전 0.4초 대기
# [680 / 2703] 	 25.16% 	 error: 82
# 다음 기사 전 0.7초 대기
# [681 / 2703] 	 25.19% 	 error: 82
# 다음 기사 전 0.7초 대기
# [682 / 2703] 	 25.23% 	 error: 82
# 다음 기사 전 0.7초 대기
# [683 / 2703] 	 25.27% 	 error: 82
# 다음 기사 전 0.7초 대기
# [684 / 2703] 	 25.31% 	 error: 82
# 다음 기사 전 0.9초 대기
# [685 / 2703] 	 25.34% 	 error: 82
# 다음 기사 전 0.4초 대기
# [686 / 2703] 	 25.38% 	 error: 82
# 다음 기사 전 0.4초 대기
# [687 / 2703] 	 25.42% 	 error: 82
# 다음 기사 전 0.7초 대기
# [688 / 2703] 	 25.45% 	 error: 82
# 다음 기사 전 0.5초 대기
# [689 / 2703] 	 25.49% 	 error: 82
# 다음 기사 전 1.1초 대기
# [690 / 2703] 	 25.53% 	 error: 82
# 다음 기사 전 0.9초 대기
# [691 / 2703] 	 25.56% 	 error: 82
# 다음 기사 전 0.9초 대기
# [692 / 2703] 	 25.60% 	 error: 82
# 다음 기사 전 0.5초 대기
# [693 / 2703] 	 25.64% 	 error: 82
# 다음 기사 전 0.4초 대기
# 오류 발생 — index 693: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [695 / 2703] 	 25.71% 	 error: 83
# 다음 기사 전 0.8초 대기
# [696 / 2703] 	 25.75% 	 error: 83
# 다음 기사 전 0.7초 대기
# [697 / 2703] 	 25.79% 	 error: 83
# 다음 기사 전 0.5초 대기
# [698 / 2703] 	 25.82% 	 error: 83
# 다음 기사 전 0.4초 대기
# [699 / 2703] 	 25.86% 	 error: 83
# 다음 기사 전 0.5초 대기
# [700 / 2703] 	 25.90% 	 error: 83
# 다음 기사 전 0.9초 대기
# [701 / 2703] 	 25.93% 	 error: 83
# 다음 기사 전 1.0초 대기
# [702 / 2703] 	 25.97% 	 error: 83
# 다음 기사 전 1.0초 대기
# [703 / 2703] 	 26.01% 	 error: 83
# 다음 기사 전 0.6초 대기
# [704 / 2703] 	 26.05% 	 error: 83
# 다음 기사 전 1.0초 대기
# [705 / 2703] 	 26.08% 	 error: 83
# 다음 기사 전 0.6초 대기
# [706 / 2703] 	 26.12% 	 error: 83
# 다음 기사 전 0.7초 대기
# [707 / 2703] 	 26.16% 	 error: 83
# 다음 기사 전 1.0초 대기
# [708 / 2703] 	 26.19% 	 error: 83
# 다음 기사 전 0.6초 대기
# [709 / 2703] 	 26.23% 	 error: 83
# 다음 기사 전 0.5초 대기
# [710 / 2703] 	 26.27% 	 error: 83
# 다음 기사 전 0.5초 대기
# [711 / 2703] 	 26.30% 	 error: 83
# 다음 기사 전 0.6초 대기
# [712 / 2703] 	 26.34% 	 error: 83
# 다음 기사 전 1.0초 대기
# [713 / 2703] 	 26.38% 	 error: 83
# 다음 기사 전 0.9초 대기
# [714 / 2703] 	 26.42% 	 error: 83
# 다음 기사 전 0.4초 대기
# [715 / 2703] 	 26.45% 	 error: 83
# 다음 기사 전 1.1초 대기
# [716 / 2703] 	 26.49% 	 error: 83
# 다음 기사 전 0.4초 대기
# [717 / 2703] 	 26.53% 	 error: 83
# 다음 기사 전 1.0초 대기
# [718 / 2703] 	 26.56% 	 error: 83
# 다음 기사 전 0.7초 대기
# [719 / 2703] 	 26.60% 	 error: 83
# 다음 기사 전 0.8초 대기
# [720 / 2703] 	 26.64% 	 error: 83
# 다음 기사 전 0.5초 대기
# [721 / 2703] 	 26.67% 	 error: 83
# 다음 기사 전 0.5초 대기
# [722 / 2703] 	 26.71% 	 error: 83
# 다음 기사 전 0.6초 대기
# [723 / 2703] 	 26.75% 	 error: 83
# 다음 기사 전 0.6초 대기
# [724 / 2703] 	 26.79% 	 error: 83
# 다음 기사 전 0.7초 대기
# [725 / 2703] 	 26.82% 	 error: 83
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 725: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 726: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [728 / 2703] 	 26.93% 	 error: 85
# 다음 기사 전 0.4초 대기
# [729 / 2703] 	 26.97% 	 error: 85
# 다음 기사 전 0.8초 대기
# [730 / 2703] 	 27.01% 	 error: 85
# 다음 기사 전 0.7초 대기
# [731 / 2703] 	 27.04% 	 error: 85
# 다음 기사 전 0.7초 대기
# [732 / 2703] 	 27.08% 	 error: 85
# 다음 기사 전 1.2초 대기
# [733 / 2703] 	 27.12% 	 error: 85
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 733: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [735 / 2703] 	 27.19% 	 error: 86
# 다음 기사 전 0.8초 대기
# [736 / 2703] 	 27.23% 	 error: 86
# 다음 기사 전 1.0초 대기
# [737 / 2703] 	 27.27% 	 error: 86
# 다음 기사 전 1.2초 대기
# [738 / 2703] 	 27.30% 	 error: 86
# 다음 기사 전 1.2초 대기
# [739 / 2703] 	 27.34% 	 error: 86
# 다음 기사 전 1.2초 대기
# [740 / 2703] 	 27.38% 	 error: 86
# 다음 기사 전 0.6초 대기
# [741 / 2703] 	 27.41% 	 error: 86
# 다음 기사 전 0.9초 대기
# [742 / 2703] 	 27.45% 	 error: 86
# 다음 기사 전 1.1초 대기
# [743 / 2703] 	 27.49% 	 error: 86
# 다음 기사 전 0.9초 대기
# [744 / 2703] 	 27.52% 	 error: 86
# 다음 기사 전 0.5초 대기
# [745 / 2703] 	 27.56% 	 error: 86
# 다음 기사 전 1.1초 대기
# [746 / 2703] 	 27.60% 	 error: 86
# 다음 기사 전 1.1초 대기
# [747 / 2703] 	 27.64% 	 error: 86
# 다음 기사 전 0.8초 대기
# [748 / 2703] 	 27.67% 	 error: 86
# 다음 기사 전 1.0초 대기
# [749 / 2703] 	 27.71% 	 error: 86
# 다음 기사 전 1.0초 대기
# [750 / 2703] 	 27.75% 	 error: 86
# 다음 기사 전 0.8초 대기
# [751 / 2703] 	 27.78% 	 error: 86
# 다음 기사 전 0.9초 대기
# [752 / 2703] 	 27.82% 	 error: 86
# 다음 기사 전 1.1초 대기
# [753 / 2703] 	 27.86% 	 error: 86
# 다음 기사 전 0.6초 대기
# [754 / 2703] 	 27.89% 	 error: 86
# 다음 기사 전 0.5초 대기
# [755 / 2703] 	 27.93% 	 error: 86
# 다음 기사 전 0.4초 대기
# [756 / 2703] 	 27.97% 	 error: 86
# 다음 기사 전 0.6초 대기
# 오류 발생 — index 756: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [758 / 2703] 	 28.04% 	 error: 87
# 다음 기사 전 1.1초 대기
# [759 / 2703] 	 28.08% 	 error: 87
# 다음 기사 전 0.8초 대기
# [760 / 2703] 	 28.12% 	 error: 87
# 다음 기사 전 0.5초 대기
# [761 / 2703] 	 28.15% 	 error: 87
# 다음 기사 전 0.7초 대기
# [762 / 2703] 	 28.19% 	 error: 87
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 762: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [764 / 2703] 	 28.26% 	 error: 88
# 다음 기사 전 0.9초 대기
# [765 / 2703] 	 28.30% 	 error: 88
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 765: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [767 / 2703] 	 28.38% 	 error: 89
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 767: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 768: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [770 / 2703] 	 28.49% 	 error: 91
# 다음 기사 전 1.0초 대기
# [771 / 2703] 	 28.52% 	 error: 91
# 다음 기사 전 0.7초 대기
# [772 / 2703] 	 28.56% 	 error: 91
# 다음 기사 전 0.9초 대기
# [773 / 2703] 	 28.60% 	 error: 91
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 773: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [775 / 2703] 	 28.67% 	 error: 92
# 다음 기사 전 0.5초 대기
# [776 / 2703] 	 28.71% 	 error: 92
# 다음 기사 전 0.7초 대기
# [777 / 2703] 	 28.75% 	 error: 92
# 다음 기사 전 0.8초 대기
# [778 / 2703] 	 28.78% 	 error: 92
# 다음 기사 전 0.7초 대기
# 오류 발생 — index 778: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [780 / 2703] 	 28.86% 	 error: 93
# 다음 기사 전 0.5초 대기
# [781 / 2703] 	 28.89% 	 error: 93
# 다음 기사 전 1.1초 대기
# [782 / 2703] 	 28.93% 	 error: 93
# 다음 기사 전 0.5초 대기
# [783 / 2703] 	 28.97% 	 error: 93
# 다음 기사 전 0.8초 대기
# [784 / 2703] 	 29.00% 	 error: 93
# 다음 기사 전 0.5초 대기
# [785 / 2703] 	 29.04% 	 error: 93
# 다음 기사 전 0.7초 대기
# [786 / 2703] 	 29.08% 	 error: 93
# 다음 기사 전 0.8초 대기
# [787 / 2703] 	 29.12% 	 error: 93
# 다음 기사 전 0.8초 대기
# [788 / 2703] 	 29.15% 	 error: 93
# 다음 기사 전 0.8초 대기
# [789 / 2703] 	 29.19% 	 error: 93
# 다음 기사 전 0.4초 대기
# [790 / 2703] 	 29.23% 	 error: 93
# 다음 기사 전 0.7초 대기
# [791 / 2703] 	 29.26% 	 error: 93
# 다음 기사 전 0.6초 대기
# [792 / 2703] 	 29.30% 	 error: 93
# 다음 기사 전 0.7초 대기
# [793 / 2703] 	 29.34% 	 error: 93
# 다음 기사 전 1.1초 대기
# [794 / 2703] 	 29.37% 	 error: 93
# 다음 기사 전 1.0초 대기
# [795 / 2703] 	 29.41% 	 error: 93
# 다음 기사 전 0.6초 대기
# [796 / 2703] 	 29.45% 	 error: 93
# 다음 기사 전 0.4초 대기
# 오류 발생 — index 796: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [798 / 2703] 	 29.52% 	 error: 94
# 다음 기사 전 1.1초 대기
# [799 / 2703] 	 29.56% 	 error: 94
# 다음 기사 전 0.6초 대기
# [800 / 2703] 	 29.60% 	 error: 94
# 체크포인트 저장 — 800건 완료
# 다음 기사 전 0.6초 대기
# [801 / 2703] 	 29.63% 	 error: 94
# 다음 기사 전 0.7초 대기
# [802 / 2703] 	 29.67% 	 error: 94
# 다음 기사 전 0.9초 대기
# [803 / 2703] 	 29.71% 	 error: 94
# 다음 기사 전 0.4초 대기
# [804 / 2703] 	 29.74% 	 error: 94
# 다음 기사 전 0.5초 대기
# [805 / 2703] 	 29.78% 	 error: 94
# 다음 기사 전 1.0초 대기
# [806 / 2703] 	 29.82% 	 error: 94
# 다음 기사 전 0.6초 대기
# [807 / 2703] 	 29.86% 	 error: 94
# 다음 기사 전 0.8초 대기
# [808 / 2703] 	 29.89% 	 error: 94
# 다음 기사 전 0.9초 대기
# [809 / 2703] 	 29.93% 	 error: 94
# 다음 기사 전 0.6초 대기
# [810 / 2703] 	 29.97% 	 error: 94
# 다음 기사 전 0.6초 대기
# [811 / 2703] 	 30.00% 	 error: 94
# 다음 기사 전 0.9초 대기
# [812 / 2703] 	 30.04% 	 error: 94
# 다음 기사 전 0.9초 대기
# [813 / 2703] 	 30.08% 	 error: 94
# 다음 기사 전 1.1초 대기
# [814 / 2703] 	 30.11% 	 error: 94
# 다음 기사 전 0.6초 대기
# [815 / 2703] 	 30.15% 	 error: 94
# 다음 기사 전 0.6초 대기
# [816 / 2703] 	 30.19% 	 error: 94
# 다음 기사 전 1.0초 대기
# [817 / 2703] 	 30.23% 	 error: 94
# 다음 기사 전 0.6초 대기
# [818 / 2703] 	 30.26% 	 error: 94
# 다음 기사 전 0.7초 대기
# [819 / 2703] 	 30.30% 	 error: 94
# 다음 기사 전 1.1초 대기
# [820 / 2703] 	 30.34% 	 error: 94
# 다음 기사 전 0.6초 대기
# [821 / 2703] 	 30.37% 	 error: 94
# 다음 기사 전 1.1초 대기
# [822 / 2703] 	 30.41% 	 error: 94
# 다음 기사 전 0.7초 대기
# [823 / 2703] 	 30.45% 	 error: 94
# 다음 기사 전 1.0초 대기
# [824 / 2703] 	 30.48% 	 error: 94
# 다음 기사 전 1.0초 대기
# [825 / 2703] 	 30.52% 	 error: 94
# 다음 기사 전 0.9초 대기
# [826 / 2703] 	 30.56% 	 error: 94
# 다음 기사 전 1.2초 대기
# [827 / 2703] 	 30.60% 	 error: 94
# 다음 기사 전 0.5초 대기
# [828 / 2703] 	 30.63% 	 error: 94
# 다음 기사 전 0.4초 대기
# [829 / 2703] 	 30.67% 	 error: 94
# 다음 기사 전 0.8초 대기
# [830 / 2703] 	 30.71% 	 error: 94
# 다음 기사 전 0.9초 대기
# [831 / 2703] 	 30.74% 	 error: 94
# 다음 기사 전 1.1초 대기
# [832 / 2703] 	 30.78% 	 error: 94
# 다음 기사 전 1.2초 대기
# [833 / 2703] 	 30.82% 	 error: 94
# 다음 기사 전 1.2초 대기
# [834 / 2703] 	 30.85% 	 error: 94
# 다음 기사 전 0.4초 대기
# [835 / 2703] 	 30.89% 	 error: 94
# 다음 기사 전 0.6초 대기
# [836 / 2703] 	 30.93% 	 error: 94
# 다음 기사 전 0.5초 대기
# [837 / 2703] 	 30.97% 	 error: 94
# 다음 기사 전 1.0초 대기
# [838 / 2703] 	 31.00% 	 error: 94
# 다음 기사 전 1.0초 대기
# [839 / 2703] 	 31.04% 	 error: 94
# 다음 기사 전 1.1초 대기
# [840 / 2703] 	 31.08% 	 error: 94
# 다음 기사 전 1.0초 대기
# [841 / 2703] 	 31.11% 	 error: 94
# 다음 기사 전 1.1초 대기
# [842 / 2703] 	 31.15% 	 error: 94
# 다음 기사 전 0.9초 대기
# [843 / 2703] 	 31.19% 	 error: 94
# 다음 기사 전 0.6초 대기
# [844 / 2703] 	 31.22% 	 error: 94
# 다음 기사 전 1.1초 대기
# [845 / 2703] 	 31.26% 	 error: 94
# 다음 기사 전 0.6초 대기
# [846 / 2703] 	 31.30% 	 error: 94
# 다음 기사 전 0.7초 대기
# [847 / 2703] 	 31.34% 	 error: 94
# 다음 기사 전 0.7초 대기
# [848 / 2703] 	 31.37% 	 error: 94
# 다음 기사 전 0.9초 대기
# [849 / 2703] 	 31.41% 	 error: 94
# 다음 기사 전 0.6초 대기
# [850 / 2703] 	 31.45% 	 error: 94
# 다음 기사 전 1.2초 대기
# [851 / 2703] 	 31.48% 	 error: 94
# 다음 기사 전 0.8초 대기
# [852 / 2703] 	 31.52% 	 error: 94
# 다음 기사 전 0.9초 대기
# [853 / 2703] 	 31.56% 	 error: 94
# 다음 기사 전 0.5초 대기
# [854 / 2703] 	 31.59% 	 error: 94
# 다음 기사 전 1.0초 대기
# [855 / 2703] 	 31.63% 	 error: 94
# 다음 기사 전 0.9초 대기
# [856 / 2703] 	 31.67% 	 error: 94
# 다음 기사 전 0.6초 대기
# [857 / 2703] 	 31.71% 	 error: 94
# 다음 기사 전 0.8초 대기
# [858 / 2703] 	 31.74% 	 error: 94
# 다음 기사 전 0.8초 대기
# [859 / 2703] 	 31.78% 	 error: 94
# 다음 기사 전 1.0초 대기
# [860 / 2703] 	 31.82% 	 error: 94
# 다음 기사 전 1.1초 대기
# [861 / 2703] 	 31.85% 	 error: 94
# 다음 기사 전 1.1초 대기
# [862 / 2703] 	 31.89% 	 error: 94
# 다음 기사 전 1.2초 대기
# [863 / 2703] 	 31.93% 	 error: 94
# 다음 기사 전 0.5초 대기
# [864 / 2703] 	 31.96% 	 error: 94
# 다음 기사 전 1.0초 대기
# [865 / 2703] 	 32.00% 	 error: 94
# 다음 기사 전 0.9초 대기
# [866 / 2703] 	 32.04% 	 error: 94
# 다음 기사 전 0.6초 대기
# [867 / 2703] 	 32.08% 	 error: 94
# 다음 기사 전 0.6초 대기
# [868 / 2703] 	 32.11% 	 error: 94
# 다음 기사 전 0.5초 대기
# [869 / 2703] 	 32.15% 	 error: 94
# 다음 기사 전 0.7초 대기
# [870 / 2703] 	 32.19% 	 error: 94
# 다음 기사 전 1.0초 대기
# [871 / 2703] 	 32.22% 	 error: 94
# 다음 기사 전 0.6초 대기
# [872 / 2703] 	 32.26% 	 error: 94
# 다음 기사 전 0.6초 대기
# [873 / 2703] 	 32.30% 	 error: 94
# 다음 기사 전 0.9초 대기
# [874 / 2703] 	 32.33% 	 error: 94
# 다음 기사 전 1.0초 대기
# [875 / 2703] 	 32.37% 	 error: 94
# 다음 기사 전 1.2초 대기
# [876 / 2703] 	 32.41% 	 error: 94
# 다음 기사 전 0.9초 대기
# [877 / 2703] 	 32.45% 	 error: 94
# 다음 기사 전 0.8초 대기
# [878 / 2703] 	 32.48% 	 error: 94
# 다음 기사 전 0.5초 대기
# [879 / 2703] 	 32.52% 	 error: 94
# 다음 기사 전 1.1초 대기
# [880 / 2703] 	 32.56% 	 error: 94
# 다음 기사 전 0.6초 대기
# [881 / 2703] 	 32.59% 	 error: 94
# 다음 기사 전 0.5초 대기
# [882 / 2703] 	 32.63% 	 error: 94
# 다음 기사 전 0.8초 대기
# [883 / 2703] 	 32.67% 	 error: 94
# 다음 기사 전 0.6초 대기
# [884 / 2703] 	 32.70% 	 error: 94
# 다음 기사 전 0.7초 대기
# [885 / 2703] 	 32.74% 	 error: 94
# 다음 기사 전 0.6초 대기
# [886 / 2703] 	 32.78% 	 error: 94
# 다음 기사 전 1.0초 대기
# [887 / 2703] 	 32.82% 	 error: 94
# 다음 기사 전 0.6초 대기
# [888 / 2703] 	 32.85% 	 error: 94
# 다음 기사 전 0.7초 대기
# [889 / 2703] 	 32.89% 	 error: 94
# 다음 기사 전 0.4초 대기
# [890 / 2703] 	 32.93% 	 error: 94
# 다음 기사 전 1.2초 대기
# [891 / 2703] 	 32.96% 	 error: 94
# 다음 기사 전 0.4초 대기
# [892 / 2703] 	 33.00% 	 error: 94
# 다음 기사 전 0.9초 대기
# [893 / 2703] 	 33.04% 	 error: 94
# 다음 기사 전 0.9초 대기
# [894 / 2703] 	 33.07% 	 error: 94
# 다음 기사 전 1.0초 대기
# [895 / 2703] 	 33.11% 	 error: 94
# 다음 기사 전 1.1초 대기
# [896 / 2703] 	 33.15% 	 error: 94
# 다음 기사 전 0.6초 대기
# [897 / 2703] 	 33.19% 	 error: 94
# 다음 기사 전 0.6초 대기
# [898 / 2703] 	 33.22% 	 error: 94
# 다음 기사 전 0.4초 대기
# [899 / 2703] 	 33.26% 	 error: 94
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 899: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 900: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 901: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 902: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 903: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 904: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 905: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 906: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [908 / 2703] 	 33.59% 	 error: 102
# 다음 기사 전 1.0초 대기
# 오류 발생 — index 908: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 909: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 910: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [912 / 2703] 	 33.74% 	 error: 105
# 다음 기사 전 0.6초 대기
# [913 / 2703] 	 33.78% 	 error: 105
# 다음 기사 전 0.9초 대기
# [914 / 2703] 	 33.81% 	 error: 105
# 다음 기사 전 0.8초 대기
# [915 / 2703] 	 33.85% 	 error: 105
# 다음 기사 전 0.6초 대기
# [916 / 2703] 	 33.89% 	 error: 105
# 다음 기사 전 0.6초 대기
# [917 / 2703] 	 33.93% 	 error: 105
# 다음 기사 전 0.9초 대기
# [918 / 2703] 	 33.96% 	 error: 105
# 다음 기사 전 1.0초 대기
# [919 / 2703] 	 34.00% 	 error: 105
# 다음 기사 전 0.9초 대기
# [920 / 2703] 	 34.04% 	 error: 105
# 다음 기사 전 1.2초 대기
# [921 / 2703] 	 34.07% 	 error: 105
# 다음 기사 전 0.5초 대기
# [922 / 2703] 	 34.11% 	 error: 105
# 다음 기사 전 0.7초 대기
# [923 / 2703] 	 34.15% 	 error: 105
# 다음 기사 전 0.7초 대기
# [924 / 2703] 	 34.18% 	 error: 105
# 다음 기사 전 0.6초 대기
# [925 / 2703] 	 34.22% 	 error: 105
# 다음 기사 전 1.1초 대기
# 오류 발생 — index 925: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 오류 발생 — index 926: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# ...
# 재시도 실패 — index 387: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 388: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 389: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 402: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 418: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 423: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 429: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 434: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 453: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 527: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 528: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 538: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 549: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 567: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 593: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 601: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 613: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 630: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 633: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 634: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 635: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 639: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 641: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 647: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 651: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 653: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 655: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 656: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 664: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 693: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 725: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 726: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 733: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 756: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 762: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 765: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 767: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 768: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 773: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 778: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 796: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 899: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 900: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 901: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 902: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 903: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 904: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 905: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 906: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 908: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 909: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 910: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 925: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 926: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 940: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 942: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 966: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 972: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 975: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1044: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1045: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1056: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1068: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1095: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1114: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1120: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1150: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1161: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1162: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1164: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1165: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1166: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1168: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1170: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1172: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1178: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1183: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1186: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1189: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1191: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1204: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1235: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1273: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1275: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1283: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1305: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1306: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1309: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1311: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1313: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1314: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1315: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1316: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1320: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1321: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1340: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1461: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1462: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1464: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1467: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1469: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1471: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1472: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1479: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1481: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1482: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1491: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1505: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1510: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1516: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1521: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1533: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1615: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1617: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1629: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1643: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1688: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1698: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1705: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1706: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1715: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1723: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1724: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1727: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1728: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1729: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1775: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1776: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1780: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1804: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1810: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1813: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1814: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1815: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1816: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1817: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1819: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1824: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1843: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1909: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1951: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1952: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1953: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1967: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1972: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1975: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1991: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1999: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2015: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2017: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2023: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2029: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2030: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2033: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2035: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2036: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2037: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2043: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2057: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2058: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2059: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2060: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2062: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2063: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2076: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2081: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2083: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2114: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2126: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2152: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2155: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2160: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2173: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2181: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2190: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2204: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2278: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2280: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2282: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2283: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2286: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2287: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2288: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2289: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2290: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2291: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2292: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2293: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2301: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2307: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2309: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2313: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2320: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2325: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2334: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2357: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2439: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2440: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2453: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2462: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2483: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2505: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2509: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2539: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2553: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2555: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2562: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2564: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2566: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2571: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2573: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2574: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2577: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2579: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2586: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2603: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2636: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2638: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2641: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2665: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2666: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2669: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2670: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2675: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2676: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2677: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2678: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2681: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 2698: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 완료 — 재실패: 282건
# 저장 완료: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_KBS_direct_260505_260511.csv
# 재실패 목록 저장: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_재실패_KBS_direct_260505_260511.json
# 본문 수집 완료 — 총 2421건 / 오류 282건
#
# 전체 작업 완료
# 성공/건너뜀: 1개, 실패: 0개
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_KBS_direct_260505_260511.csv
