# %% [markdown]
# # SBS 뉴스 본문 수집 (BS4 Colab용) — 사이트 직접 / 기간 모드
#
# URL 수집 노트북에서 만든 `링크_{press}_*.json` 파일을 읽어 SBS 사이트(`news.sbs.co.kr`) 본문을 BS4로 추출한다. 통신3사/LPOD 트랙과 동일하게 **기간 단위 통합 CSV** 1개를 만든다 (입력 JSON 1개 → 출력 CSV 1개). SBS는 og:* / article:* 메타 태그가 깨끗하게 들어있어 거의 모든 필드를 메타에서 얻는다.
#
# - 입력: `data/링크_{press}_{YYMMDD}_{YYMMDD}.json` (기간 통합)
# - 출력: `data/본문_bs4_{press}_{YYMMDD}_{YYMMDD}.csv`
# - 보조 출력: 중간 재개용 체크포인트 JSON, 재실패 URL JSON
# - 특징: 기간 단위 통합 수집, 중간 재개, 오류 URL 1회 재시도, 완료 파일 건너뛰기
# - 셀렉터: title=og:title, body=div.text_area[itemprop="articleBody"], pubdate=article:published_time, category=article:section

# %%
# Colab 환경 세팅 — requests, BeautifulSoup 설치
# SBS는 정적 HTML이라 Selenium 불필요, requests + BS4로 충분
# !pip install -q requests beautifulsoup4 pandas

# %%
# Google Drive 마운트 — 중간에 끊겨도 데이터 보존
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Drive 안의 프로젝트 폴더로 이동
# 통신3사 트리와 분리하기 위해 SBS 등 언론사 직접 수집은 news/ 하위에 보관
import os
PROJECT_DIR = '/content/drive/MyDrive/Text-data-Analysis_26-Spring/news'
os.chdir(PROJECT_DIR)
print(f'현재 작업 폴더: {os.getcwd()}')
# Out:
# 현재 작업 폴더: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news

# %%
import json
import os
import random
import re
import time
from datetime import datetime, timedelta
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup

# 로컬/Colab 비교를 위해 User-Agent 고정
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36'

# 담당 언론사와 수집 기간 지정 — 날짜 형식: 'YYYY.MM.DD'
# press 하나당 start_date ~ end_date 안의 일자를 한 통합 CSV로 묶어 저장 (통신3사/LPOD 트랙과 동일 패턴)
# _direct 접미사로 네이버 경유본 본문(`본문_bs4_SBS_*.csv`)과 출력 파일 분리
press_ranges = [
    {'press': 'SBS_direct', 'start_date': '2026.05.05', 'end_date': '2026.05.11'},
]


# 기간 단위 작업 목록 생성 — press_ranges 한 항목당 jobs 1개
# URL 수집 노트북과 같은 시그니처(press/start_date/end_date)를 본문 수집에 그대로 전달
def build_period_jobs(press_ranges):
    jobs = []
    for item in press_ranges:
        # 'YYYY.MM.DD' 문자열을 datetime으로 파싱 — 기간 유효성 검사용
        start = datetime.strptime(item['start_date'], '%Y.%m.%d')
        end = datetime.strptime(item['end_date'], '%Y.%m.%d')
        # 시작 일자가 끝 일자보다 늦으면 작업 범위가 잘못된 것이므로 즉시 중단
        if start > end:
            raise ValueError(f"시작 일자가 끝 일자보다 늦습니다: {item}")
        jobs.append({
            'press': item['press'],
            'start_date': item['start_date'],
            'end_date': item['end_date'],
        })
    return jobs


# 변수 정의 (날짜 형식: 'YYYY.MM.DD')
jobs = build_period_jobs(press_ranges)

print(f'총 작업 수: {len(jobs)}')
for job in jobs:
    print(job)

# 셀 3을 건너뛰고 실행해도 기본 프로젝트 경로를 사용할 수 있게 보완
try:
    PROJECT_DIR
except NameError:
    PROJECT_DIR = '/content/drive/MyDrive/Text-data-Analysis_26-Spring/news'

# 저장할 폴더 지정 — 링크 파일, 체크포인트, 본문 CSV, 실패 목록이 모두 이 폴더에 저장
SAVE_DIR = Path(PROJECT_DIR) / 'notebook' / 'crawling' / 'data'
SAVE_DIR.mkdir(parents=True, exist_ok=True)
print(f'저장 위치: {SAVE_DIR}')

# requests 세션 — User-Agent/Accept-Language를 반복 요청에 일관 적용, TCP/TLS 핸드셰이크 비용 절감
session = requests.Session()
session.headers.update({
    'User-Agent': USER_AGENT,
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
})
print(f'User-Agent: {USER_AGENT}')
# Out:
# 총 작업 수: 1
# {'press': 'SBS_direct', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
# 저장 위치: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36

# %%
# 봇 탐지 방지를 위해 기사/job 사이에 랜덤한 시간을 기다림
ARTICLE_PAUSE_RANGE_SEC = (0.4, 1.2)
JOB_PAUSE_RANGE_SEC = (8, 20)

# 중간에 끊겨도 이어서 수집할 수 있도록 일정 건수마다 체크포인트 저장
CHECKPOINT_INTERVAL = 200
# requests 응답 대기 상한 — SBS 페이지가 늦게 뜨면 끊고 err_idx에 기록
REQUEST_TIMEOUT_SEC = 10
SKIP_COMPLETED = True


# 랜덤 대기 후 로그 출력
def polite_sleep(label, pause_range):
    pause_sec = random.uniform(*pause_range)
    print(f"{label} {pause_sec:.1f}초 대기")
    time.sleep(pause_sec)


# 파일명에 사용할 YYMMDD_YYMMDD 형식 기간 문자열 생성 (통신3사 트랙과 동일 시그니처)
# 예: 2026.05.01 ~ 2026.05.07 -> '260501_260507'
def make_period_suffix(start_date, end_date):
    return f"{start_date.replace('.', '')[2:]}_{end_date.replace('.', '')[2:]}"


# 지정한 meta property의 content 반환 (없으면 빈 문자열)
# SBS는 og:* / article:* 메타가 잘 갖춰져 있어 대부분 필드를 여기서 추출
def meta_content(soup, prop):
    el = soup.select_one(f'meta[property="{prop}"]')
    return el.get('content', '') if el else ''


# 본문 안의 줄바꿈/연속 공백을 하나의 공백으로 정리
def normalize_body_text(text):
    return re.sub(r'\s+', ' ', text).strip()


# 기사 한 건에서 title/body/pubdate/category 추출 (SBS 셀렉터 사용)
# title/body/pubdate 중 하나라도 비면 호출부에서 err_idx로 기록할 수 있도록 ValueError 발생
def extract_article_bs4(link, session=session):
    # SBS 사이트 기사 페이지 HTML 요청 — 정적 HTML이라 requests로 충분
    response = session.get(link, timeout=REQUEST_TIMEOUT_SEC)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')

    # 제목 추출하기 — og:title 메타 태그 (HTML entity는 BS4가 자동 디코딩)
    title = meta_content(soup, 'og:title')

    # 본문 추출하기 — div.text_area[itemprop="articleBody"]
    # schema.org microdata가 잡아주는 SBS 본문 컨테이너
    body_el = soup.select_one('div.text_area[itemprop="articleBody"]')
    body = normalize_body_text(body_el.get_text(' ', strip=True)) if body_el else ''

    # 날짜 추출하기 — article:published_time (ISO 8601, 게시 시각)
    # og:updated_time은 수정 시각이라 5/5에 publish 후 5/14에 수정된 기사도 5/14로 찍힘 → 안 씀
    pubdate = meta_content(soup, 'article:published_time')

    # 카테고리: article:section ('정치', '경제' 등 한글 라벨)
    # SBS 특유의 카테고리 메타 — 네이버의 Nitem_link 탭과 달리 메타 한 줄로 끝
    category = meta_content(soup, 'article:section')

    # 제목/본문/날짜 중 하나라도 없으면 실패 — 호출부에서 err_idx로 기록
    if not title or not body or not pubdate:
        raise ValueError('title/body/pubdate 중 일부를 추출하지 못함')

    return {
        'link': link,
        'pubdate': pubdate,
        'category': category,
        'title': title,
        'body': body,
    }


# 한 언론사의 기간 통합 링크 JSON을 읽어 본문을 수집하고 통합 CSV로 저장
# 체크포인트 기반 재개 + 오류 자동 1회 재시도 + 재실패 URL JSON 저장
def collect_bodies_bs4(press, start_date, end_date, save_dir=SAVE_DIR):
    # 파일명 키로 쓸 기간 접미사 (예: 260501_260507)
    period = make_period_suffix(start_date, end_date)
    # 입력: URL 수집 단계가 만들어 둔 기간 통합 SBS 링크 JSON
    links_path = save_dir / f"링크_{press}_{period}.json"
    # 체크포인트: 중간 결과(all_results) + 오류 인덱스 + 다음 인덱스를 보관
    checkpoint_path = save_dir / f"체크포인트_본문_bs4_{press}_{period}.json"
    # 최종 출력: 기간 통합 본문 CSV (네이버 경유본과 분리하기 위해 press에 _direct 접미사가 붙음)
    csv_save_path = save_dir / f"본문_bs4_{press}_{period}.csv"

    # 최종 CSV가 이미 있으면 같은 기간은 건너뜀 (재실행 시 idempotent)
    if SKIP_COMPLETED and csv_save_path.exists():
        print()
        print(f"=== {press} / {start_date} ~ {end_date} 이미 완료됨, 건너뜀 ===")
        print(f"기존 파일: {csv_save_path}")
        return csv_save_path

    # 링크 파일 불러오기
    if links_path.exists():
        with links_path.open('r', encoding='utf-8') as f:
            sbs_news_links = json.load(f)
        # 기사 한 건당 대략 (랜덤 대기 평균 + 0.7s) 잡은 거친 예상치 — 로그 확인용
        avg_pause_sec = sum(ARTICLE_PAUSE_RANGE_SEC) / 2
        est_sec_per_article = avg_pause_sec + 0.7
        est_min = len(sbs_news_links) * est_sec_per_article / 60
        print()
        print(f"=== {press} / {start_date} ~ {end_date} BS4 본문 수집 시작 ===")
        print(f'링크 {len(sbs_news_links)}개 불러옴: {links_path}')
        print(f'예상 소요 시간: 약 {est_min:.0f}분')
    else:
        raise FileNotFoundError(f'링크 파일 없음 — SBS_직접_url_수집_colab.ipynb를 먼저 실행하세요\n경로: {links_path}')

    # 이전에 중단된 작업이 있으면 이어받기 — next_i 인덱스 다음부터 시작
    if checkpoint_path.exists():
        with checkpoint_path.open('r', encoding='utf-8') as f:
            checkpoint = json.load(f)
        # JSON은 dict 키를 문자열로 저장하므로 int로 다시 변환
        all_results = {int(k): v for k, v in checkpoint.get('all_results', {}).items()}
        err_idx = checkpoint.get('err_idx', [])
        i = checkpoint.get('next_i', 0)
        print(f'체크포인트 발견 — {i}번째부터 이어서 시작 (이미 수집: {len(all_results)}건)')
    else:
        all_results = dict()
        i = 0
        err_idx = []
        print('새로 시작')

    # 본문 수집 메인 루프 — i 인덱스를 함께 들고 다녀 체크포인트와 동기화
    for link in sbs_news_links[i:]:
        try:
            all_results[i] = extract_article_bs4(link)
            # 진행 상황 확인용 코드
            print(f'[{i+1} / {len(sbs_news_links)}] \t {(i+1)/len(sbs_news_links)*100:.2f}% \t error: {len(err_idx)}')
            i += 1
            # 중간저장 — N건마다 체크포인트 갱신해 중간 중단에도 진행 보존
            if i % CHECKPOINT_INTERVAL == 0:
                with checkpoint_path.open('w', encoding='utf-8') as f:
                    json.dump({'all_results': all_results, 'err_idx': err_idx, 'next_i': i}, f, ensure_ascii=False, indent=2)
                print(f'체크포인트 저장 — {i}건 완료')
            polite_sleep('다음 기사 전', ARTICLE_PAUSE_RANGE_SEC)
        except Exception as exc:
            # 오류 인덱스를 err_idx에 누적해두고 즉시 체크포인트도 갱신
            print(f'오류 발생 — index {i}: {exc!r}')
            err_idx.append(i)
            i += 1
            with checkpoint_path.open('w', encoding='utf-8') as f:
                json.dump({'all_results': all_results, 'err_idx': err_idx, 'next_i': i}, f, ensure_ascii=False, indent=2)

    # 1차 오류 자동 재시도 — 페이지가 늦게 떴거나 일시적 네트워크 문제였던 경우를 한 번 더 시도
    if err_idx:
        print()
        print(f'오류 {len(err_idx)}건 재시도 시작...')
        re_err_idx = []
        for retry_i in err_idx:
            try:
                link = sbs_news_links[retry_i]
                all_results[retry_i] = extract_article_bs4(link)
                print(f'재시도 성공 — index {retry_i}')
                polite_sleep('다음 재시도 전', ARTICLE_PAUSE_RANGE_SEC)
            except Exception as exc:
                print(f'재시도 실패 — index {retry_i}: {exc!r}')
                re_err_idx.append(retry_i)
        # 재시도 후에도 실패한 인덱스만 남김 — 본문_bs4_재실패_*.json으로 저장 대상
        err_idx = re_err_idx
        print(f'재시도 완료 — 재실패: {len(err_idx)}건')

    # 수집한 정보들을 dataframe으로 변환
    df = pd.DataFrame(all_results).T
    if df.empty:
        raise ValueError('수집된 본문 데이터가 없습니다.')

    # 수집한 기사들 중 중복인 경우 이를 제거
    df_no_duplicates = df.drop_duplicates().reset_index(drop=True)
    # 오래된 순부터 수집했으나 혹시 모를 상황을 방지하기 위해 pubdate를 datetime으로 변환 후 정렬
    df_no_duplicates['pubdate'] = pd.to_datetime(df_no_duplicates['pubdate'], errors='coerce')
    df_sorted = df_no_duplicates.sort_values(by='pubdate')

    # 수집한 정보들을 csv로 저장 (Google Drive에 저장)
    df_sorted.to_csv(csv_save_path, index=False, encoding='utf-8-sig')
    print(f'저장 완료: {csv_save_path}')

    if err_idx:
        # 재시도 후에도 실패한 URL은 별 JSON으로 떨어뜨려 Selenium 재시도 노트북에서 다시 시도 가능
        failed_path = save_dir / f"본문_bs4_재실패_{press}_{period}.json"
        with failed_path.open('w', encoding='utf-8') as f:
            json.dump({'err_idx': err_idx, 'links': [sbs_news_links[x] for x in err_idx]}, f, ensure_ascii=False, indent=2)
        print(f'재실패 목록 저장: {failed_path}')
    elif checkpoint_path.exists():
        # 재실패가 없을 때만 체크포인트 삭제 — 실패가 남아있으면 디버깅용으로 보존
        checkpoint_path.unlink()

    print(f'본문 수집 완료 — 총 {len(df_sorted)}건 / 오류 {len(err_idx)}건')
    return csv_save_path


# 생성된 jobs를 순서대로 실행
# 한 작업이 실패해도 실패 목록에 기록하고 다음 작업으로 넘어감
results = []
failures = []
for index, job in enumerate(jobs, start=1):
    print()
    print(f"[{index}/{len(jobs)}] 작업 실행: {job}")
    try:
        # job 딕셔너리의 press/start_date/end_date를 collect_bodies_bs4 인자로 전달
        results.append(collect_bodies_bs4(**job))
    except Exception as exc:
        # 한 언론사에서 오류가 나도 전체 작업이 멈추지 않도록 실패 정보만 저장
        failures.append({'job': job, 'error': repr(exc)})
        print(f"작업 실패, 다음 작업으로 넘어감: {exc!r}")
    finally:
        if index < len(jobs):
            # 다음 언론사 job으로 넘어가기 전 대기
            polite_sleep('다음 작업 전', JOB_PAUSE_RANGE_SEC)

# 실패한 작업이 있으면 나중에 다시 돌릴 수 있게 파일로 저장
if failures:
    failures_path = SAVE_DIR / '본문_bs4_수집실패목록_SBS_direct.json'
    with failures_path.open('w', encoding='utf-8') as f:
        json.dump(failures, f, ensure_ascii=False, indent=2)
    print()
    print(f"실패 작업 {len(failures)}개 저장: {failures_path}")

print()
print('전체 작업 완료')
print(f'성공/건너뜀: {len(results)}개, 실패: {len(failures)}개')
for result_path in results:
    print(result_path)
# Out:
# [1/1] 작업 실행: {'press': 'SBS_direct', 'start_date': '2026.05.05', 'end_date': '2026.05.11'}
#
# === SBS_direct / 2026.05.05 ~ 2026.05.11 BS4 본문 수집 시작 ===
# 링크 1795개 불러옴: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/링크_SBS_direct_260505_260511.json
# 예상 소요 시간: 약 45분
# 체크포인트 발견 — 1161번째부터 이어서 시작 (이미 수집: 1154건)
# [1162 / 1795] 	 64.74% 	 error: 7
# 다음 기사 전 1.1초 대기
# [1163 / 1795] 	 64.79% 	 error: 7
# 다음 기사 전 1.1초 대기
# [1164 / 1795] 	 64.85% 	 error: 7
# 다음 기사 전 1.1초 대기
# [1165 / 1795] 	 64.90% 	 error: 7
# 다음 기사 전 0.5초 대기
# [1166 / 1795] 	 64.96% 	 error: 7
# 다음 기사 전 0.8초 대기
# [1167 / 1795] 	 65.01% 	 error: 7
# 다음 기사 전 0.7초 대기
# [1168 / 1795] 	 65.07% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1169 / 1795] 	 65.13% 	 error: 7
# 다음 기사 전 0.8초 대기
# [1170 / 1795] 	 65.18% 	 error: 7
# 다음 기사 전 1.2초 대기
# [1171 / 1795] 	 65.24% 	 error: 7
# 다음 기사 전 0.6초 대기
# [1172 / 1795] 	 65.29% 	 error: 7
# 다음 기사 전 0.8초 대기
# [1173 / 1795] 	 65.35% 	 error: 7
# 다음 기사 전 0.7초 대기
# [1174 / 1795] 	 65.40% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1175 / 1795] 	 65.46% 	 error: 7
# 다음 기사 전 0.7초 대기
# [1176 / 1795] 	 65.52% 	 error: 7
# 다음 기사 전 0.7초 대기
# [1177 / 1795] 	 65.57% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1178 / 1795] 	 65.63% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1179 / 1795] 	 65.68% 	 error: 7
# 다음 기사 전 0.4초 대기
# [1180 / 1795] 	 65.74% 	 error: 7
# 다음 기사 전 0.6초 대기
# [1181 / 1795] 	 65.79% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1182 / 1795] 	 65.85% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1183 / 1795] 	 65.91% 	 error: 7
# 다음 기사 전 0.9초 대기
# [
 	 error: 7
# 다음 기사 전 0.8초 대기
# [1565 / 1795] 	 87.19% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1566 / 1795] 	 87.24% 	 error: 7
# 다음 기사 전 0.7초 대기
# [1567 / 1795] 	 87.30% 	 error: 7
# 다음 기사 전 0.6초 대기
# [1568 / 1795] 	 87.35% 	 error: 7
# 다음 기사 전 0.7초 대기
# [1569 / 1795] 	 87.41% 	 error: 7
# 다음 기사 전 0.6초 대기
# [1570 / 1795] 	 87.47% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1571 / 1795] 	 87.52% 	 error: 7
# 다음 기사 전 1.0초 대기
# [1572 / 1795] 	 87.58% 	 error: 7
# 다음 기사 전 1.0초 대기
# [1573 / 1795] 	 87.63% 	 error: 7
# 다음 기사 전 1.0초 대기
# [1574 / 1795] 	 87.69% 	 error: 7
# 다음 기사 전 1.1초 대기
# [1575 / 1795] 	 87.74% 	 error: 7
# 다음 기사 전 1.0초 대기
# [1576 / 1795] 	 87.80% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1577 / 1795] 	 87.86% 	 error: 7
# 다음 기사 전 0.9초 대기
# [1578 / 1795] 	 87.91% 	 error: 7
# 다음 기사 전 1.1초 대기
# [1579 / 1795] 	 87.97% 	 error: 7
# 다음 기사 전 0.5초 대기
# [1580 / 1795] 	 88.02% 	 error: 7
# 다음 기사 전 0.5초 대기
# [1581 / 1795] 	 88.08% 	 error: 7
# 다음 기사 전 0.8초 대기
# [1582 / 1795] 	 88.13% 	 error: 7
# 다음 기사 전 0.5초 대기
# 오류 발생 — index 1582: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# [1584 / 1795] 	 88.25% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1585 / 1795] 	 88.30% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1586 / 1795] 	 88.36% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1587 / 1795] 	 88.41% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1588 / 1795] 	 88.47% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1589 / 1795] 	 88.52% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1590 / 1795] 	 88.58% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1591 / 1795] 	 88.64% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1592 / 1795] 	 88.69% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1593 / 1795] 	 88.75% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1594 / 1795] 	 88.80% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1595 / 1795] 	 88.86% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1596 / 1795] 	 88.91% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1597 / 1795] 	 88.97% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1598 / 1795] 	 89.03% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1599 / 1795] 	 89.08% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1600 / 1795] 	 89.14% 	 error: 8
# 체크포인트 저장 — 1600건 완료
# 다음 기사 전 0.9초 대기
# [1601 / 1795] 	 89.19% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1602 / 1795] 	 89.25% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1603 / 1795] 	 89.30% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1604 / 1795] 	 89.36% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1605 / 1795] 	 89.42% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1606 / 1795] 	 89.47% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1607 / 1795] 	 89.53% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1608 / 1795] 	 89.58% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1609 / 1795] 	 89.64% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1610 / 1795] 	 89.69% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1611 / 1795] 	 89.75% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1612 / 1795] 	 89.81% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1613 / 1795] 	 89.86% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1614 / 1795] 	 89.92% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1615 / 1795] 	 89.97% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1616 / 1795] 	 90.03% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1617 / 1795] 	 90.08% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1618 / 1795] 	 90.14% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1619 / 1795] 	 90.19% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1620 / 1795] 	 90.25% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1621 / 1795] 	 90.31% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1622 / 1795] 	 90.36% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1623 / 1795] 	 90.42% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1624 / 1795] 	 90.47% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1625 / 1795] 	 90.53% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1626 / 1795] 	 90.58% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1627 / 1795] 	 90.64% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1628 / 1795] 	 90.70% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1629 / 1795] 	 90.75% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1630 / 1795] 	 90.81% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1631 / 1795] 	 90.86% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1632 / 1795] 	 90.92% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1633 / 1795] 	 90.97% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1634 / 1795] 	 91.03% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1635 / 1795] 	 91.09% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1636 / 1795] 	 91.14% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1637 / 1795] 	 91.20% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1638 / 1795] 	 91.25% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1639 / 1795] 	 91.31% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1640 / 1795] 	 91.36% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1641 / 1795] 	 91.42% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1642 / 1795] 	 91.48% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1643 / 1795] 	 91.53% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1644 / 1795] 	 91.59% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1645 / 1795] 	 91.64% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1646 / 1795] 	 91.70% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1647 / 1795] 	 91.75% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1648 / 1795] 	 91.81% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1649 / 1795] 	 91.87% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1650 / 1795] 	 91.92% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1651 / 1795] 	 91.98% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1652 / 1795] 	 92.03% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1653 / 1795] 	 92.09% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1654 / 1795] 	 92.14% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1655 / 1795] 	 92.20% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1656 / 1795] 	 92.26% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1657 / 1795] 	 92.31% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1658 / 1795] 	 92.37% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1659 / 1795] 	 92.42% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1660 / 1795] 	 92.48% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1661 / 1795] 	 92.53% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1662 / 1795] 	 92.59% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1663 / 1795] 	 92.65% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1664 / 1795] 	 92.70% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1665 / 1795] 	 92.76% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1666 / 1795] 	 92.81% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1667 / 1795] 	 92.87% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1668 / 1795] 	 92.92% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1669 / 1795] 	 92.98% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1670 / 1795] 	 93.04% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1671 / 1795] 	 93.09% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1672 / 1795] 	 93.15% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1673 / 1795] 	 93.20% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1674 / 1795] 	 93.26% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1675 / 1795] 	 93.31% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1676 / 1795] 	 93.37% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1677 / 1795] 	 93.43% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1678 / 1795] 	 93.48% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1679 / 1795] 	 93.54% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1680 / 1795] 	 93.59% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1681 / 1795] 	 93.65% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1682 / 1795] 	 93.70% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1683 / 1795] 	 93.76% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1684 / 1795] 	 93.82% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1685 / 1795] 	 93.87% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1686 / 1795] 	 93.93% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1687 / 1795] 	 93.98% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1688 / 1795] 	 94.04% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1689 / 1795] 	 94.09% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1690 / 1795] 	 94.15% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1691 / 1795] 	 94.21% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1692 / 1795] 	 94.26% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1693 / 1795] 	 94.32% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1694 / 1795] 	 94.37% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1695 / 1795] 	 94.43% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1696 / 1795] 	 94.48% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1697 / 1795] 	 94.54% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1698 / 1795] 	 94.60% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1699 / 1795] 	 94.65% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1700 / 1795] 	 94.71% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1701 / 1795] 	 94.76% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1702 / 1795] 	 94.82% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1703 / 1795] 	 94.87% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1704 / 1795] 	 94.93% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1705 / 1795] 	 94.99% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1706 / 1795] 	 95.04% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1707 / 1795] 	 95.10% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1708 / 1795] 	 95.15% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1709 / 1795] 	 95.21% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1710 / 1795] 	 95.26% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1711 / 1795] 	 95.32% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1712 / 1795] 	 95.38% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1713 / 1795] 	 95.43% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1714 / 1795] 	 95.49% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1715 / 1795] 	 95.54% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1716 / 1795] 	 95.60% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1717 / 1795] 	 95.65% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1718 / 1795] 	 95.71% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1719 / 1795] 	 95.77% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1720 / 1795] 	 95.82% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1721 / 1795] 	 95.88% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1722 / 1795] 	 95.93% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1723 / 1795] 	 95.99% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1724 / 1795] 	 96.04% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1725 / 1795] 	 96.10% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1726 / 1795] 	 96.16% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1727 / 1795] 	 96.21% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1728 / 1795] 	 96.27% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1729 / 1795] 	 96.32% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1730 / 1795] 	 96.38% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1731 / 1795] 	 96.43% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1732 / 1795] 	 96.49% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1733 / 1795] 	 96.55% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1734 / 1795] 	 96.60% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1735 / 1795] 	 96.66% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1736 / 1795] 	 96.71% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1737 / 1795] 	 96.77% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1738 / 1795] 	 96.82% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1739 / 1795] 	 96.88% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1740 / 1795] 	 96.94% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1741 / 1795] 	 96.99% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1742 / 1795] 	 97.05% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1743 / 1795] 	 97.10% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1744 / 1795] 	 97.16% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1745 / 1795] 	 97.21% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1746 / 1795] 	 97.27% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1747 / 1795] 	 97.33% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1748 / 1795] 	 97.38% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1749 / 1795] 	 97.44% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1750 / 1795] 	 97.49% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1751 / 1795] 	 97.55% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1752 / 1795] 	 97.60% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1753 / 1795] 	 97.66% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1754 / 1795] 	 97.72% 	 error: 8
# 다음 기사 전 0.4초 대기
# [1755 / 1795] 	 97.77% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1756 / 1795] 	 97.83% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1757 / 1795] 	 97.88% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1758 / 1795] 	 97.94% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1759 / 1795] 	 97.99% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1760 / 1795] 	 98.05% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1761 / 1795] 	 98.11% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1762 / 1795] 	 98.16% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1763 / 1795] 	 98.22% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1764 / 1795] 	 98.27% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1765 / 1795] 	 98.33% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1766 / 1795] 	 98.38% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1767 / 1795] 	 98.44% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1768 / 1795] 	 98.50% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1769 / 1795] 	 98.55% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1770 / 1795] 	 98.61% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1771 / 1795] 	 98.66% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1772 / 1795] 	 98.72% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1773 / 1795] 	 98.77% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1774 / 1795] 	 98.83% 	 error: 8
# 다음 기사 전 0.9초 대기
# [1775 / 1795] 	 98.89% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1776 / 1795] 	 98.94% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1777 / 1795] 	 99.00% 	 error: 8
# 다음 기사 전 0.6초 대기
# [1778 / 1795] 	 99.05% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1779 / 1795] 	 99.11% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1780 / 1795] 	 99.16% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1781 / 1795] 	 99.22% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1782 / 1795] 	 99.28% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1783 / 1795] 	 99.33% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1784 / 1795] 	 99.39% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1785 / 1795] 	 99.44% 	 error: 8
# 다음 기사 전 0.7초 대기
# [1786 / 1795] 	 99.50% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1787 / 1795] 	 99.55% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1788 / 1795] 	 99.61% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1789 / 1795] 	 99.67% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1790 / 1795] 	 99.72% 	 error: 8
# 다음 기사 전 0.5초 대기
# [1791 / 1795] 	 99.78% 	 error: 8
# 다음 기사 전 0.8초 대기
# [1792 / 1795] 	 99.83% 	 error: 8
# 다음 기사 전 1.1초 대기
# [1793 / 1795] 	 99.89% 	 error: 8
# 다음 기사 전 1.0초 대기
# [1794 / 1795] 	 99.94% 	 error: 8
# 다음 기사 전 1.2초 대기
# [1795 / 1795] 	 100.00% 	 error: 8
# 다음 기사 전 0.8초 대기
#
# 오류 8건 재시도 시작...
# 재시도 실패 — index 0: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 361: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 815: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 976: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1019: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1108: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1160: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 실패 — index 1582: ValueError('title/body/pubdate 중 일부를 추출하지 못함')
# 재시도 완료 — 재실패: 8건
# 저장 완료: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_SBS_direct_260505_260511.csv
# 재실패 목록 저장: /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_재실패_SBS_direct_260505_260511.json
# 본문 수집 완료 — 총 1787건 / 오류 8건
#
# 전체 작업 완료
# 성공/건너뜀: 1개, 실패: 0개
# /content/drive/MyDrive/Text-data-Analysis_26-Spring/news/notebook/crawling/data/본문_bs4_SBS_direct_260505_260511.csv
